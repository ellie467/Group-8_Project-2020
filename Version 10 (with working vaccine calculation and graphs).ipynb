# %%
def user():
    '''Function that asks for the user for values that will be used throughout the rest of the program.'''
    population = int(input('What is the approximate population size of your city/town? ')) #Asks the user for the total population (number of individuals who can become suseptible.)
    daily_rate = int(input('What was the daily number of cases in your area? ')) #Asks the user for the the number of cases (Thus the number of infectives in the first year)
    num_gen= int(input('The assumed generation time is 10 days, how many generations do you want to go through: ')) #The number of generations indicated how many data points the user wants.
    
    high_or_low = input('Would you like the transmission rate to be a high or low estimate? ') #Asks the user for what type of estimate they would like
    if len(high_or_low)==3: #if the user wants a low estimate
        low_estimate={'England':0.8, 'Northen Ireland':0.9, 'Scotland':0.8, 'Wales':0.8} #low estimates for UK values
        country = input('What country in the UK is your town or city? ') #answer used to select from the dictionary
        B = low_estimate[country] #pulls the estimate from the dictionary
        return B, country, num_gen, daily_rate, population
    else:
        high_estimate={'England':1.0, 'Northen Ireland':1.1, 'Scotland':1.0, 'Wales':1.0} #high estimates for UK values
        country = input('What country in the UK is your town or city? ') #answer used to select from the dictionary
        B = high_estimate[country] #pulls the estimate from the dictionary
        return B, country, num_gen, daily_rate, population

# %%
def calculations():
    '''Function to Calculate the number of individuals who gain immunity each generation without the inclusion of a vaccine.'''
    B, country, num_gen, daily_rate, population = user()
    print('The transmission rate for {} is {}. '.format(country, B)) #informs the user of the information they did not directly imput
    mr= 0.036 #the UK death rate for the corona virus
    zero_death = (daily_rate*mr) #number of individuals that died from the cases the user provided
    zero_immunity = daily_rate - zero_death #number of individuals that gained immunity from the cases the user provides
    length= int(num_gen) + 1 #the number of generations the user provided +1 so that the for program goes through the required amount of times
    gen = range(1, length) #list of all generations
    total_cases = [daily_rate] #a list of all the cases
    total_immunity=[zero_immunity] #list of number of individuals immune each generation
    total_death = [zero_death] #list of number of individuals died each generation
    total_generation= [0] #creates a list of the generation numbers
    lisha_list = [zero_immunity] #Sum of total immunity each generation
    for t in gen: #Sequences through all generations
        total_generation.append(t) #adds a number to the total generation
        sum_cases = sum(total_cases) #sums all the number of cases
        if sum_cases>=population: #if total number of cases is larger than the population or there are no more cases
            print('All the population has been processed.')
            R = sum(total_immunity) #number of people who recovered
            I= daily_rate #number of people who are infectious
            portion_infected= I/population #the portion of the individuals who 
            not_in_population = (R + sum(total_death)) #sum of the people no longer suseptible either immune or dead
            S = (population-not_in_population) #removes those who are not suseptible from the population
            portion_S = (S/population) #portion of the people suseptible
            new_cases = portion_S*I*B #number of new cases: portion of individuals in the population who are suseptible * infected (contagious) * transmission rate
            total_cases.append(new_cases) #adds to the total number of cases
            death =  (new_cases)*0.036 #portion of those infected who died
            total_death.append(death) #adds to the total number of deaths
            immunity = new_cases - death #individuals who are immune that generation
            total_immunity.append(immunity) #adds to the total number of immune
            print('In generation {}, there were {:.0f} cases, after an increase of {:.0f}. {:.0f} people became immune, and {:.0f} died.'.format(t, new_cases, 
                                                                                                                               daily_rate, immunity, death))
            print('After {} generation(s) of COVID, {:.0f} number of people will be immune.'.format(t,sum(total_immunity))) 
            daily_rate = new_cases
            print(' ')
            lisha_list.append(sum(total_immunity))
            break
           
        else:
            R = sum(total_immunity) #number of people who recovered
            I= daily_rate #number of people who are infectious
            portion_infected= I/population #the portion of the individuals who 
            not_in_population = (R + sum(total_death)) #sum of the people no longer suseptible either immune or dead
            S = (population-not_in_population) #removes those who are not suseptible from the population
            portion_S = (S/population) #portion of the people suseptible
            new_cases = portion_S*I*B #number of new cases: portion of individuals in the population who are suseptible * infected (contagious) * transmission rate
            total_cases.append(new_cases) #adds to the total number of cases
            death =  (new_cases)*0.036 #portion of those infected who died
            if death<1:
                total_death.append(1) #adds to the total number of deaths
            else:
                total_death.append(death) #adds to the total number of deaths
            immunity = new_cases - death #individuals who are immune that generation
            if immunity<1:
                    total_immunity.append(1)
            else:
                total_immunity.append(immunity) #adds to the total number of immune
            print('In generation {}, there were {:.0f} cases, after an increase of {:.0f}. {:.0f} people became immune, and {:.0f} died.'.format(t, new_cases, 
                                                                                                                               daily_rate, immunity, death))
            print('After {} generation(s) of COVID, {:.0f} number of people will be immune.'.format(t,sum(total_immunity))) 
            daily_rate = new_cases
            print(' ')
            lisha_list.append(sum(total_immunity))
    
    return total_cases, total_immunity, total_death, total_generation, lisha_list

# %%
def table():
    '''Function to display and save to a file the data to be displayed in a graph'''
    total_cases, total_immunity, total_death, total_generation, lisha_list = calculations()
    #imports a software libraries needed to complete the program
    import pandas as pd
    import numpy as np
    
    #creates a dictionary of the number of generations vs the sum of the individuals with immunity
    data = {
    'Number of Generations': total_generation,
    'Number of individuals with immunity': lisha_list
        }
    
    #prints the information in data to a table
    table = pd.DataFrame(data)
    print(table)
    numpy_array = table.to_numpy()
    print(' ')
    
    decide= input('Do you want to save the report to a file? Enter yes or no: ') #ask if they want to save a file
    if len(decide)==3: #If they input yes
        #currently only input that works is Gen
        print('Your file name will be "Gen"') #user needs to provide a file name
        
        how = input('How would you like your file to be opened? Enter append or write: ') #ask how they want the data to be saved
        confirm_how = input('Confirm editing format with yes or no: ') #ask for confirmation
        if len(confirm_how)==2:#if enter no
            how = input('How would you like your file to be opened? Enter append or write: ') #allowed to enter again
        if len(how)== 5: #write the following into the provided file
            file = open('Gen', 'w')
            np.savetxt('Gen' , numpy_array, fmt = "%d")
            file.close()
            print('The program is complete.')
        else: #append the following into the provided file
            file= open('Gen', 'a')
            np.savetxt('Gen' , numpy_array, fmt = "%d")
            file.close()
            print('The program is complete.')
                    
    else: #if the user doesn't want to save a file.
        print('Okay, the program is complete.')

# %%
def graph():
    '''Function which prints a graph of established data'''
    import pandas as pd
    table()
    tdf= pd.read_csv("Gen",sep=" ") #reads file to collect the data
    tdf.shape
    tdf=pd.read_csv("Gen",sep=" ",names=["Gen time", "Immunity"]) #creates headers for the graph
    tdf.head()
    tdf.plot(x="Gen time",y="Immunity") #plots the data

# %%
graph()
# Out:
# What is the approximate population size of your city/town? 5000000
# What was the daily number of cases in your area? 754
# The assumed generation time is 10 days, how many Generation do you want to go through: 300
# Would you like the transmission rate to be a high or low estimate? high
# What country in the UK is your town or city? Scotland
# The transmission rate for Scotland is 1.0.
# In generation 1, there were 754 cases, after an increase of 754. 727 people became immune, and 27 died.
# After 1 generation(s) of COVID, 1454 number of people will be immune.
#
# In generation 2, there were 754 cases, after an increase of 754. 727 people became immune, and 27 died.
# After 2 generation(s) of COVID, 2180 number of people will be immune.
#
# In generation 3, there were 753 cases, after an increase of 754. 726 people became immune, and 27 died.
# After 3 generation(s) of COVID, 2906 number of people will be immune.
#
# In generation 4, there were 753 cases, after an increase of 753. 726 people became immune, and 27 died.
# After 4 generation(s) of COVID, 3632 number of people will be immune.
#
# In generation 5, there were 752 cases, after an increase of 753. 725 people became immune, and 27 died.
# After 5 generation(s) of COVID, 4357 number of people will be immune.
#
# In generation 6, there were 752 cases, after an increase of 752. 725 people became immune, and 27 died.
# After 6 generation(s) of COVID, 5082 number of people will be immune.
#
# In generation 7, there were 751 cases, after an increase of 752. 724 people became immune, and 27 died.
# After 7 generation(s) of COVID, 5806 number of people will be immune.
#
# In generation 8, there were 750 cases, after an increase of 751. 723 people became immune, and 27 died.
# After 8 generation(s) of COVID, 6529 number of people will be immune.
#
# In generation 9, there were 749 cases, after an increase of 750. 722 people became immune, and 27 died.
# After 9 generation(s) of COVID, 7251 number of people will be immune.
#
# In generation 10, there were 748 cases, after an increase of 749. 721 people became immune, and 27 died.
# After 10 generation(s) of COVID, 7971 number of people will be immune.
#
# In generation 11, there were 747 cases, after an increase of 748. 720 people became immune, and 27 died.
# After 11 generation(s) of COVID, 8691 number of people will be immune.
#
# In generation 12, there were 745 cases, after an increase of 747. 718 people became immune, and 27 died.
# After 12 generation(s) of COVID, 9409 number of people will be immune.
#
# In generation 13, there were 744 cases, after an increase of 745. 717 people became immune, and 27 died.
# After 13 generation(s) of COVID, 10126 number of people will be immune.
#
# In generation 14, there were 742 cases, after an increase of 744. 715 people became immune, and 27 died.
# After 14 generation(s) of COVID, 10842 number of people will be immune.
#
# In generation 15, there were 741 cases, after an increase of 742. 714 people became immune, and 27 died.
# After 15 generation(s) of COVID, 11556 number of people will be immune.
#
# In generation 16, there were 739 cases, after an increase of 741. 712 people became immune, and 27 died.
# After 16 generation(s) of COVID, 12268 number of people will be immune.
#
# In generation 17, there were 737 cases, after an increase of 739. 710 people became immune, and 27 died.
# After 17 generation(s) of COVID, 12978 number of people will be immune.
#
# In generation 18, there were 735 cases, after an increase of 737. 708 people became immune, and 26 died.
# After 18 generation(s) of COVID, 13687 number of people will be immune.
#
# In generation 19, there were 733 cases, after an increase of 735. 706 people became immune, and 26 died.
# After 19 generation(s) of COVID, 14393 number of people will be immune.
#
# In generation 20, there were 731 cases, after an increase of 733. 704 people became immune, and 26 died.
# After 20 generation(s) of COVID, 15097 number of people will be immune.
#
# In generation 21, there were 728 cases, after an increase of 731. 702 people became immune, and 26 died.
# After 21 generation(s) of COVID, 15799 number of people will be immune.
#
# In generation 22, there were 726 cases, after an increase of 728. 700 people became immune, and 26 died.
# After 22 generation(s) of COVID, 16499 number of people will be immune.
#
# In generation 23, there were 723 cases, after an increase of 726. 697 people became immune, and 26 died.
# After 23 generation(s) of COVID, 17197 number of people will be immune.
#
# In generation 24, there were 721 cases, after an increase of 723. 695 people became immune, and 26 died.
# After 24 generation(s) of COVID, 17891 number of people will be immune.
#
# In generation 25, there were 718 cases, after an increase of 721. 692 people became immune, and 26 died.
# After 25 generation(s) of COVID, 18584 number of people will be immune.
#
# In generation 26, there were 715 cases, after an increase of 718. 690 people became immune, and 26 died.
# After 26 generation(s) of COVID, 19273 number of people will be immune.
#
# In generation 27, there were 713 cases, after an increase of 715. 687 people became immune, and 26 died.
# After 27 generation(s) of COVID, 19960 number of people will be immune.
#
# In generation 28, there were 710 cases, after an increase of 713. 684 people became immune, and 26 died.
# After 28 generation(s) of COVID, 20644 number of people will be immune.
#
# In generation 29, there were 707 cases, after an increase of 710. 681 people became immune, and 25 died.
# After 29 generation(s) of COVID, 21325 number of people will be immune.
#
# In generation 30, there were 703 cases, after an increase of 707. 678 people became immune, and 25 died.
# After 30 generation(s) of COVID, 22004 number of people will be immune.
#
# In generation 31, there were 700 cases, after an increase of 703. 675 people became immune, and 25 died.
# After 31 generation(s) of COVID, 22679 number of people will be immune.
#
# In generation 32, there were 697 cases, after an increase of 700. 672 people became immune, and 25 died.
# After 32 generation(s) of COVID, 23350 number of people will be immune.
#
# In generation 33, there were 694 cases, after an increase of 697. 669 people became immune, and 25 died.
# After 33 generation(s) of COVID, 24019 number of people will be immune.
#
# In generation 34, there were 690 cases, after an increase of 694. 665 people became immune, and 25 died.
# After 34 generation(s) of COVID, 24684 number of people will be immune.
#
# In generation 35, there were 687 cases, after an increase of 690. 662 people became immune, and 25 died.
# After 35 generation(s) of COVID, 25346 number of people will be immune.
#
# In generation 36, there were 683 cases, after an increase of 687. 658 people became immune, and 25 died.
# After 36 generation(s) of COVID, 26004 number of people will be immune.
#
# In generation 37, there were 679 cases, after an increase of 683. 655 people became immune, and 24 died.
# After 37 generation(s) of COVID, 26659 number of people will be immune.
#
# In generation 38, there were 676 cases, after an increase of 679. 651 people became immune, and 24 died.
# After 38 generation(s) of COVID, 27310 number of people will be immune.
#
# In generation 39, there were 672 cases, after an increase of 676. 647 people became immune, and 24 died.
# After 39 generation(s) of COVID, 27958 number of people will be immune.
#
# In generation 40, there were 668 cases, after an increase of 672. 644 people became immune, and 24 died.
# After 40 generation(s) of COVID, 28602 number of people will be immune.
#
# In generation 41, there were 664 cases, after an increase of 668. 640 people became immune, and 24 died.
# After 41 generation(s) of COVID, 29242 number of people will be immune.
#
# In generation 42, there were 660 cases, after an increase of 664. 636 people became immune, and 24 died.
# After 42 generation(s) of COVID, 29878 number of people will be immune.
#
# In generation 43, there were 656 cases, after an increase of 660. 632 people became immune, and 24 died.
# After 43 generation(s) of COVID, 30510 number of people will be immune.
#
# In generation 44, there were 652 cases, after an increase of 656. 628 people became immune, and 23 died.
# After 44 generation(s) of COVID, 31138 number of people will be immune.
#
# In generation 45, there were 647 cases, after an increase of 652. 624 people became immune, and 23 died.
# After 45 generation(s) of COVID, 31762 number of people will be immune.
#
# In generation 46, there were 643 cases, after an increase of 647. 620 people became immune, and 23 died.
# After 46 generation(s) of COVID, 32382 number of people will be immune.
#
# In generation 47, there were 639 cases, after an increase of 643. 616 people became immune, and 23 died.
# After 47 generation(s) of COVID, 32998 number of people will be immune.
#
# In generation 48, there were 634 cases, after an increase of 639. 612 people became immune, and 23 died.
# After 48 generation(s) of COVID, 33609 number of people will be immune.
#
# In generation 49, there were 630 cases, after an increase of 634. 607 people became immune, and 23 died.
# After 49 generation(s) of COVID, 34216 number of people will be immune.
#
# In generation 50, there were 625 cases, after an increase of 630. 603 people became immune, and 23 died.
# After 50 generation(s) of COVID, 34819 number of people will be immune.
#
# In generation 51, there were 621 cases, after an increase of 625. 599 people became immune, and 22 died.
# After 51 generation(s) of COVID, 35418 number of people will be immune.
#
# In generation 52, there were 616 cases, after an increase of 621. 594 people became immune, and 22 died.
# After 52 generation(s) of COVID, 36012 number of people will be immune.
#
# In generation 53, there were 612 cases, after an increase of 616. 590 people became immune, and 22 died.
# After 53 generation(s) of COVID, 36602 number of people will be immune.
#
# In generation 54, there were 607 cases, after an increase of 612. 585 people became immune, and 22 died.
# After 54 generation(s) of COVID, 37187 number of people will be immune.
#
# In generation 55, there were 602 cases, after an increase of 607. 581 people became immune, and 22 died.
# After 55 generation(s) of COVID, 37768 number of people will be immune.
#
# In generation 56, there were 598 cases, after an increase of 602. 576 people became immune, and 22 died.
# After 56 generation(s) of COVID, 38344 number of people will be immune.
#
# In generation 57, there were 593 cases, after an increase of 598. 572 people became immune, and 21 died.
# After 57 generation(s) of COVID, 38916 number of people will be immune.
#
# In generation 58, there were 588 cases, after an increase of 593. 567 people became immune, and 21 died.
# After 58 generation(s) of COVID, 39483 number of people will be immune.
#
# In generation 59, there were 583 cases, after an increase of 588. 562 people became immune, and 21 died.
# After 59 generation(s) of COVID, 40045 number of people will be immune.
#
# In generation 60, there were 579 cases, after an increase of 583. 558 people became immune, and 21 died.
# After 60 generation(s) of COVID, 40603 number of people will be immune.
#
# In generation 61, there were 574 cases, after an increase of 579. 553 people became immune, and 21 died.
# After 61 generation(s) of COVID, 41156 number of people will be immune.
#
# In generation 62, there were 569 cases, after an increase of 574. 548 people became immune, and 20 died.
# After 62 generation(s) of COVID, 41704 number of people will be immune.
#
# In generation 63, there were 564 cases, after an increase of 569. 544 people became immune, and 20 died.
# After 63 generation(s) of COVID, 42248 number of people will be immune.
#
# In generation 64, there were 559 cases, after an increase of 564. 539 people became immune, and 20 died.
# After 64 generation(s) of COVID, 42787 number of people will be immune.
#
# In generation 65, there were 554 cases, after an increase of 559. 534 people became immune, and 20 died.
# After 65 generation(s) of COVID, 43321 number of people will be immune.
#
# In generation 66, there were 549 cases, after an increase of 554. 529 people became immune, and 20 died.
# After 66 generation(s) of COVID, 43850 number of people will be immune.
#
# In generation 67, there were 544 cases, after an increase of 549. 524 people became immune, and 20 died.
# After 67 generation(s) of COVID, 44374 number of people will be immune.
#
# In generation 68, there were 539 cases, after an increase of 544. 520 people became immune, and 19 died.
# After 68 generation(s) of COVID, 44894 number of people will be immune.
#
# In generation 69, there were 534 cases, after an increase of 539. 515 people became immune, and 19 died.
# After 69 generation(s) of COVID, 45409 number of people will be immune.
#
# In generation 70, there were 529 cases, after an increase of 534. 510 people became immune, and 19 died.
# After 70 generation(s) of COVID, 45918 number of people will be immune.
#
# In generation 71, there were 524 cases, after an increase of 529. 505 people became immune, and 19 died.
# After 71 generation(s) of COVID, 46424 number of people will be immune.
#
# In generation 72, there were 519 cases, after an increase of 524. 500 people became immune, and 19 died.
# After 72 generation(s) of COVID, 46924 number of people will be immune.
#
# In generation 73, there were 514 cases, after an increase of 519. 495 people became immune, and 18 died.
# After 73 generation(s) of COVID, 47419 number of people will be immune.
#
# In generation 74, there were 509 cases, after an increase of 514. 490 people became immune, and 18 died.
# After 74 generation(s) of COVID, 47909 number of people will be immune.
#
# In generation 75, there were 504 cases, after an increase of 509. 486 people became immune, and 18 died.
# After 75 generation(s) of COVID, 48395 number of people will be immune.
#
# In generation 76, there were 499 cases, after an increase of 504. 481 people became immune, and 18 died.
# After 76 generation(s) of COVID, 48876 number of people will be immune.
#
# In generation 77, there were 494 cases, after an increase of 499. 476 people became immune, and 18 died.
# After 77 generation(s) of COVID, 49351 number of people will be immune.
#
# In generation 78, there were 489 cases, after an increase of 494. 471 people became immune, and 18 died.
# After 78 generation(s) of COVID, 49822 number of people will be immune.
#
# In generation 79, there were 483 cases, after an increase of 489. 466 people became immune, and 17 died.
# After 79 generation(s) of COVID, 50288 number of people will be immune.
#
# In generation 80, there were 478 cases, after an increase of 483. 461 people became immune, and 17 died.
# After 80 generation(s) of COVID, 50749 number of people will be immune.
#
# In generation 81, there were 473 cases, after an increase of 478. 456 people became immune, and 17 died.
# After 81 generation(s) of COVID, 51206 number of people will be immune.
#
# In generation 82, there were 468 cases, after an increase of 473. 451 people became immune, and 17 died.
# After 82 generation(s) of COVID, 51657 number of people will be immune.
#
# In generation 83, there were 463 cases, after an increase of 468. 447 people became immune, and 17 died.
# After 83 generation(s) of COVID, 52104 number of people will be immune.
#
# In generation 84, there were 458 cases, after an increase of 463. 442 people became immune, and 16 died.
# After 84 generation(s) of COVID, 52546 number of people will be immune.
#
# In generation 85, there were 453 cases, after an increase of 458. 437 people became immune, and 16 died.
# After 85 generation(s) of COVID, 52983 number of people will be immune.
#
# In generation 86, there were 448 cases, after an increase of 453. 432 people became immune, and 16 died.
# After 86 generation(s) of COVID, 53415 number of people will be immune.
#
# In generation 87, there were 443 cases, after an increase of 448. 427 people became immune, and 16 died.
# After 87 generation(s) of COVID, 53842 number of people will be immune.
#
# In generation 88, there were 438 cases, after an increase of 443. 423 people became immune, and 16 died.
# After 88 generation(s) of COVID, 54265 number of people will be immune.
#
# In generation 89, there were 433 cases, after an increase of 438. 418 people became immune, and 16 died.
# After 89 generation(s) of COVID, 54683 number of people will be immune.
#
# In generation 90, there were 429 cases, after an increase of 433. 413 people became immune, and 15 died.
# After 90 generation(s) of COVID, 55096 number of people will be immune.
#
# In generation 91, there were 424 cases, after an increase of 429. 408 people became immune, and 15 died.
# After 91 generation(s) of COVID, 55504 number of people will be immune.
#
# In generation 92, there were 419 cases, after an increase of 424. 404 people became immune, and 15 died.
# After 92 generation(s) of COVID, 55908 number of people will be immune.
#
# In generation 93, there were 414 cases, after an increase of 419. 399 people became immune, and 15 died.
# After 93 generation(s) of COVID, 56307 number of people will be immune.
#
# In generation 94, there were 409 cases, after an increase of 414. 394 people became immune, and 15 died.
# After 94 generation(s) of COVID, 56702 number of people will be immune.
#
# In generation 95, there were 404 cases, after an increase of 409. 390 people became immune, and 15 died.
# After 95 generation(s) of COVID, 57091 number of people will be immune.
#
# In generation 96, there were 399 cases, after an increase of 404. 385 people became immune, and 14 died.
# After 96 generation(s) of COVID, 57476 number of people will be immune.
#
# In generation 97, there were 395 cases, after an increase of 399. 381 people became immune, and 14 died.
# After 97 generation(s) of COVID, 57857 number of people will be immune.
#
# In generation 98, there were 390 cases, after an increase of 395. 376 people became immune, and 14 died.
# After 98 generation(s) of COVID, 58233 number of people will be immune.
#
# In generation 99, there were 385 cases, after an increase of 390. 371 people became immune, and 14 died.
# After 99 generation(s) of COVID, 58604 number of people will be immune.
#
# In generation 100, there were 381 cases, after an increase of 385. 367 people became immune, and 14 died.
# After 100 generation(s) of COVID, 58971 number of people will be immune.
#
# In generation 101, there were 376 cases, after an increase of 381. 362 people became immune, and 14 died.
# After 101 generation(s) of COVID, 59334 number of people will be immune.
#
# In generation 102, there were 371 cases, after an increase of 376. 358 people became immune, and 13 died.
# After 102 generation(s) of COVID, 59691 number of people will be immune.
#
# In generation 103, there were 367 cases, after an increase of 371. 354 people became immune, and 13 died.
# After 103 generation(s) of COVID, 60045 number of people will be immune.
#
# In generation 104, there were 362 cases, after an increase of 367. 349 people became immune, and 13 died.
# After 104 generation(s) of COVID, 60394 number of people will be immune.
#
# In generation 105, there were 358 cases, after an increase of 362. 345 people became immune, and 13 died.
# After 105 generation(s) of COVID, 60739 number of people will be immune.
#
# In generation 106, there were 353 cases, after an increase of 358. 340 people became immune, and 13 died.
# After 106 generation(s) of COVID, 61079 number of people will be immune.
#
# In generation 107, there were 349 cases, after an increase of 353. 336 people became immune, and 13 died.
# After 107 generation(s) of COVID, 61415 number of people will be immune.
#
# In generation 108, there were 344 cases, after an increase of 349. 332 people became immune, and 12 died.
# After 108 generation(s) of COVID, 61747 number of people will be immune.
#
# In generation 109, there were 340 cases, after an increase of 344. 328 people became immune, and 12 died.
# After 109 generation(s) of COVID, 62075 number of people will be immune.
#
# In generation 110, there were 335 cases, after an increase of 340. 323 people became immune, and 12 died.
# After 110 generation(s) of COVID, 62398 number of people will be immune.
#
# In generation 111, there were 331 cases, after an increase of 335. 319 people became immune, and 12 died.
# After 111 generation(s) of COVID, 62717 number of people will be immune.
#
# In generation 112, there were 327 cases, after an increase of 331. 315 people became immune, and 12 died.
# After 112 generation(s) of COVID, 63032 number of people will be immune.
#
# In generation 113, there were 322 cases, after an increase of 327. 311 people became immune, and 12 died.
# After 113 generation(s) of COVID, 63343 number of people will be immune.
#
# In generation 114, there were 318 cases, after an increase of 322. 307 people became immune, and 11 died.
# After 114 generation(s) of COVID, 63650 number of people will be immune.
#
# In generation 115, there were 314 cases, after an increase of 318. 303 people became immune, and 11 died.
# After 115 generation(s) of COVID, 63952 number of people will be immune.
#
# In generation 116, there were 310 cases, after an increase of 314. 299 people became immune, and 11 died.
# After 116 generation(s) of COVID, 64251 number of people will be immune.
#
# In generation 117, there were 306 cases, after an increase of 310. 295 people became immune, and 11 died.
# After 117 generation(s) of COVID, 64546 number of people will be immune.
#
# In generation 118, there were 302 cases, after an increase of 306. 291 people became immune, and 11 died.
# After 118 generation(s) of COVID, 64837 number of people will be immune.
#
# In generation 119, there were 298 cases, after an increase of 302. 287 people became immune, and 11 died.
# After 119 generation(s) of COVID, 65123 number of people will be immune.
#
# In generation 120, there were 294 cases, after an increase of 298. 283 people became immune, and 11 died.
# After 120 generation(s) of COVID, 65406 number of people will be immune.
#
# In generation 121, there were 290 cases, after an increase of 294. 279 people became immune, and 10 died.
# After 121 generation(s) of COVID, 65686 number of people will be immune.
#
# In generation 122, there were 286 cases, after an increase of 290. 275 people became immune, and 10 died.
# After 122 generation(s) of COVID, 65961 number of people will be immune.
#
# In generation 123, there were 282 cases, after an increase of 286. 272 people became immune, and 10 died.
# After 123 generation(s) of COVID, 66233 number of people will be immune.
#
# In generation 124, there were 278 cases, after an increase of 282. 268 people became immune, and 10 died.
# After 124 generation(s) of COVID, 66500 number of people will be immune.
#
# In generation 125, there were 274 cases, after an increase of 278. 264 people became immune, and 10 died.
# After 125 generation(s) of COVID, 66765 number of people will be immune.
#
# In generation 126, there were 270 cases, after an increase of 274. 260 people became immune, and 10 died.
# After 126 generation(s) of COVID, 67025 number of people will be immune.
#
# In generation 127, there were 266 cases, after an increase of 270. 257 people became immune, and 10 died.
# After 127 generation(s) of COVID, 67282 number of people will be immune.
#
# In generation 128, there were 263 cases, after an increase of 266. 253 people became immune, and 9 died.
# After 128 generation(s) of COVID, 67535 number of people will be immune.
#
# In generation 129, there were 259 cases, after an increase of 263. 250 people became immune, and 9 died.
# After 129 generation(s) of COVID, 67785 number of people will be immune.
#
# In generation 130, there were 255 cases, after an increase of 259. 246 people became immune, and 9 died.
# After 130 generation(s) of COVID, 68031 number of people will be immune.
#
# In generation 131, there were 252 cases, after an increase of 255. 243 people became immune, and 9 died.
# After 131 generation(s) of COVID, 68274 number of people will be immune.
#
# In generation 132, there were 248 cases, after an increase of 252. 239 people became immune, and 9 died.
# After 132 generation(s) of COVID, 68513 number of people will be immune.
#
# In generation 133, there were 245 cases, after an increase of 248. 236 people became immune, and 9 died.
# After 133 generation(s) of COVID, 68749 number of people will be immune.
#
# In generation 134, there were 241 cases, after an increase of 245. 233 people became immune, and 9 died.
# After 134 generation(s) of COVID, 68982 number of people will be immune.
#
# In generation 135, there were 238 cases, after an increase of 241. 229 people became immune, and 9 died.
# After 135 generation(s) of COVID, 69211 number of people will be immune.
#
# In generation 136, there were 234 cases, after an increase of 238. 226 people became immune, and 8 died.
# After 136 generation(s) of COVID, 69437 number of people will be immune.
#
# In generation 137, there were 231 cases, after an increase of 234. 223 people became immune, and 8 died.
# After 137 generation(s) of COVID, 69660 number of people will be immune.
#
# In generation 138, there were 228 cases, after an increase of 231. 219 people became immune, and 8 died.
# After 138 generation(s) of COVID, 69879 number of people will be immune.
#
# In generation 139, there were 224 cases, after an increase of 228. 216 people became immune, and 8 died.
# After 139 generation(s) of COVID, 70095 number of people will be immune.
#
# In generation 140, there were 221 cases, after an increase of 224. 213 people became immune, and 8 died.
# After 140 generation(s) of COVID, 70308 number of people will be immune.
#
# In generation 141, there were 218 cases, after an increase of 221. 210 people became immune, and 8 died.
# After 141 generation(s) of COVID, 70518 number of people will be immune.
#
# In generation 142, there were 215 cases, after an increase of 218. 207 people became immune, and 8 died.
# After 142 generation(s) of COVID, 70725 number of people will be immune.
#
# In generation 143, there were 212 cases, after an increase of 215. 204 people became immune, and 8 died.
# After 143 generation(s) of COVID, 70929 number of people will be immune.
#
# In generation 144, there were 208 cases, after an increase of 212. 201 people became immune, and 8 died.
# After 144 generation(s) of COVID, 71130 number of people will be immune.
#
# In generation 145, there were 205 cases, after an increase of 208. 198 people became immune, and 7 died.
# After 145 generation(s) of COVID, 71328 number of people will be immune.
#
# In generation 146, there were 202 cases, after an increase of 205. 195 people became immune, and 7 died.
# After 146 generation(s) of COVID, 71523 number of people will be immune.
#
# In generation 147, there were 199 cases, after an increase of 202. 192 people became immune, and 7 died.
# After 147 generation(s) of COVID, 71715 number of people will be immune.
#
# In generation 148, there were 196 cases, after an increase of 199. 189 people became immune, and 7 died.
# After 148 generation(s) of COVID, 71905 number of people will be immune.
#
# In generation 149, there were 193 cases, after an increase of 196. 186 people became immune, and 7 died.
# After 149 generation(s) of COVID, 72091 number of people will be immune.
#
# In generation 150, there were 191 cases, after an increase of 193. 184 people became immune, and 7 died.
# After 150 generation(s) of COVID, 72275 number of people will be immune.
#
# In generation 151, there were 188 cases, after an increase of 191. 181 people became immune, and 7 died.
# After 151 generation(s) of COVID, 72455 number of people will be immune.
#
# In generation 152, there were 185 cases, after an increase of 188. 178 people became immune, and 7 died.
# After 152 generation(s) of COVID, 72634 number of people will be immune.
#
# In generation 153, there were 182 cases, after an increase of 185. 175 people became immune, and 7 died.
# After 153 generation(s) of COVID, 72809 number of people will be immune.
#
# In generation 154, there were 179 cases, after an increase of 182. 173 people became immune, and 6 died.
# After 154 generation(s) of COVID, 72982 number of people will be immune.
#
# In generation 155, there were 177 cases, after an increase of 179. 170 people became immune, and 6 died.
# After 155 generation(s) of COVID, 73152 number of people will be immune.
#
# In generation 156, there were 174 cases, after an increase of 177. 168 people became immune, and 6 died.
# After 156 generation(s) of COVID, 73320 number of people will be immune.
#
# In generation 157, there were 171 cases, after an increase of 174. 165 people became immune, and 6 died.
# After 157 generation(s) of COVID, 73485 number of people will be immune.
#
# In generation 158, there were 169 cases, after an increase of 171. 163 people became immune, and 6 died.
# After 158 generation(s) of COVID, 73648 number of people will be immune.
#
# In generation 159, there were 166 cases, after an increase of 169. 160 people became immune, and 6 died.
# After 159 generation(s) of COVID, 73808 number of people will be immune.
#
# In generation 160, there were 164 cases, after an increase of 166. 158 people became immune, and 6 died.
# After 160 generation(s) of COVID, 73965 number of people will be immune.
#
# In generation 161, there were 161 cases, after an increase of 164. 155 people became immune, and 6 died.
# After 161 generation(s) of COVID, 74120 number of people will be immune.
#
# In generation 162, there were 159 cases, after an increase of 161. 153 people became immune, and 6 died.
# After 162 generation(s) of COVID, 74273 number of people will be immune.
#
# In generation 163, there were 156 cases, after an increase of 159. 150 people became immune, and 6 died.
# After 163 generation(s) of COVID, 74424 number of people will be immune.
#
# In generation 164, there were 154 cases, after an increase of 156. 148 people became immune, and 6 died.
# After 164 generation(s) of COVID, 74572 number of people will be immune.
#
# In generation 165, there were 151 cases, after an increase of 154. 146 people became immune, and 5 died.
# After 165 generation(s) of COVID, 74718 number of people will be immune.
#
# In generation 166, there were 149 cases, after an increase of 151. 144 people became immune, and 5 died.
# After 166 generation(s) of COVID, 74861 number of people will be immune.
#
# In generation 167, there were 147 cases, after an increase of 149. 141 people became immune, and 5 died.
# After 167 generation(s) of COVID, 75003 number of people will be immune.
#
# In generation 168, there were 144 cases, after an increase of 147. 139 people became immune, and 5 died.
# After 168 generation(s) of COVID, 75142 number of people will be immune.
#
# In generation 169, there were 142 cases, after an increase of 144. 137 people became immune, and 5 died.
# After 169 generation(s) of COVID, 75279 number of people will be immune.
#
# In generation 170, there were 140 cases, after an increase of 142. 135 people became immune, and 5 died.
# After 170 generation(s) of COVID, 75414 number of people will be immune.
#
# In generation 171, there were 138 cases, after an increase of 140. 133 people became immune, and 5 died.
# After 171 generation(s) of COVID, 75547 number of people will be immune.
#
# In generation 172, there were 136 cases, after an increase of 138. 131 people became immune, and 5 died.
# After 172 generation(s) of COVID, 75677 number of people will be immune.
#
# In generation 173, there were 133 cases, after an increase of 136. 129 people became immune, and 5 died.
# After 173 generation(s) of COVID, 75806 number of people will be immune.
#
# In generation 174, there were 131 cases, after an increase of 133. 127 people became immune, and 5 died.
# After 174 generation(s) of COVID, 75932 number of people will be immune.
#
# In generation 175, there were 129 cases, after an increase of 131. 125 people became immune, and 5 died.
# After 175 generation(s) of COVID, 76057 number of people will be immune.
#
# In generation 176, there were 127 cases, after an increase of 129. 123 people became immune, and 5 died.
# After 176 generation(s) of COVID, 76180 number of people will be immune.
#
# In generation 177, there were 125 cases, after an increase of 127. 121 people became immune, and 5 died.
# After 177 generation(s) of COVID, 76300 number of people will be immune.
#
# In generation 178, there were 123 cases, after an increase of 125. 119 people became immune, and 4 died.
# After 178 generation(s) of COVID, 76419 number of people will be immune.
#
# In generation 179, there were 121 cases, after an increase of 123. 117 people became immune, and 4 died.
# After 179 generation(s) of COVID, 76536 number of people will be immune.
#
# In generation 180, there were 119 cases, after an increase of 121. 115 people became immune, and 4 died.
# After 180 generation(s) of COVID, 76651 number of people will be immune.
#
# In generation 181, there were 117 cases, after an increase of 119. 113 people became immune, and 4 died.
# After 181 generation(s) of COVID, 76764 number of people will be immune.
#
# In generation 182, there were 116 cases, after an increase of 117. 111 people became immune, and 4 died.
# After 182 generation(s) of COVID, 76876 number of people will be immune.
#
# In generation 183, there were 114 cases, after an increase of 116. 110 people became immune, and 4 died.
# After 183 generation(s) of COVID, 76985 number of people will be immune.
#
# In generation 184, there were 112 cases, after an increase of 114. 108 people became immune, and 4 died.
# After 184 generation(s) of COVID, 77093 number of people will be immune.
#
# In generation 185, there were 110 cases, after an increase of 112. 106 people became immune, and 4 died.
# After 185 generation(s) of COVID, 77199 number of people will be immune.
#
# In generation 186, there were 108 cases, after an increase of 110. 104 people became immune, and 4 died.
# After 186 generation(s) of COVID, 77304 number of people will be immune.
#
# In generation 187, there were 107 cases, after an increase of 108. 103 people became immune, and 4 died.
# After 187 generation(s) of COVID, 77407 number of people will be immune.
#
# In generation 188, there were 105 cases, after an increase of 107. 101 people became immune, and 4 died.
# After 188 generation(s) of COVID, 77508 number of people will be immune.
#
# In generation 189, there were 103 cases, after an increase of 105. 100 people became immune, and 4 died.
# After 189 generation(s) of COVID, 77607 number of people will be immune.
#
# In generation 190, there were 102 cases, after an increase of 103. 98 people became immune, and 4 died.
# After 190 generation(s) of COVID, 77705 number of people will be immune.
#
# In generation 191, there were 100 cases, after an increase of 102. 96 people became immune, and 4 died.
# After 191 generation(s) of COVID, 77802 number of people will be immune.
#
# In generation 192, there were 98 cases, after an increase of 100. 95 people became immune, and 4 died.
# After 192 generation(s) of COVID, 77896 number of people will be immune.
#
# In generation 193, there were 97 cases, after an increase of 98. 93 people became immune, and 3 died.
# After 193 generation(s) of COVID, 77990 number of people will be immune.
#
# In generation 194, there were 95 cases, after an increase of 97. 92 people became immune, and 3 died.
# After 194 generation(s) of COVID, 78081 number of people will be immune.
#
# In generation 195, there were 94 cases, after an increase of 95. 90 people became immune, and 3 died.
# After 195 generation(s) of COVID, 78172 number of people will be immune.
#
# In generation 196, there were 92 cases, after an increase of 94. 89 people became immune, and 3 died.
# After 196 generation(s) of COVID, 78260 number of people will be immune.
#
# In generation 197, there were 91 cases, after an increase of 92. 87 people became immune, and 3 died.
# After 197 generation(s) of COVID, 78348 number of people will be immune.
#
# In generation 198, there were 89 cases, after an increase of 91. 86 people became immune, and 3 died.
# After 198 generation(s) of COVID, 78434 number of people will be immune.
#
# In generation 199, there were 88 cases, after an increase of 89. 85 people became immune, and 3 died.
# After 199 generation(s) of COVID, 78518 number of people will be immune.
#
# In generation 200, there were 86 cases, after an increase of 88. 83 people became immune, and 3 died.
# After 200 generation(s) of COVID, 78601 number of people will be immune.
#
# In generation 201, there were 85 cases, after an increase of 86. 82 people became immune, and 3 died.
# After 201 generation(s) of COVID, 78683 number of people will be immune.
#
# In generation 202, there were 83 cases, after an increase of 85. 80 people became immune, and 3 died.
# After 202 generation(s) of COVID, 78764 number of people will be immune.
#
# In generation 203, there were 82 cases, after an increase of 83. 79 people became immune, and 3 died.
# After 203 generation(s) of COVID, 78843 number of people will be immune.
#
# In generation 204, there were 81 cases, after an increase of 82. 78 people became immune, and 3 died.
# After 204 generation(s) of COVID, 78920 number of people will be immune.
#
# In generation 205, there were 79 cases, after an increase of 81. 77 people became immune, and 3 died.
# After 205 generation(s) of COVID, 78997 number of people will be immune.
#
# In generation 206, there were 78 cases, after an increase of 79. 75 people became immune, and 3 died.
# After 206 generation(s) of COVID, 79072 number of people will be immune.
#
# In generation 207, there were 77 cases, after an increase of 78. 74 people became immune, and 3 died.
# After 207 generation(s) of COVID, 79146 number of people will be immune.
#
# In generation 208, there were 76 cases, after an increase of 77. 73 people became immune, and 3 died.
# After 208 generation(s) of COVID, 79219 number of people will be immune.
#
# In generation 209, there were 74 cases, after an increase of 76. 72 people became immune, and 3 died.
# After 209 generation(s) of COVID, 79291 number of people will be immune.
#
# In generation 210, there were 73 cases, after an increase of 74. 70 people became immune, and 3 died.
# After 210 generation(s) of COVID, 79361 number of people will be immune.
#
# In generation 211, there were 72 cases, after an increase of 73. 69 people became immune, and 3 died.
# After 211 generation(s) of COVID, 79431 number of people will be immune.
#
# In generation 212, there were 71 cases, after an increase of 72. 68 people became immune, and 3 died.
# After 212 generation(s) of COVID, 79499 number of people will be immune.
#
# In generation 213, there were 70 cases, after an increase of 71. 67 people became immune, and 3 died.
# After 213 generation(s) of COVID, 79566 number of people will be immune.
#
# In generation 214, there were 68 cases, after an increase of 70. 66 people became immune, and 2 died.
# After 214 generation(s) of COVID, 79632 number of people will be immune.
#
# In generation 215, there were 67 cases, after an increase of 68. 65 people became immune, and 2 died.
# After 215 generation(s) of COVID, 79697 number of people will be immune.
#
# In generation 216, there were 66 cases, after an increase of 67. 64 people became immune, and 2 died.
# After 216 generation(s) of COVID, 79761 number of people will be immune.
#
# In generation 217, there were 65 cases, after an increase of 66. 63 people became immune, and 2 died.
# After 217 generation(s) of COVID, 79823 number of people will be immune.
#
# In generation 218, there were 64 cases, after an increase of 65. 62 people became immune, and 2 died.
# After 218 generation(s) of COVID, 79885 number of people will be immune.
#
# In generation 219, there were 63 cases, after an increase of 64. 61 people became immune, and 2 died.
# After 219 generation(s) of COVID, 79946 number of people will be immune.
#
# In generation 220, there were 62 cases, after an increase of 63. 60 people became immune, and 2 died.
# After 220 generation(s) of COVID, 80005 number of people will be immune.
#
# In generation 221, there were 61 cases, after an increase of 62. 59 people became immune, and 2 died.
# After 221 generation(s) of COVID, 80064 number of people will be immune.
#
# In generation 222, there were 60 cases, after an increase of 61. 58 people became immune, and 2 died.
# After 222 generation(s) of COVID, 80122 number of people will be immune.
#
# In generation 223, there were 59 cases, after an increase of 60. 57 people became immune, and 2 died.
# After 223 generation(s) of COVID, 80179 number of people will be immune.
#
# In generation 224, there were 58 cases, after an increase of 59. 56 people became immune, and 2 died.
# After 224 generation(s) of COVID, 80234 number of people will be immune.
#
# In generation 225, there were 57 cases, after an increase of 58. 55 people became immune, and 2 died.
# After 225 generation(s) of COVID, 80289 number of people will be immune.
#
# In generation 226, there were 56 cases, after an increase of 57. 54 people became immune, and 2 died.
# After 226 generation(s) of COVID, 80343 number of people will be immune.
#
# In generation 227, there were 55 cases, after an increase of 56. 53 people became immune, and 2 died.
# After 227 generation(s) of COVID, 80396 number of people will be immune.
#
# In generation 228, there were 54 cases, after an increase of 55. 52 people became immune, and 2 died.
# After 228 generation(s) of COVID, 80448 number of people will be immune.
#
# In generation 229, there were 53 cases, after an increase of 54. 51 people became immune, and 2 died.
# After 229 generation(s) of COVID, 80500 number of people will be immune.
#
# In generation 230, there were 52 cases, after an increase of 53. 50 people became immune, and 2 died.
# After 230 generation(s) of COVID, 80550 number of people will be immune.
#
# In generation 231, there were 51 cases, after an increase of 52. 50 people became immune, and 2 died.
# After 231 generation(s) of COVID, 80600 number of people will be immune.
#
# In generation 232, there were 51 cases, after an increase of 51. 49 people became immune, and 2 died.
# After 232 generation(s) of COVID, 80649 number of people will be immune.
#
# In generation 233, there were 50 cases, after an increase of 51. 48 people became immune, and 2 died.
# After 233 generation(s) of COVID, 80696 number of people will be immune.
#
# In generation 234, there were 49 cases, after an increase of 50. 47 people became immune, and 2 died.
# After 234 generation(s) of COVID, 80744 number of people will be immune.
#
# In generation 235, there were 48 cases, after an increase of 49. 46 people became immune, and 2 died.
# After 235 generation(s) of COVID, 80790 number of people will be immune.
#
# In generation 236, there were 47 cases, after an increase of 48. 46 people became immune, and 2 died.
# After 236 generation(s) of COVID, 80836 number of people will be immune.
#
# In generation 237, there were 46 cases, after an increase of 47. 45 people became immune, and 2 died.
# After 237 generation(s) of COVID, 80880 number of people will be immune.
#
# In generation 238, there were 46 cases, after an increase of 46. 44 people became immune, and 2 died.
# After 238 generation(s) of COVID, 80924 number of people will be immune.
#
# In generation 239, there were 45 cases, after an increase of 46. 43 people became immune, and 2 died.
# After 239 generation(s) of COVID, 80968 number of people will be immune.
#
# In generation 240, there were 44 cases, after an increase of 45. 43 people became immune, and 2 died.
# After 240 generation(s) of COVID, 81010 number of people will be immune.
#
# In generation 241, there were 43 cases, after an increase of 44. 42 people became immune, and 2 died.
# After 241 generation(s) of COVID, 81052 number of people will be immune.
#
# In generation 242, there were 43 cases, after an increase of 43. 41 people became immune, and 2 died.
# After 242 generation(s) of COVID, 81093 number of people will be immune.
#
# In generation 243, there were 42 cases, after an increase of 43. 40 people became immune, and 2 died.
# After 243 generation(s) of COVID, 81134 number of people will be immune.
#
# In generation 244, there were 41 cases, after an increase of 42. 40 people became immune, and 1 died.
# After 244 generation(s) of COVID, 81174 number of people will be immune.
#
# In generation 245, there were 41 cases, after an increase of 41. 39 people became immune, and 1 died.
# After 245 generation(s) of COVID, 81213 number of people will be immune.
#
# In generation 246, there were 40 cases, after an increase of 41. 38 people became immune, and 1 died.
# After 246 generation(s) of COVID, 81251 number of people will be immune.
#
# In generation 247, there were 39 cases, after an increase of 40. 38 people became immune, and 1 died.
# After 247 generation(s) of COVID, 81289 number of people will be immune.
#
# In generation 248, there were 39 cases, after an increase of 39. 37 people became immune, and 1 died.
# After 248 generation(s) of COVID, 81326 number of people will be immune.
#
# In generation 249, there were 38 cases, after an increase of 39. 37 people became immune, and 1 died.
# After 249 generation(s) of COVID, 81363 number of people will be immune.
#
# In generation 250, there were 37 cases, after an increase of 38. 36 people became immune, and 1 died.
# After 250 generation(s) of COVID, 81399 number of people will be immune.
#
# In generation 251, there were 37 cases, after an increase of 37. 35 people became immune, and 1 died.
# After 251 generation(s) of COVID, 81434 number of people will be immune.
#
# In generation 252, there were 36 cases, after an increase of 37. 35 people became immune, and 1 died.
# After 252 generation(s) of COVID, 81469 number of people will be immune.
#
# In generation 253, there were 35 cases, after an increase of 36. 34 people became immune, and 1 died.
# After 253 generation(s) of COVID, 81503 number of people will be immune.
#
# In generation 254, there were 35 cases, after an increase of 35. 34 people became immune, and 1 died.
# After 254 generation(s) of COVID, 81537 number of people will be immune.
#
# In generation 255, there were 34 cases, after an increase of 35. 33 people became immune, and 1 died.
# After 255 generation(s) of COVID, 81570 number of people will be immune.
#
# In generation 256, there were 34 cases, after an increase of 34. 32 people became immune, and 1 died.
# After 256 generation(s) of COVID, 81602 number of people will be immune.
#
# In generation 257, there were 33 cases, after an increase of 34. 32 people became immune, and 1 died.
# After 257 generation(s) of COVID, 81634 number of people will be immune.
#
# In generation 258, there were 33 cases, after an increase of 33. 31 people became immune, and 1 died.
# After 258 generation(s) of COVID, 81665 number of people will be immune.
#
# In generation 259, there were 32 cases, after an increase of 33. 31 people became immune, and 1 died.
# After 259 generation(s) of COVID, 81696 number of people will be immune.
#
# In generation 260, there were 31 cases, after an increase of 32. 30 people became immune, and 1 died.
# After 260 generation(s) of COVID, 81727 number of people will be immune.
#
# In generation 261, there were 31 cases, after an increase of 31. 30 people became immune, and 1 died.
# After 261 generation(s) of COVID, 81756 number of people will be immune.
#
# In generation 262, there were 30 cases, after an increase of 31. 29 people became immune, and 1 died.
# After 262 generation(s) of COVID, 81786 number of people will be immune.
#
# In generation 263, there were 30 cases, after an increase of 30. 29 people became immune, and 1 died.
# After 263 generation(s) of COVID, 81814 number of people will be immune.
#
# In generation 264, there were 29 cases, after an increase of 30. 28 people became immune, and 1 died.
# After 264 generation(s) of COVID, 81843 number of people will be immune.
#
# In generation 265, there were 29 cases, after an increase of 29. 28 people became immune, and 1 died.
# After 265 generation(s) of COVID, 81871 number of people will be immune.
#
# In generation 266, there were 28 cases, after an increase of 29. 27 people became immune, and 1 died.
# After 266 generation(s) of COVID, 81898 number of people will be immune.
#
# In generation 267, there were 28 cases, after an increase of 28. 27 people became immune, and 1 died.
# After 267 generation(s) of COVID, 81925 number of people will be immune.
#
# In generation 268, there were 27 cases, after an increase of 28. 26 people became immune, and 1 died.
# After 268 generation(s) of COVID, 81951 number of people will be immune.
#
# In generation 269, there were 27 cases, after an increase of 27. 26 people became immune, and 1 died.
# After 269 generation(s) of COVID, 81977 number of people will be immune.
#
# In generation 270, there were 26 cases, after an increase of 27. 26 people became immune, and 1 died.
# After 270 generation(s) of COVID, 82003 number of people will be immune.
#
# In generation 271, there were 26 cases, after an increase of 26. 25 people became immune, and 1 died.
# After 271 generation(s) of COVID, 82028 number of people will be immune.
#
# In generation 272, there were 26 cases, after an increase of 26. 25 people became immune, and 1 died.
# After 272 generation(s) of COVID, 82053 number of people will be immune.
#
# In generation 273, there were 25 cases, after an increase of 26. 24 people became immune, and 1 died.
# After 273 generation(s) of COVID, 82077 number of people will be immune.
#
# In generation 274, there were 25 cases, after an increase of 25. 24 people became immune, and 1 died.
# After 274 generation(s) of COVID, 82101 number of people will be immune.
#
# In generation 275, there were 24 cases, after an increase of 25. 23 people became immune, and 1 died.
# After 275 generation(s) of COVID, 82124 number of people will be immune.
#
# In generation 276, there were 24 cases, after an increase of 24. 23 people became immune, and 1 died.
# After 276 generation(s) of COVID, 82147 number of people will be immune.
#
# In generation 277, there were 23 cases, after an increase of 24. 23 people became immune, and 1 died.
# After 277 generation(s) of COVID, 82170 number of people will be immune.
#
# In generation 278, there were 23 cases, after an increase of 23. 22 people became immune, and 1 died.
# After 278 generation(s) of COVID, 82192 number of people will be immune.
#
# In generation 279, there were 23 cases, after an increase of 23. 22 people became immune, and 1 died.
# After 279 generation(s) of COVID, 82214 number of people will be immune.
#
# In generation 280, there were 22 cases, after an increase of 23. 22 people became immune, and 1 died.
# After 280 generation(s) of COVID, 82235 number of people will be immune.
#
# In generation 281, there were 22 cases, after an increase of 22. 21 people became immune, and 1 died.
# After 281 generation(s) of COVID, 82257 number of people will be immune.
#
# In generation 282, there were 22 cases, after an increase of 22. 21 people became immune, and 1 died.
# After 282 generation(s) of COVID, 82277 number of people will be immune.
#
# In generation 283, there were 21 cases, after an increase of 22. 20 people became immune, and 1 died.
# After 283 generation(s) of COVID, 82298 number of people will be immune.
#
# In generation 284, there were 21 cases, after an increase of 21. 20 people became immune, and 1 died.
# After 284 generation(s) of COVID, 82318 number of people will be immune.
#
# In generation 285, there were 20 cases, after an increase of 21. 20 people became immune, and 1 died.
# After 285 generation(s) of COVID, 82338 number of people will be immune.
#
# In generation 286, there were 20 cases, after an increase of 20. 19 people became immune, and 1 died.
# After 286 generation(s) of COVID, 82357 number of people will be immune.
#
# In generation 287, there were 20 cases, after an increase of 20. 19 people became immune, and 1 died.
# After 287 generation(s) of COVID, 82376 number of people will be immune.
#
# In generation 288, there were 19 cases, after an increase of 20. 19 people became immune, and 1 died.
# After 288 generation(s) of COVID, 82395 number of people will be immune.
#
# In generation 289, there were 19 cases, after an increase of 19. 18 people became immune, and 1 died.
# After 289 generation(s) of COVID, 82413 number of people will be immune.
#
# In generation 290, there were 19 cases, after an increase of 19. 18 people became immune, and 1 died.
# After 290 generation(s) of COVID, 82431 number of people will be immune.
#
# In generation 291, there were 18 cases, after an increase of 19. 18 people became immune, and 1 died.
# After 291 generation(s) of COVID, 82449 number of people will be immune.
#
# In generation 292, there were 18 cases, after an increase of 18. 17 people became immune, and 1 died.
# After 292 generation(s) of COVID, 82467 number of people will be immune.
#
# In generation 293, there were 18 cases, after an increase of 18. 17 people became immune, and 1 died.
# After 293 generation(s) of COVID, 82484 number of people will be immune.
#
# In generation 294, there were 18 cases, after an increase of 18. 17 people became immune, and 1 died.
# After 294 generation(s) of COVID, 82501 number of people will be immune.
#
# In generation 295, there were 17 cases, after an increase of 18. 17 people became immune, and 1 died.
# After 295 generation(s) of COVID, 82517 number of people will be immune.
#
# In generation 296, there were 17 cases, after an increase of 17. 16 people became immune, and 1 died.
# After 296 generation(s) of COVID, 82534 number of people will be immune.
#
# In generation 297, there were 17 cases, after an increase of 17. 16 people became immune, and 1 died.
# After 297 generation(s) of COVID, 82550 number of people will be immune.
#
# In generation 298, there were 16 cases, after an increase of 17. 16 people became immune, and 1 died.
# After 298 generation(s) of COVID, 82565 number of people will be immune.
#
# In generation 299, there were 16 cases, after an increase of 16. 15 people became immune, and 1 died.
# After 299 generation(s) of COVID, 82581 number of people will be immune.
#
# In generation 300, there were 16 cases, after an increase of 16. 15 people became immune, and 1 died.
# After 300 generation(s) of COVID, 82596 number of people will be immune.
#
#      Number of Generations  Number of individuals with immunity
# 0                        0                           726.856000
# 1                        1                          1453.602390
# 2                        2                          2180.129610
# 3                        3                          2906.328215
# 4                        4                          3632.088942
# ..                     ...                                  ...
# 296                    296                         82533.539841
# 297                    297                         82549.581018
# 298                    298                         82565.347445
# 299                    299                         82580.843775
# 300                    300                         82596.074584
#
# [301 rows x 2 columns]
# Do you want to save the report to a file? Enter yes or no: yes
# Your file name will be "Gen"
# How would you like your file to be opened? Enter append or write: write
# Confirm editing format with yes or no: yes
# The program is complete.

# %%
#vaccine
def vac_user():
    '''Function to ask the user for the vaccine data and efficiency, and calculate how many people become immune from 
    the vaccine per generation'''  
    vac_name= input("What is the vaccine used?")
    efficiency=input(("What is the efficiency of the vaccine in percentage? "))
    effi_dec=(int(efficiency)/100)
    vac_number=input(("How many people are being vaccinated in your city/town per day? "))
    vacpeople= (int(vac_number))*10
    vac_immunity= (int(vacpeople) *effi_dec) #calculates how many people are becoming immune from the vaccine per generation
    return vac_immunity

# %%
def vac_calculations():
    '''Function to Calculate the number of individuals who gain immunity each generation WITH the inclusion of a vaccine.'''
    B, country, num_gen, daily_rate, population = user()
    vac_immunity=vac_user()
    print('The transmission rate for {} is {}. '.format(country, B)) #informs the user of the information they did not directly imput
    mr= 0.036 #the UK death rate for the corona virus
    zero_death = (daily_rate*mr) #number of individuals that died from the cases the user provided
    zero_immunity = daily_rate - zero_death #number of individuals that gained immunity from the cases the user provides
    length= int(num_gen) + 1 #the number of generations the user provided +1 so that the for program goes through the required amount of times
    gen = range(1, length) #list of all generations
    total_cases = [daily_rate] #a list of all the cases
    vac_total_immunity=[zero_immunity] #list of number of individuals immune each generation
    total_death = [zero_death] #list of number of individuals died each generation
    total_generation= [0] #creates a list of the generation numbers
    ana_list = [zero_immunity] #Sum of total immunity each generation
    for t in gen: #Sequences through all generations
        total_generation.append(t) #adds a number to the total generation
        sum_cases = sum(total_cases) #sums all the number of cases
        if sum_cases>=population: #if total number of cases is larger than the population or there are no more cases
            print('All the population has been processed.')
            R = sum(total_immunity) #number of people who recovered
            I= daily_rate #number of people who are infectious
            portion_infected= I/population #the portion of the individuals who 
            not_in_population = (R + sum(total_death)) #sum of the people no longer suseptible either immune or dead
            S = (population-not_in_population) #removes those who are not suseptible from the population
            portion_S = (S/population) #portion of the people suseptible
            new_cases = portion_S*I*B #number of new cases: portion of individuals in the population who are suseptible * infected (contagious) * transmission rate
            total_cases.append(new_cases) #adds to the total number of cases
            death =  (new_cases)*0.036 #portion of those infected who died
            total_death.append(death) #adds to the total number of deaths
            vimmunity = new_cases + vac_immunity - death  #individuals who are immune that generation
            vac_total_immunity.append(vimmunity) #adds to the total number of immune 
            print('In generation {}, there were {:.0f} cases, after an increase of {:.0f}. {:.0f} people became immune, and {:.0f} died.'.format(t, new_cases, 
                                                                                                                               daily_rate, vimmunity, death))
            print('After {} generation(s) of COVID, {:.0f} number of people will be immune.'.format(t,sum(vac_total_immunity))) 
            daily_rate = new_cases
            print(' ')
            ana_list.append(sum(vac_total_immunity))
           
            break
           
        else:
            R = sum(vac_total_immunity) #number of people who recovered
            I= daily_rate #number of people who are infectious
            portion_infected= I/population #the portion of the individuals who 
            not_in_population = (R + sum(total_death)) #sum of the people no longer suseptible either immune or dead
            S = (population-not_in_population) #removes those who are not suseptible from the population
            portion_S = (S/population) #portion of the people suseptible
            new_cases = portion_S*I*B #number of new cases: portion of individuals in the population who are suseptible * infected (contagious) * transmission rate
            total_cases.append(new_cases) #adds to the total number of cases
            death =  (new_cases)*0.036 #portion of those infected who died
            if death<1:
                total_death.append(1) #adds to the total number of deaths
            else:
                total_death.append(death) #adds to the total number of deaths
            vimmunity = new_cases+ vac_immunity - death #individuals who are immune that generation
            if vimmunity<1:
                    vac_total_immunity.append(1)
            else:
                vac_total_immunity.append(vimmunity) #adds to the total number of immune
            print('In generation {}, there were {:.0f} cases, after an increase of {:.0f}. {:.0f} people became immune, and {:.0f} died.'.format(t, new_cases, 
                                                                                                                               daily_rate, vimmunity, death))
            print('After {} generation(s) of COVID, {:.0f} number of people will be immune.'.format(t,sum(vac_total_immunity))) 
            daily_rate = new_cases
            print(' ')
            ana_list.append(sum(vac_total_immunity))
    
    return total_cases, vac_total_immunity, total_death, total_generation, ana_list

# %%
def vac_table():
    '''Function to display and save to a file the data to be displayed in a graph'''
    total_cases, vac_total_immunity, total_death, total_generation, ana_list = vac_calculations()
    #imports a software libraries needed to complete the program
    import pandas as pd
    import numpy as np
    
    #creates a dictionary of the number of generations vs the sum of the individuals with immunity
    data = {
    'Number of Generations': total_generation,
    'Number of individuals with immunity': ana_list
        }
    
    #prints the information in data to a table
    table = pd.DataFrame(data)
    print(vac_table)
    numpy_array = table.to_numpy()
    print(' ')
    
    decide= input('Do you want to save the report to a file? Enter yes or no: ') #ask if they want to save a file
    if len(decide)==3: #If they input yes
        #currently only input that works is Gen
        print('Your file name will be "Vac"') #user needs to provide a file name
        
        how = input('How would you like your file to be opened? Enter append or write: ') #ask how they want the data to be saved
        confirm_how = input('Confirm editing format with yes or no: ') #ask for confirmation
        if len(confirm_how)==2:#if enter no
            how = input('How would you like your file to be opened? Enter append or write: ') #allowed to enter again
        if len(how)== 5: #write the following into the provided file
            file = open('Vac', 'w')
            np.savetxt('Vac' , numpy_array, fmt = "%d")
            file.close()
            print('The program is complete.')
        else: #append the following into the provided file
            file= open('Vac', 'a')
            np.savetxt('Vac' , numpy_array, fmt = "%d")
            file.close()
            print('The program is complete.')
                    
    else: #if the user doesn't want to save a file.
        print('Okay, the program is complete.')

# %%
def vac_graph():
    '''Function which prints a graph of established data'''
    import pandas as pd
    vac_table()
    tdf= pd.read_csv("Vac",sep=" ") #reads file to collect the data
    tdf.shape
    tdf=pd.read_csv("Vac",sep=" ",names=["Gen time", "Immunity"]) #creates headers for the graph
    tdf.head()
    tdf.plot(x="Gen time",y="Immunity") #plots the data

# %%
vac_graph()
# Out:
# What is the approximate population size of your city/town? 5000000
# What was the daily number of cases in your area? 754
# The assumed generation time is 10 days, how many Generation do you want to go through: 600
# Would you like the transmission rate to be a high or low estimate? high
# What country in the UK is your town or city? Scotland
# What is the vaccine used?Phizer
# What is the efficiency of the vaccine in percentage 95
# How many people are being vaccinated in your city/town per day?100
# The transmission rate for Scotland is 1.0.
# In generation 1, there were 754 cases, after an increase of 754. 1677 people became immune, and 27 died.
# After 1 generation(s) of COVID, 2404 number of people will be immune.
#
# In generation 2, there were 754 cases, after an increase of 754. 1676 people became immune, and 27 died.
# After 2 generation(s) of COVID, 4080 number of people will be immune.
#
# In generation 3, there were 753 cases, after an increase of 754. 1676 people became immune, and 27 died.
# After 3 generation(s) of COVID, 5756 number of people will be immune.
#
# In generation 4, there were 752 cases, after an increase of 753. 1675 people became immune, and 27 died.
# After 4 generation(s) of COVID, 7431 number of people will be immune.
#
# In generation 5, there were 751 cases, after an increase of 752. 1674 people became immune, and 27 died.
# After 5 generation(s) of COVID, 9105 number of people will be immune.
#
# In generation 6, there were 749 cases, after an increase of 751. 1672 people became immune, and 27 died.
# After 6 generation(s) of COVID, 10777 number of people will be immune.
#
# In generation 7, there were 748 cases, after an increase of 749. 1671 people became immune, and 27 died.
# After 7 generation(s) of COVID, 12448 number of people will be immune.
#
# In generation 8, there were 746 cases, after an increase of 748. 1669 people became immune, and 27 died.
# After 8 generation(s) of COVID, 14117 number of people will be immune.
#
# In generation 9, there were 744 cases, after an increase of 746. 1667 people became immune, and 27 died.
# After 9 generation(s) of COVID, 15784 number of people will be immune.
#
# In generation 10, there were 741 cases, after an increase of 744. 1665 people became immune, and 27 died.
# After 10 generation(s) of COVID, 17449 number of people will be immune.
#
# In generation 11, there were 739 cases, after an increase of 741. 1662 people became immune, and 27 died.
# After 11 generation(s) of COVID, 19111 number of people will be immune.
#
# In generation 12, there were 736 cases, after an increase of 739. 1659 people became immune, and 26 died.
# After 12 generation(s) of COVID, 20770 number of people will be immune.
#
# In generation 13, there were 733 cases, after an increase of 736. 1656 people became immune, and 26 died.
# After 13 generation(s) of COVID, 22427 number of people will be immune.
#
# In generation 14, there were 729 cases, after an increase of 733. 1653 people became immune, and 26 died.
# After 14 generation(s) of COVID, 24080 number of people will be immune.
#
# In generation 15, there were 726 cases, after an increase of 729. 1650 people became immune, and 26 died.
# After 15 generation(s) of COVID, 25730 number of people will be immune.
#
# In generation 16, there were 722 cases, after an increase of 726. 1646 people became immune, and 26 died.
# After 16 generation(s) of COVID, 27376 number of people will be immune.
#
# In generation 17, there were 718 cases, after an increase of 722. 1642 people became immune, and 26 died.
# After 17 generation(s) of COVID, 29018 number of people will be immune.
#
# In generation 18, there were 714 cases, after an increase of 718. 1638 people became immune, and 26 died.
# After 18 generation(s) of COVID, 30656 number of people will be immune.
#
# In generation 19, there were 709 cases, after an increase of 714. 1634 people became immune, and 26 died.
# After 19 generation(s) of COVID, 32290 number of people will be immune.
#
# In generation 20, there were 705 cases, after an increase of 709. 1629 people became immune, and 25 died.
# After 20 generation(s) of COVID, 33919 number of people will be immune.
#
# In generation 21, there were 700 cases, after an increase of 705. 1625 people became immune, and 25 died.
# After 21 generation(s) of COVID, 35544 number of people will be immune.
#
# In generation 22, there were 695 cases, after an increase of 700. 1620 people became immune, and 25 died.
# After 22 generation(s) of COVID, 37164 number of people will be immune.
#
# In generation 23, there were 690 cases, after an increase of 695. 1615 people became immune, and 25 died.
# After 23 generation(s) of COVID, 38779 number of people will be immune.
#
# In generation 24, there were 684 cases, after an increase of 690. 1609 people became immune, and 25 died.
# After 24 generation(s) of COVID, 40388 number of people will be immune.
#
# In generation 25, there were 679 cases, after an increase of 684. 1604 people became immune, and 24 died.
# After 25 generation(s) of COVID, 41992 number of people will be immune.
#
# In generation 26, there were 673 cases, after an increase of 679. 1598 people became immune, and 24 died.
# After 26 generation(s) of COVID, 43591 number of people will be immune.
#
# In generation 27, there were 667 cases, after an increase of 673. 1593 people became immune, and 24 died.
# After 27 generation(s) of COVID, 45183 number of people will be immune.
#
# In generation 28, there were 661 cases, after an increase of 667. 1587 people became immune, and 24 died.
# After 28 generation(s) of COVID, 46770 number of people will be immune.
#
# In generation 29, there were 654 cases, after an increase of 661. 1581 people became immune, and 24 died.
# After 29 generation(s) of COVID, 48351 number of people will be immune.
#
# In generation 30, there were 648 cases, after an increase of 654. 1575 people became immune, and 23 died.
# After 30 generation(s) of COVID, 49926 number of people will be immune.
#
# In generation 31, there were 641 cases, after an increase of 648. 1568 people became immune, and 23 died.
# After 31 generation(s) of COVID, 51494 number of people will be immune.
#
# In generation 32, there were 635 cases, after an increase of 641. 1562 people became immune, and 23 died.
# After 32 generation(s) of COVID, 53056 number of people will be immune.
#
# In generation 33, there were 628 cases, after an increase of 635. 1555 people became immune, and 23 died.
# After 33 generation(s) of COVID, 54611 number of people will be immune.
#
# In generation 34, there were 621 cases, after an increase of 628. 1548 people became immune, and 22 died.
# After 34 generation(s) of COVID, 56159 number of people will be immune.
#
# In generation 35, there were 614 cases, after an increase of 621. 1542 people became immune, and 22 died.
# After 35 generation(s) of COVID, 57701 number of people will be immune.
#
# In generation 36, there were 607 cases, after an increase of 614. 1535 people became immune, and 22 died.
# After 36 generation(s) of COVID, 59236 number of people will be immune.
#
# In generation 37, there were 599 cases, after an increase of 607. 1528 people became immune, and 22 died.
# After 37 generation(s) of COVID, 60763 number of people will be immune.
#
# In generation 38, there were 592 cases, after an increase of 599. 1521 people became immune, and 21 died.
# After 38 generation(s) of COVID, 62284 number of people will be immune.
#
# In generation 39, there were 584 cases, after an increase of 592. 1513 people became immune, and 21 died.
# After 39 generation(s) of COVID, 63797 number of people will be immune.
#
# In generation 40, there were 577 cases, after an increase of 584. 1506 people became immune, and 21 died.
# After 40 generation(s) of COVID, 65303 number of people will be immune.
#
# In generation 41, there were 569 cases, after an increase of 577. 1499 people became immune, and 20 died.
# After 41 generation(s) of COVID, 66802 number of people will be immune.
#
# In generation 42, there were 561 cases, after an increase of 569. 1491 people became immune, and 20 died.
# After 42 generation(s) of COVID, 68293 number of people will be immune.
#
# In generation 43, there were 554 cases, after an increase of 561. 1484 people became immune, and 20 died.
# After 43 generation(s) of COVID, 69777 number of people will be immune.
#
# In generation 44, there were 546 cases, after an increase of 554. 1476 people became immune, and 20 died.
# After 44 generation(s) of COVID, 71253 number of people will be immune.
#
# In generation 45, there were 538 cases, after an increase of 546. 1469 people became immune, and 19 died.
# After 45 generation(s) of COVID, 72722 number of people will be immune.
#
# In generation 46, there were 530 cases, after an increase of 538. 1461 people became immune, and 19 died.
# After 46 generation(s) of COVID, 74182 number of people will be immune.
#
# In generation 47, there were 522 cases, after an increase of 530. 1453 people became immune, and 19 died.
# After 47 generation(s) of COVID, 75636 number of people will be immune.
#
# In generation 48, there were 514 cases, after an increase of 522. 1445 people became immune, and 19 died.
# After 48 generation(s) of COVID, 77081 number of people will be immune.
#
# In generation 49, there were 506 cases, after an increase of 514. 1438 people became immune, and 18 died.
# After 49 generation(s) of COVID, 78519 number of people will be immune.
#
# In generation 50, there were 498 cases, after an increase of 506. 1430 people became immune, and 18 died.
# After 50 generation(s) of COVID, 79949 number of people will be immune.
#
# In generation 51, there were 490 cases, after an increase of 498. 1422 people became immune, and 18 died.
# After 51 generation(s) of COVID, 81371 number of people will be immune.
#
# In generation 52, there were 482 cases, after an increase of 490. 1414 people became immune, and 17 died.
# After 52 generation(s) of COVID, 82785 number of people will be immune.
#
# In generation 53, there were 474 cases, after an increase of 482. 1407 people became immune, and 17 died.
# After 53 generation(s) of COVID, 84192 number of people will be immune.
#
# In generation 54, there were 465 cases, after an increase of 474. 1399 people became immune, and 17 died.
# After 54 generation(s) of COVID, 85590 number of people will be immune.
#
# In generation 55, there were 457 cases, after an increase of 465. 1391 people became immune, and 16 died.
# After 55 generation(s) of COVID, 86981 number of people will be immune.
#
# In generation 56, there were 449 cases, after an increase of 457. 1383 people became immune, and 16 died.
# After 56 generation(s) of COVID, 88364 number of people will be immune.
#
# In generation 57, there were 441 cases, after an increase of 449. 1375 people became immune, and 16 died.
# After 57 generation(s) of COVID, 89740 number of people will be immune.
#
# In generation 58, there were 433 cases, after an increase of 441. 1368 people became immune, and 16 died.
# After 58 generation(s) of COVID, 91107 number of people will be immune.
#
# In generation 59, there were 425 cases, after an increase of 433. 1360 people became immune, and 15 died.
# After 59 generation(s) of COVID, 92467 number of people will be immune.
#
# In generation 60, there were 417 cases, after an increase of 425. 1352 people became immune, and 15 died.
# After 60 generation(s) of COVID, 93820 number of people will be immune.
#
# In generation 61, there were 409 cases, after an increase of 417. 1345 people became immune, and 15 died.
# After 61 generation(s) of COVID, 95164 number of people will be immune.
#
# In generation 62, there were 401 cases, after an increase of 409. 1337 people became immune, and 14 died.
# After 62 generation(s) of COVID, 96501 number of people will be immune.
#
# In generation 63, there were 394 cases, after an increase of 401. 1329 people became immune, and 14 died.
# After 63 generation(s) of COVID, 97830 number of people will be immune.
#
# In generation 64, there were 386 cases, after an increase of 394. 1322 people became immune, and 14 died.
# After 64 generation(s) of COVID, 99152 number of people will be immune.
#
# In generation 65, there were 378 cases, after an increase of 386. 1314 people became immune, and 14 died.
# After 65 generation(s) of COVID, 100467 number of people will be immune.
#
# In generation 66, there were 370 cases, after an increase of 378. 1307 people became immune, and 13 died.
# After 66 generation(s) of COVID, 101774 number of people will be immune.
#
# In generation 67, there were 363 cases, after an increase of 370. 1300 people became immune, and 13 died.
# After 67 generation(s) of COVID, 103073 number of people will be immune.
#
# In generation 68, there were 355 cases, after an increase of 363. 1292 people became immune, and 13 died.
# After 68 generation(s) of COVID, 104365 number of people will be immune.
#
# In generation 69, there were 348 cases, after an increase of 355. 1285 people became immune, and 13 died.
# After 69 generation(s) of COVID, 105650 number of people will be immune.
#
# In generation 70, there were 340 cases, after an increase of 348. 1278 people became immune, and 12 died.
# After 70 generation(s) of COVID, 106928 number of people will be immune.
#
# In generation 71, there were 333 cases, after an increase of 340. 1271 people became immune, and 12 died.
# After 71 generation(s) of COVID, 108199 number of people will be immune.
#
# In generation 72, there were 325 cases, after an increase of 333. 1264 people became immune, and 12 died.
# After 72 generation(s) of COVID, 109463 number of people will be immune.
#
# In generation 73, there were 318 cases, after an increase of 325. 1257 people became immune, and 11 died.
# After 73 generation(s) of COVID, 110719 number of people will be immune.
#
# In generation 74, there were 311 cases, after an increase of 318. 1250 people became immune, and 11 died.
# After 74 generation(s) of COVID, 111969 number of people will be immune.
#
# In generation 75, there were 304 cases, after an increase of 311. 1243 people became immune, and 11 died.
# After 75 generation(s) of COVID, 113212 number of people will be immune.
#
# In generation 76, there were 297 cases, after an increase of 304. 1236 people became immune, and 11 died.
# After 76 generation(s) of COVID, 114448 number of people will be immune.
#
# In generation 77, there were 290 cases, after an increase of 297. 1230 people became immune, and 10 died.
# After 77 generation(s) of COVID, 115678 number of people will be immune.
#
# In generation 78, there were 283 cases, after an increase of 290. 1223 people became immune, and 10 died.
# After 78 generation(s) of COVID, 116901 number of people will be immune.
#
# In generation 79, there were 277 cases, after an increase of 283. 1217 people became immune, and 10 died.
# After 79 generation(s) of COVID, 118118 number of people will be immune.
#
# In generation 80, there were 270 cases, after an increase of 277. 1210 people became immune, and 10 died.
# After 80 generation(s) of COVID, 119328 number of people will be immune.
#
# In generation 81, there were 263 cases, after an increase of 270. 1204 people became immune, and 9 died.
# After 81 generation(s) of COVID, 120532 number of people will be immune.
#
# In generation 82, there were 257 cases, after an increase of 263. 1198 people became immune, and 9 died.
# After 82 generation(s) of COVID, 121730 number of people will be immune.
#
# In generation 83, there were 251 cases, after an increase of 257. 1192 people became immune, and 9 died.
# After 83 generation(s) of COVID, 122921 number of people will be immune.
#
# In generation 84, there were 244 cases, after an increase of 251. 1186 people became immune, and 9 died.
# After 84 generation(s) of COVID, 124107 number of people will be immune.
#
# In generation 85, there were 238 cases, after an increase of 244. 1180 people became immune, and 9 died.
# After 85 generation(s) of COVID, 125286 number of people will be immune.
#
# In generation 86, there were 232 cases, after an increase of 238. 1174 people became immune, and 8 died.
# After 86 generation(s) of COVID, 126460 number of people will be immune.
#
# In generation 87, there were 226 cases, after an increase of 232. 1168 people became immune, and 8 died.
# After 87 generation(s) of COVID, 127628 number of people will be immune.
#
# In generation 88, there were 220 cases, after an increase of 226. 1162 people became immune, and 8 died.
# After 88 generation(s) of COVID, 128791 number of people will be immune.
#
# In generation 89, there were 215 cases, after an increase of 220. 1157 people became immune, and 8 died.
# After 89 generation(s) of COVID, 129948 number of people will be immune.
#
# In generation 90, there were 209 cases, after an increase of 215. 1151 people became immune, and 8 died.
# After 90 generation(s) of COVID, 131099 number of people will be immune.
#
# In generation 91, there were 203 cases, after an increase of 209. 1146 people became immune, and 7 died.
# After 91 generation(s) of COVID, 132245 number of people will be immune.
#
# In generation 92, there were 198 cases, after an increase of 203. 1141 people became immune, and 7 died.
# After 92 generation(s) of COVID, 133386 number of people will be immune.
#
# In generation 93, there were 193 cases, after an increase of 198. 1136 people became immune, and 7 died.
# After 93 generation(s) of COVID, 134522 number of people will be immune.
#
# In generation 94, there were 187 cases, after an increase of 193. 1131 people became immune, and 7 died.
# After 94 generation(s) of COVID, 135653 number of people will be immune.
#
# In generation 95, there were 182 cases, after an increase of 187. 1126 people became immune, and 7 died.
# After 95 generation(s) of COVID, 136778 number of people will be immune.
#
# In generation 96, there were 177 cases, after an increase of 182. 1121 people became immune, and 6 died.
# After 96 generation(s) of COVID, 137899 number of people will be immune.
#
# In generation 97, there were 172 cases, after an increase of 177. 1116 people became immune, and 6 died.
# After 97 generation(s) of COVID, 139015 number of people will be immune.
#
# In generation 98, there were 167 cases, after an increase of 172. 1111 people became immune, and 6 died.
# After 98 generation(s) of COVID, 140127 number of people will be immune.
#
# In generation 99, there were 163 cases, after an increase of 167. 1107 people became immune, and 6 died.
# After 99 generation(s) of COVID, 141233 number of people will be immune.
#
# In generation 100, there were 158 cases, after an increase of 163. 1102 people became immune, and 6 died.
# After 100 generation(s) of COVID, 142336 number of people will be immune.
#
# In generation 101, there were 153 cases, after an increase of 158. 1098 people became immune, and 6 died.
# After 101 generation(s) of COVID, 143434 number of people will be immune.
#
# In generation 102, there were 149 cases, after an increase of 153. 1094 people became immune, and 5 died.
# After 102 generation(s) of COVID, 144527 number of people will be immune.
#
# In generation 103, there were 145 cases, after an increase of 149. 1089 people became immune, and 5 died.
# After 103 generation(s) of COVID, 145617 number of people will be immune.
#
# In generation 104, there were 140 cases, after an increase of 145. 1085 people became immune, and 5 died.
# After 104 generation(s) of COVID, 146702 number of people will be immune.
#
# In generation 105, there were 136 cases, after an increase of 140. 1081 people became immune, and 5 died.
# After 105 generation(s) of COVID, 147783 number of people will be immune.
#
# In generation 106, there were 132 cases, after an increase of 136. 1077 people became immune, and 5 died.
# After 106 generation(s) of COVID, 148861 number of people will be immune.
#
# In generation 107, there were 128 cases, after an increase of 132. 1074 people became immune, and 5 died.
# After 107 generation(s) of COVID, 149934 number of people will be immune.
#
# In generation 108, there were 124 cases, after an increase of 128. 1070 people became immune, and 4 died.
# After 108 generation(s) of COVID, 151004 number of people will be immune.
#
# In generation 109, there were 120 cases, after an increase of 124. 1066 people became immune, and 4 died.
# After 109 generation(s) of COVID, 152070 number of people will be immune.
#
# In generation 110, there were 117 cases, after an increase of 120. 1063 people became immune, and 4 died.
# After 110 generation(s) of COVID, 153133 number of people will be immune.
#
# In generation 111, there were 113 cases, after an increase of 117. 1059 people became immune, and 4 died.
# After 111 generation(s) of COVID, 154192 number of people will be immune.
#
# In generation 112, there were 110 cases, after an increase of 113. 1056 people became immune, and 4 died.
# After 112 generation(s) of COVID, 155247 number of people will be immune.
#
# In generation 113, there were 106 cases, after an increase of 110. 1052 people became immune, and 4 died.
# After 113 generation(s) of COVID, 156300 number of people will be immune.
#
# In generation 114, there were 103 cases, after an increase of 106. 1049 people became immune, and 4 died.
# After 114 generation(s) of COVID, 157349 number of people will be immune.
#
# In generation 115, there were 100 cases, after an increase of 103. 1046 people became immune, and 4 died.
# After 115 generation(s) of COVID, 158395 number of people will be immune.
#
# In generation 116, there were 96 cases, after an increase of 100. 1043 people became immune, and 3 died.
# After 116 generation(s) of COVID, 159438 number of people will be immune.
#
# In generation 117, there were 93 cases, after an increase of 96. 1040 people became immune, and 3 died.
# After 117 generation(s) of COVID, 160477 number of people will be immune.
#
# In generation 118, there were 90 cases, after an increase of 93. 1037 people became immune, and 3 died.
# After 118 generation(s) of COVID, 161514 number of people will be immune.
#
# In generation 119, there were 87 cases, after an increase of 90. 1034 people became immune, and 3 died.
# After 119 generation(s) of COVID, 162548 number of people will be immune.
#
# In generation 120, there were 84 cases, after an increase of 87. 1031 people became immune, and 3 died.
# After 120 generation(s) of COVID, 163580 number of people will be immune.
#
# In generation 121, there were 82 cases, after an increase of 84. 1029 people became immune, and 3 died.
# After 121 generation(s) of COVID, 164608 number of people will be immune.
#
# In generation 122, there were 79 cases, after an increase of 82. 1026 people became immune, and 3 died.
# After 122 generation(s) of COVID, 165634 number of people will be immune.
#
# In generation 123, there were 76 cases, after an increase of 79. 1023 people became immune, and 3 died.
# After 123 generation(s) of COVID, 166658 number of people will be immune.
#
# In generation 124, there were 74 cases, after an increase of 76. 1021 people became immune, and 3 died.
# After 124 generation(s) of COVID, 167679 number of people will be immune.
#
# In generation 125, there were 71 cases, after an increase of 74. 1019 people became immune, and 3 died.
# After 125 generation(s) of COVID, 168698 number of people will be immune.
#
# In generation 126, there were 69 cases, after an increase of 71. 1016 people became immune, and 2 died.
# After 126 generation(s) of COVID, 169714 number of people will be immune.
#
# In generation 127, there were 66 cases, after an increase of 69. 1014 people became immune, and 2 died.
# After 127 generation(s) of COVID, 170728 number of people will be immune.
#
# In generation 128, there were 64 cases, after an increase of 66. 1012 people became immune, and 2 died.
# After 128 generation(s) of COVID, 171740 number of people will be immune.
#
# In generation 129, there were 62 cases, after an increase of 64. 1010 people became immune, and 2 died.
# After 129 generation(s) of COVID, 172749 number of people will be immune.
#
# In generation 130, there were 60 cases, after an increase of 62. 1008 people became immune, and 2 died.
# After 130 generation(s) of COVID, 173757 number of people will be immune.
#
# In generation 131, there were 58 cases, after an increase of 60. 1006 people became immune, and 2 died.
# After 131 generation(s) of COVID, 174762 number of people will be immune.
#
# In generation 132, there were 56 cases, after an increase of 58. 1004 people became immune, and 2 died.
# After 132 generation(s) of COVID, 175766 number of people will be immune.
#
# In generation 133, there were 54 cases, after an increase of 56. 1002 people became immune, and 2 died.
# After 133 generation(s) of COVID, 176768 number of people will be immune.
#
# In generation 134, there were 52 cases, after an increase of 54. 1000 people became immune, and 2 died.
# After 134 generation(s) of COVID, 177767 number of people will be immune.
#
# In generation 135, there were 50 cases, after an increase of 52. 998 people became immune, and 2 died.
# After 135 generation(s) of COVID, 178765 number of people will be immune.
#
# In generation 136, there were 48 cases, after an increase of 50. 996 people became immune, and 2 died.
# After 136 generation(s) of COVID, 179762 number of people will be immune.
#
# In generation 137, there were 46 cases, after an increase of 48. 995 people became immune, and 2 died.
# After 137 generation(s) of COVID, 180756 number of people will be immune.
#
# In generation 138, there were 45 cases, after an increase of 46. 993 people became immune, and 2 died.
# After 138 generation(s) of COVID, 181749 number of people will be immune.
#
# In generation 139, there were 43 cases, after an increase of 45. 991 people became immune, and 2 died.
# After 139 generation(s) of COVID, 182741 number of people will be immune.
#
# In generation 140, there were 41 cases, after an increase of 43. 990 people became immune, and 1 died.
# After 140 generation(s) of COVID, 183731 number of people will be immune.
#
# In generation 141, there were 40 cases, after an increase of 41. 988 people became immune, and 1 died.
# After 141 generation(s) of COVID, 184719 number of people will be immune.
#
# In generation 142, there were 38 cases, after an increase of 40. 987 people became immune, and 1 died.
# After 142 generation(s) of COVID, 185706 number of people will be immune.
#
# In generation 143, there were 37 cases, after an increase of 38. 986 people became immune, and 1 died.
# After 143 generation(s) of COVID, 186692 number of people will be immune.
#
# In generation 144, there were 36 cases, after an increase of 37. 984 people became immune, and 1 died.
# After 144 generation(s) of COVID, 187676 number of people will be immune.
#
# In generation 145, there were 34 cases, after an increase of 36. 983 people became immune, and 1 died.
# After 145 generation(s) of COVID, 188659 number of people will be immune.
#
# In generation 146, there were 33 cases, after an increase of 34. 982 people became immune, and 1 died.
# After 146 generation(s) of COVID, 189640 number of people will be immune.
#
# In generation 147, there were 32 cases, after an increase of 33. 980 people became immune, and 1 died.
# After 147 generation(s) of COVID, 190621 number of people will be immune.
#
# In generation 148, there were 30 cases, after an increase of 32. 979 people became immune, and 1 died.
# After 148 generation(s) of COVID, 191600 number of people will be immune.
#
# In generation 149, there were 29 cases, after an increase of 30. 978 people became immune, and 1 died.
# After 149 generation(s) of COVID, 192578 number of people will be immune.
#
# In generation 150, there were 28 cases, after an increase of 29. 977 people became immune, and 1 died.
# After 150 generation(s) of COVID, 193555 number of people will be immune.
#
# In generation 151, there were 27 cases, after an increase of 28. 976 people became immune, and 1 died.
# After 151 generation(s) of COVID, 194531 number of people will be immune.
#
# In generation 152, there were 26 cases, after an increase of 27. 975 people became immune, and 1 died.
# After 152 generation(s) of COVID, 195506 number of people will be immune.
#
# In generation 153, there were 25 cases, after an increase of 26. 974 people became immune, and 1 died.
# After 153 generation(s) of COVID, 196480 number of people will be immune.
#
# In generation 154, there were 24 cases, after an increase of 25. 973 people became immune, and 1 died.
# After 154 generation(s) of COVID, 197453 number of people will be immune.
#
# In generation 155, there were 23 cases, after an increase of 24. 972 people became immune, and 1 died.
# After 155 generation(s) of COVID, 198426 number of people will be immune.
#
# In generation 156, there were 22 cases, after an increase of 23. 971 people became immune, and 1 died.
# After 156 generation(s) of COVID, 199397 number of people will be immune.
#
# In generation 157, there were 21 cases, after an increase of 22. 970 people became immune, and 1 died.
# After 157 generation(s) of COVID, 200367 number of people will be immune.
#
# In generation 158, there were 20 cases, after an increase of 21. 970 people became immune, and 1 died.
# After 158 generation(s) of COVID, 201337 number of people will be immune.
#
# In generation 159, there were 19 cases, after an increase of 20. 969 people became immune, and 1 died.
# After 159 generation(s) of COVID, 202306 number of people will be immune.
#
# In generation 160, there were 19 cases, after an increase of 19. 968 people became immune, and 1 died.
# After 160 generation(s) of COVID, 203274 number of people will be immune.
#
# In generation 161, there were 18 cases, after an increase of 19. 967 people became immune, and 1 died.
# After 161 generation(s) of COVID, 204241 number of people will be immune.
#
# In generation 162, there were 17 cases, after an increase of 18. 967 people became immune, and 1 died.
# After 162 generation(s) of COVID, 205207 number of people will be immune.
#
# In generation 163, there were 16 cases, after an increase of 17. 966 people became immune, and 1 died.
# After 163 generation(s) of COVID, 206173 number of people will be immune.
#
# In generation 164, there were 16 cases, after an increase of 16. 965 people became immune, and 1 died.
# After 164 generation(s) of COVID, 207138 number of people will be immune.
#
# In generation 165, there were 15 cases, after an increase of 16. 965 people became immune, and 1 died.
# After 165 generation(s) of COVID, 208103 number of people will be immune.
#
# In generation 166, there were 14 cases, after an increase of 15. 964 people became immune, and 1 died.
# After 166 generation(s) of COVID, 209067 number of people will be immune.
#
# In generation 167, there were 14 cases, after an increase of 14. 963 people became immune, and 0 died.
# After 167 generation(s) of COVID, 210030 number of people will be immune.
#
# In generation 168, there were 13 cases, after an increase of 14. 963 people became immune, and 0 died.
# After 168 generation(s) of COVID, 210993 number of people will be immune.
#
# In generation 169, there were 13 cases, after an increase of 13. 962 people became immune, and 0 died.
# After 169 generation(s) of COVID, 211955 number of people will be immune.
#
# In generation 170, there were 12 cases, after an increase of 13. 962 people became immune, and 0 died.
# After 170 generation(s) of COVID, 212917 number of people will be immune.
#
# In generation 171, there were 12 cases, after an increase of 12. 961 people became immune, and 0 died.
# After 171 generation(s) of COVID, 213878 number of people will be immune.
#
# In generation 172, there were 11 cases, after an increase of 12. 961 people became immune, and 0 died.
# After 172 generation(s) of COVID, 214839 number of people will be immune.
#
# In generation 173, there were 11 cases, after an increase of 11. 960 people became immune, and 0 died.
# After 173 generation(s) of COVID, 215799 number of people will be immune.
#
# In generation 174, there were 10 cases, after an increase of 11. 960 people became immune, and 0 died.
# After 174 generation(s) of COVID, 216759 number of people will be immune.
#
# In generation 175, there were 10 cases, after an increase of 10. 959 people became immune, and 0 died.
# After 175 generation(s) of COVID, 217719 number of people will be immune.
#
# In generation 176, there were 9 cases, after an increase of 10. 959 people became immune, and 0 died.
# After 176 generation(s) of COVID, 218678 number of people will be immune.
#
# In generation 177, there were 9 cases, after an increase of 9. 959 people became immune, and 0 died.
# After 177 generation(s) of COVID, 219636 number of people will be immune.
#
# In generation 178, there were 9 cases, after an increase of 9. 958 people became immune, and 0 died.
# After 178 generation(s) of COVID, 220594 number of people will be immune.
#
# In generation 179, there were 8 cases, after an increase of 9. 958 people became immune, and 0 died.
# After 179 generation(s) of COVID, 221552 number of people will be immune.
#
# In generation 180, there were 8 cases, after an increase of 8. 957 people became immune, and 0 died.
# After 180 generation(s) of COVID, 222510 number of people will be immune.
#
# In generation 181, there were 7 cases, after an increase of 8. 957 people became immune, and 0 died.
# After 181 generation(s) of COVID, 223467 number of people will be immune.
#
# In generation 182, there were 7 cases, after an increase of 7. 957 people became immune, and 0 died.
# After 182 generation(s) of COVID, 224424 number of people will be immune.
#
# In generation 183, there were 7 cases, after an increase of 7. 957 people became immune, and 0 died.
# After 183 generation(s) of COVID, 225380 number of people will be immune.
#
# In generation 184, there were 6 cases, after an increase of 7. 956 people became immune, and 0 died.
# After 184 generation(s) of COVID, 226336 number of people will be immune.
#
# In generation 185, there were 6 cases, after an increase of 6. 956 people became immune, and 0 died.
# After 185 generation(s) of COVID, 227292 number of people will be immune.
#
# In generation 186, there were 6 cases, after an increase of 6. 956 people became immune, and 0 died.
# After 186 generation(s) of COVID, 228248 number of people will be immune.
#
# In generation 187, there were 6 cases, after an increase of 6. 955 people became immune, and 0 died.
# After 187 generation(s) of COVID, 229203 number of people will be immune.
#
# In generation 188, there were 5 cases, after an increase of 6. 955 people became immune, and 0 died.
# After 188 generation(s) of COVID, 230159 number of people will be immune.
#
# In generation 189, there were 5 cases, after an increase of 5. 955 people became immune, and 0 died.
# After 189 generation(s) of COVID, 231114 number of people will be immune.
#
# In generation 190, there were 5 cases, after an increase of 5. 955 people became immune, and 0 died.
# After 190 generation(s) of COVID, 232068 number of people will be immune.
#
# In generation 191, there were 5 cases, after an increase of 5. 954 people became immune, and 0 died.
# After 191 generation(s) of COVID, 233023 number of people will be immune.
#
# In generation 192, there were 4 cases, after an increase of 5. 954 people became immune, and 0 died.
# After 192 generation(s) of COVID, 233977 number of people will be immune.
#
# In generation 193, there were 4 cases, after an increase of 4. 954 people became immune, and 0 died.
# After 193 generation(s) of COVID, 234931 number of people will be immune.
#
# In generation 194, there were 4 cases, after an increase of 4. 954 people became immune, and 0 died.
# After 194 generation(s) of COVID, 235885 number of people will be immune.
#
# In generation 195, there were 4 cases, after an increase of 4. 954 people became immune, and 0 died.
# After 195 generation(s) of COVID, 236839 number of people will be immune.
#
# In generation 196, there were 4 cases, after an increase of 4. 954 people became immune, and 0 died.
# After 196 generation(s) of COVID, 237792 number of people will be immune.
#
# In generation 197, there were 3 cases, after an increase of 4. 953 people became immune, and 0 died.
# After 197 generation(s) of COVID, 238745 number of people will be immune.
#
# In generation 198, there were 3 cases, after an increase of 3. 953 people became immune, and 0 died.
# After 198 generation(s) of COVID, 239699 number of people will be immune.
#
# In generation 199, there were 3 cases, after an increase of 3. 953 people became immune, and 0 died.
# After 199 generation(s) of COVID, 240652 number of people will be immune.
#
# In generation 200, there were 3 cases, after an increase of 3. 953 people became immune, and 0 died.
# After 200 generation(s) of COVID, 241605 number of people will be immune.
#
# In generation 201, there were 3 cases, after an increase of 3. 953 people became immune, and 0 died.
# After 201 generation(s) of COVID, 242557 number of people will be immune.
#
# In generation 202, there were 3 cases, after an increase of 3. 953 people became immune, and 0 died.
# After 202 generation(s) of COVID, 243510 number of people will be immune.
#
# In generation 203, there were 3 cases, after an increase of 3. 952 people became immune, and 0 died.
# After 203 generation(s) of COVID, 244462 number of people will be immune.
#
# In generation 204, there were 2 cases, after an increase of 3. 952 people became immune, and 0 died.
# After 204 generation(s) of COVID, 245415 number of people will be immune.
#
# In generation 205, there were 2 cases, after an increase of 2. 952 people became immune, and 0 died.
# After 205 generation(s) of COVID, 246367 number of people will be immune.
#
# In generation 206, there were 2 cases, after an increase of 2. 952 people became immune, and 0 died.
# After 206 generation(s) of COVID, 247319 number of people will be immune.
#
# In generation 207, there were 2 cases, after an increase of 2. 952 people became immune, and 0 died.
# After 207 generation(s) of COVID, 248271 number of people will be immune.
#
# In generation 208, there were 2 cases, after an increase of 2. 952 people became immune, and 0 died.
# After 208 generation(s) of COVID, 249223 number of people will be immune.
#
# In generation 209, there were 2 cases, after an increase of 2. 952 people became immune, and 0 died.
# After 209 generation(s) of COVID, 250175 number of people will be immune.
#
# In generation 210, there were 2 cases, after an increase of 2. 952 people became immune, and 0 died.
# After 210 generation(s) of COVID, 251127 number of people will be immune.
#
# In generation 211, there were 2 cases, after an increase of 2. 952 people became immune, and 0 died.
# After 211 generation(s) of COVID, 252078 number of people will be immune.
#
# In generation 212, there were 2 cases, after an increase of 2. 952 people became immune, and 0 died.
# After 212 generation(s) of COVID, 253030 number of people will be immune.
#
# In generation 213, there were 2 cases, after an increase of 2. 951 people became immune, and 0 died.
# After 213 generation(s) of COVID, 253981 number of people will be immune.
#
# In generation 214, there were 1 cases, after an increase of 2. 951 people became immune, and 0 died.
# After 214 generation(s) of COVID, 254933 number of people will be immune.
#
# In generation 215, there were 1 cases, after an increase of 1. 951 people became immune, and 0 died.
# After 215 generation(s) of COVID, 255884 number of people will be immune.
#
# In generation 216, there were 1 cases, after an increase of 1. 951 people became immune, and 0 died.
# After 216 generation(s) of COVID, 256835 number of people will be immune.
#
# In generation 217, there were 1 cases, after an increase of 1. 951 people became immune, and 0 died.
# After 217 generation(s) of COVID, 257786 number of people will be immune.
#
# In generation 218, there were 1 cases, after an increase of 1. 951 people became immune, and 0 died.
# After 218 generation(s) of COVID, 258738 number of people will be immune.
#
# In generation 219, there were 1 cases, after an increase of 1. 951 people became immune, and 0 died.
# After 219 generation(s) of COVID, 259689 number of people will be immune.
#
# In generation 220, there were 1 cases, after an increase of 1. 951 people became immune, and 0 died.
# After 220 generation(s) of COVID, 260640 number of people will be immune.
#
# In generation 221, there were 1 cases, after an increase of 1. 951 people became immune, and 0 died.
# After 221 generation(s) of COVID, 261591 number of people will be immune.
#
# In generation 222, there were 1 cases, after an increase of 1. 951 people became immune, and 0 died.
# After 222 generation(s) of COVID, 262542 number of people will be immune.
#
# In generation 223, there were 1 cases, after an increase of 1. 951 people became immune, and 0 died.
# After 223 generation(s) of COVID, 263492 number of people will be immune.
#
# In generation 224, there were 1 cases, after an increase of 1. 951 people became immune, and 0 died.
# After 224 generation(s) of COVID, 264443 number of people will be immune.
#
# In generation 225, there were 1 cases, after an increase of 1. 951 people became immune, and 0 died.
# After 225 generation(s) of COVID, 265394 number of people will be immune.
#
# In generation 226, there were 1 cases, after an increase of 1. 951 people became immune, and 0 died.
# After 226 generation(s) of COVID, 266345 number of people will be immune.
#
# In generation 227, there were 1 cases, after an increase of 1. 951 people became immune, and 0 died.
# After 227 generation(s) of COVID, 267295 number of people will be immune.
#
# In generation 228, there were 1 cases, after an increase of 1. 951 people became immune, and 0 died.
# After 228 generation(s) of COVID, 268246 number of people will be immune.
#
# In generation 229, there were 1 cases, after an increase of 1. 951 people became immune, and 0 died.
# After 229 generation(s) of COVID, 269197 number of people will be immune.
#
# In generation 230, there were 1 cases, after an increase of 1. 951 people became immune, and 0 died.
# After 230 generation(s) of COVID, 270147 number of people will be immune.
#
# In generation 231, there were 1 cases, after an increase of 1. 951 people became immune, and 0 died.
# After 231 generation(s) of COVID, 271098 number of people will be immune.
#
# In generation 232, there were 1 cases, after an increase of 1. 951 people became immune, and 0 died.
# After 232 generation(s) of COVID, 272048 number of people will be immune.
#
# In generation 233, there were 1 cases, after an increase of 1. 950 people became immune, and 0 died.
# After 233 generation(s) of COVID, 272999 number of people will be immune.
#
# In generation 234, there were 0 cases, after an increase of 1. 950 people became immune, and 0 died.
# After 234 generation(s) of COVID, 273949 number of people will be immune.
#
# In generation 235, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 235 generation(s) of COVID, 274900 number of people will be immune.
#
# In generation 236, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 236 generation(s) of COVID, 275850 number of people will be immune.
#
# In generation 237, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 237 generation(s) of COVID, 276801 number of people will be immune.
#
# In generation 238, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 238 generation(s) of COVID, 277751 number of people will be immune.
#
# In generation 239, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 239 generation(s) of COVID, 278701 number of people will be immune.
#
# In generation 240, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 240 generation(s) of COVID, 279652 number of people will be immune.
#
# In generation 241, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 241 generation(s) of COVID, 280602 number of people will be immune.
#
# In generation 242, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 242 generation(s) of COVID, 281552 number of people will be immune.
#
# In generation 243, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 243 generation(s) of COVID, 282503 number of people will be immune.
#
# In generation 244, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 244 generation(s) of COVID, 283453 number of people will be immune.
#
# In generation 245, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 245 generation(s) of COVID, 284403 number of people will be immune.
#
# In generation 246, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 246 generation(s) of COVID, 285353 number of people will be immune.
#
# In generation 247, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 247 generation(s) of COVID, 286304 number of people will be immune.
#
# In generation 248, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 248 generation(s) of COVID, 287254 number of people will be immune.
#
# In generation 249, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 249 generation(s) of COVID, 288204 number of people will be immune.
#
# In generation 250, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 250 generation(s) of COVID, 289154 number of people will be immune.
#
# In generation 251, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 251 generation(s) of COVID, 290104 number of people will be immune.
#
# In generation 252, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 252 generation(s) of COVID, 291055 number of people will be immune.
#
# In generation 253, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 253 generation(s) of COVID, 292005 number of people will be immune.
#
# In generation 254, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 254 generation(s) of COVID, 292955 number of people will be immune.
#
# In generation 255, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 255 generation(s) of COVID, 293905 number of people will be immune.
#
# In generation 256, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 256 generation(s) of COVID, 294855 number of people will be immune.
#
# In generation 257, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 257 generation(s) of COVID, 295805 number of people will be immune.
#
# In generation 258, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 258 generation(s) of COVID, 296755 number of people will be immune.
#
# In generation 259, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 259 generation(s) of COVID, 297705 number of people will be immune.
#
# In generation 260, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 260 generation(s) of COVID, 298656 number of people will be immune.
#
# In generation 261, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 261 generation(s) of COVID, 299606 number of people will be immune.
#
# In generation 262, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 262 generation(s) of COVID, 300556 number of people will be immune.
#
# In generation 263, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 263 generation(s) of COVID, 301506 number of people will be immune.
#
# In generation 264, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 264 generation(s) of COVID, 302456 number of people will be immune.
#
# In generation 265, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 265 generation(s) of COVID, 303406 number of people will be immune.
#
# ...
# After 512 generation(s) of COVID, 538057 number of people will be immune.
#
# In generation 513, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 513 generation(s) of COVID, 539007 number of people will be immune.
#
# In generation 514, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 514 generation(s) of COVID, 539957 number of people will be immune.
#
# In generation 515, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 515 generation(s) of COVID, 540907 number of people will be immune.
#
# In generation 516, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 516 generation(s) of COVID, 541857 number of people will be immune.
#
# In generation 517, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 517 generation(s) of COVID, 542807 number of people will be immune.
#
# In generation 518, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 518 generation(s) of COVID, 543757 number of people will be immune.
#
# In generation 519, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 519 generation(s) of COVID, 544707 number of people will be immune.
# In generation 520, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 520 generation(s) of COVID, 545657 number of people will be immune.
#
# In generation 521, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 521 generation(s) of COVID, 546607 number of people will be immune.
#
# In generation 522, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 522 generation(s) of COVID, 547557 number of people will be immune.
#
# In generation 523, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 523 generation(s) of COVID, 548507 number of people will be immune.
#
# In generation 524, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 524 generation(s) of COVID, 549457 number of people will be immune.
#
# In generation 525, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 525 generation(s) of COVID, 550407 number of people will be immune.
#
# In generation 526, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 526 generation(s) of COVID, 551357 number of people will be immune.
#
# In generation 527, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 527 generation(s) of COVID, 552307 number of people will be immune.
#
# In generation 528, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 528 generation(s) of COVID, 553257 number of people will be immune.
#
# In generation 529, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 529 generation(s) of COVID, 554207 number of people will be immune.
#
# In generation 530, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 530 generation(s) of COVID, 555157 number of people will be immune.
#
# In generation 531, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 531 generation(s) of COVID, 556107 number of people will be immune.
#
# In generation 532, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 532 generation(s) of COVID, 557057 number of people will be immune.
#
# In generation 533, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 533 generation(s) of COVID, 558007 number of people will be immune.
#
# In generation 534, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 534 generation(s) of COVID, 558957 number of people will be immune.
#
# In generation 535, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 535 generation(s) of COVID, 559907 number of people will be immune.
#
# In generation 536, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 536 generation(s) of COVID, 560857 number of people will be immune.
#
# In generation 537, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 537 generation(s) of COVID, 561807 number of people will be immune.
#
# In generation 538, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 538 generation(s) of COVID, 562757 number of people will be immune.
#
# In generation 539, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 539 generation(s) of COVID, 563707 number of people will be immune.
#
# In generation 540, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 540 generation(s) of COVID, 564657 number of people will be immune.
#
# In generation 541, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 541 generation(s) of COVID, 565607 number of people will be immune.
#
# In generation 542, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 542 generation(s) of COVID, 566557 number of people will be immune.
#
# In generation 543, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 543 generation(s) of COVID, 567507 number of people will be immune.
#
# In generation 544, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 544 generation(s) of COVID, 568457 number of people will be immune.
#
# In generation 545, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 545 generation(s) of COVID, 569407 number of people will be immune.
#
# In generation 546, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 546 generation(s) of COVID, 570357 number of people will be immune.
#
# In generation 547, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 547 generation(s) of COVID, 571307 number of people will be immune.
#
# In generation 548, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 548 generation(s) of COVID, 572257 number of people will be immune.
#
# In generation 549, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 549 generation(s) of COVID, 573207 number of people will be immune.
#
# In generation 550, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 550 generation(s) of COVID, 574157 number of people will be immune.
#
# In generation 551, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 551 generation(s) of COVID, 575107 number of people will be immune.
#
# In generation 552, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 552 generation(s) of COVID, 576057 number of people will be immune.
#
# In generation 553, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 553 generation(s) of COVID, 577007 number of people will be immune.
#
# In generation 554, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 554 generation(s) of COVID, 577957 number of people will be immune.
#
# In generation 555, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 555 generation(s) of COVID, 578907 number of people will be immune.
#
# In generation 556, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 556 generation(s) of COVID, 579857 number of people will be immune.
#
# In generation 557, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 557 generation(s) of COVID, 580807 number of people will be immune.
#
# In generation 558, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 558 generation(s) of COVID, 581757 number of people will be immune.
#
# In generation 559, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 559 generation(s) of COVID, 582707 number of people will be immune.
#
# In generation 560, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 560 generation(s) of COVID, 583657 number of people will be immune.
#
# In generation 561, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 561 generation(s) of COVID, 584607 number of people will be immune.
#
# In generation 562, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 562 generation(s) of COVID, 585557 number of people will be immune.
#
# In generation 563, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 563 generation(s) of COVID, 586507 number of people will be immune.
#
# In generation 564, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 564 generation(s) of COVID, 587457 number of people will be immune.
#
# In generation 565, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 565 generation(s) of COVID, 588407 number of people will be immune.
#
# In generation 566, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 566 generation(s) of COVID, 589357 number of people will be immune.
#
# In generation 567, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 567 generation(s) of COVID, 590307 number of people will be immune.
#
# In generation 568, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 568 generation(s) of COVID, 591257 number of people will be immune.
#
# In generation 569, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 569 generation(s) of COVID, 592207 number of people will be immune.
#
# In generation 570, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 570 generation(s) of COVID, 593157 number of people will be immune.
#
# In generation 571, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 571 generation(s) of COVID, 594107 number of people will be immune.
#
# In generation 572, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 572 generation(s) of COVID, 595057 number of people will be immune.
#
# In generation 573, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 573 generation(s) of COVID, 596007 number of people will be immune.
#
# In generation 574, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 574 generation(s) of COVID, 596957 number of people will be immune.
#
# In generation 575, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 575 generation(s) of COVID, 597907 number of people will be immune.
#
# In generation 576, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 576 generation(s) of COVID, 598857 number of people will be immune.
#
# In generation 577, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 577 generation(s) of COVID, 599807 number of people will be immune.
#
# In generation 578, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 578 generation(s) of COVID, 600757 number of people will be immune.
#
# In generation 579, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 579 generation(s) of COVID, 601707 number of people will be immune.
#
# In generation 580, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 580 generation(s) of COVID, 602657 number of people will be immune.
#
# In generation 581, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 581 generation(s) of COVID, 603607 number of people will be immune.
#
# In generation 582, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 582 generation(s) of COVID, 604557 number of people will be immune.
#
# In generation 583, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 583 generation(s) of COVID, 605507 number of people will be immune.
#
# In generation 584, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 584 generation(s) of COVID, 606457 number of people will be immune.
#
# In generation 585, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 585 generation(s) of COVID, 607407 number of people will be immune.
#
# In generation 586, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 586 generation(s) of COVID, 608357 number of people will be immune.
#
# In generation 587, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 587 generation(s) of COVID, 609307 number of people will be immune.
#
# In generation 588, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 588 generation(s) of COVID, 610257 number of people will be immune.
#
# In generation 589, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 589 generation(s) of COVID, 611207 number of people will be immune.
#
# In generation 590, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 590 generation(s) of COVID, 612157 number of people will be immune.
#
# In generation 591, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 591 generation(s) of COVID, 613107 number of people will be immune.
#
# In generation 592, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 592 generation(s) of COVID, 614057 number of people will be immune.
#
# In generation 593, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 593 generation(s) of COVID, 615007 number of people will be immune.
#
# In generation 594, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 594 generation(s) of COVID, 615957 number of people will be immune.
#
# In generation 595, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 595 generation(s) of COVID, 616907 number of people will be immune.
#
# In generation 596, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 596 generation(s) of COVID, 617857 number of people will be immune.
#
# In generation 597, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 597 generation(s) of COVID, 618807 number of people will be immune.
#
# In generation 598, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 598 generation(s) of COVID, 619757 number of people will be immune.
#
# In generation 599, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 599 generation(s) of COVID, 620707 number of people will be immune.
#
# In generation 600, there were 0 cases, after an increase of 0. 950 people became immune, and 0 died.
# After 600 generation(s) of COVID, 621657 number of people will be immune.
#
# <function vac_table at 0x1165f3160>
# Do you want to save the report to a file? Enter yes or no: yes
# Your file name will be "Vac"
# How would you like your file to be opened? Enter append or write: write
# Confirm editing format with yes or no: yes
# The program is complete.
