# %%
def user():
    
    '''Function that asks for the user for values that will be used throughout the rest of the program.'''
    try: 
        population = int(input('What is the approximate population size of your city/town? ')) #Asks the user for the total population (number of individuals who can become suseptible.)
        daily_rise = int(input('What was the daily rise in number of cases in your area? ')) #Asks the user for the the number of cases (Thus the number of infectives in the first year)
        num_gen= int(input('How many days would you like to cycle through: ')) #The number of generations indicated how many data points the user wants.
    except:
        print('Error: Please enter numbers only and try again.')
        graph()
    high_or_low = input('Would you like the transmission rate to be a high or low estimate? Please enter "High" or "Low". ').capitalize() #Asks the user for what type of estimate they would like
    try:
        if high_or_low == 'Low': #if the user wants a low estimate
            low_estimate = {'England':0.8, 'Northen Ireland':0.9, 'Scotland':0.8, 'Wales':0.8} #low estimates for UK values
            country = input('What country in the UK is your town or city? ').capitalize() #answer used to select from the dictionary
            trans_rate = low_estimate[country] #pulls the estimate from the dictionary
            return trans_rate, country, num_gen, daily_rise, population
        
        else: # For high estimate
            high_estimate={'England':1.0, 'Northen Ireland':1.1, 'Scotland':1.0, 'Wales':1.0} #high estimates for UK values
            country = input('What country in the UK is your town or city? ').capitalize() #answer used to select from the dictionary
            trans_rate = high_estimate[country] #pulls the estimate from the dictionary
            return trans_rate, country, num_gen, daily_rise, population
    except:
        print('Error: {} is not a valid entry. Please enter a country in the UK and try again.'.format(country))
        graph()

def calculations():
    
    '''Function to Calculate the number of individuals who gain immunity each generation without the inclusion of a vaccine.'''
    
    trans_rate, country, num_gen, daily_rise, population = user()
    print('The transmission rate for {} is {}. '.format(country, trans_rate)) #informs the user of the information they did not directly imput
    mr= 0.036 #the UK mortality rate for the corona virus
    zero_death = (daily_rise*mr) #number of individuals that died from the cases the user provided (at time zero)
    zero_immunity = daily_rise - zero_death #number of individuals that gained immunity from the cases the user provides (at time zero)
    #length= int(num_gen) + 1 #the number of generations the user provided +1 so that the for program goes through the required amount of times
    gen = range(1, num_gen + 1) #list of all generations
    total_cases = [daily_rise] #a list of all the cases - that for now only includes the daily rise
    total_immunity = [zero_immunity] #list of number of individuals immune each generation
    total_death = [zero_death] #list of number of individuals died each generation
    total_generation= [0] #creates a list of the generation numbers
    immune_list = [zero_immunity] #Sum of total immunity each generation
    immune_percentage = [] #Creats an empty list where the percentage of each element of 'immune_list' will be added
    
    for t in gen: #Sequences through all generations
        total_generation.append(t) #adds a number to the total generation
        sum_cases = sum(total_cases) #sums all the number of cases
        
        if daily_rise == 0: #if total number of cases is larger than the population or there are no more cases
            
            print('All of the population has been processed.')
            recovered = sum(total_immunity) #number of people who recovered
            I = daily_rise #number of people who are infectious
            portion_infected = I/population #the portion of the individuals who 
            not_in_population = (recovered + sum(total_death)) #sum of the people no longer suseptible either immune or dead
            S = (population-not_in_population) #removes those who are not suseptible from the population
            portion_S = (S/population) #portion of the people suseptible
            new_cases = portion_S*I*trans_rate #number of new cases: portion of individuals in the population who are suseptible * infected (contagious) * transmission rate
            total_cases.append(new_cases) #adds to the total number of cases
            death = (new_cases)*0.036 #portion of those infected who died
            total_death.append(death) #adds to the total number of deaths
            immunity = new_cases - death #individuals who are immune that generation
            total_immunity.append(immunity) #adds to the total number of immune
            print('In generation {}, there were {:.0f} cases, after an increase of {:.0f}. {:.0f} people became immune, and {:.0f} died.'.format(t, new_cases, 
                                                                                                                               daily_rise, immunity, death))
            print('After {} generation(s) of COVID, {:.0f} number of people will be immune.'.format(t,sum(total_immunity))) 
            daily_rise = new_cases
            print(' ')
            immune_list.append(sum(total_immunity))
            break
           
        else:
            recovered = sum(total_immunity) #number of people who recovered
            I = daily_rise #number of people who are infectious
            portion_infected= I/population #the portion of the individuals who 
            not_in_population = (recovered + sum(total_death)) #sum of the people no longer suseptible either immune or dead
            S = (population-not_in_population) #removes those who are not suseptible from the population
            portion_S = (S/population) #portion of the people suseptible
            new_cases = portion_S*I*trans_rate #number of new cases: portion of individuals in the population who are suseptible * infected (contagious) * transmission rate
            total_cases.append(new_cases) #adds to the total number of cases
            death = (new_cases)*0.036 #portion of those infected who died
            
            if death < 1:
                total_death.append(1) #adds to the total number of deaths
            else:
                total_death.append(death) #adds to the total number of deaths
            immunity = new_cases - death #individuals who are immune that generation
            
            if immunity < 1:
                    total_immunity.append(1) 
            else:
                total_immunity.append(immunity) #adds to the total number of immune
            print('On day {}, there were {:.0f} new cases. {:.0f} people became immune, and {:.0f} died.'.format(t, new_cases, 
                                                                                                             immunity, death))
            print('After {} generation(s) of COVID; there are {:.0f} total cases across the population and a total {:.0f} number of people will be immune.'.format(t, sum(total_cases),
                                                                                                                                                              sum(total_immunity))) 
            daily_rise = new_cases
            print(' ')
            immune_list.append(sum(total_immunity))
    
    #The percentage is calculated and added to the list
    for immune in immune_list:
        percentage=immune/population*100
        immune_percentage.append(percentage)
    
    return total_cases, total_immunity, total_death, total_generation, immune_list, immune_percentage

def table():
    
    '''Function to display and save to a file the data to be displayed in a graph'''
    
    total_cases, total_immunity, total_death, total_generation, immune_list, immune_percentage = calculations()
    
    #imports a software libraries needed to complete the program
    
    import pandas as pd
    import numpy as np
    
    #creates a dictionary of the number of generations vs the sum of the individuals with immunity
    
    data = {
    'Number of Generations': total_generation,
    'Percentage of individuals with immunity': immune_percentage
        }
    
    #prints the information in data to a table
    table = pd.DataFrame(data)
    print(table)
    numpy_array = table.to_numpy()
    print(' ')
    
    decide = input('Do you want to save the report to a file? Enter yes or no: ').capitalize() #ask if they want to save a file
    if decide == 'Yes': #If they input yes
        #currently only input that works is Gen
        print('Your file name will be "ImmunityTable"') 

        how = input('How would you like your file to be opened? Enter append or write: ').capitalize() #ask how they want the data to be saved

            #confirm_how = input('Confirm editing format with yes or no: ').capitalize() #ask for confirmation

            #if confirm_how == 'No':#if enter no
               # how = input('How would you like your file to be opened? Enter append or write: ') #allowed to enter again

        if how == 'Write': #write the following into the provided file
            file = open('ImmunityTable', 'w')
            np.savetxt('ImmunityTable' , numpy_array, fmt = "%d")
            file.close()
            print('I have successfully saved the dat under "ImmunityTable". The program is complete.')

        elif how == 'Append': #append the following into the provided file
            file = open('ImmunityTable', 'a')
            np.savetxt('ImmunityTable' , numpy_array, fmt = "%d")
            file.close()
            print('I have successfully saved the data under "ImmunityTable" The program is complete.')
            
        else:
            print('Error: I do not understand command "{}". Please enter either "Write" or "Append" and try again.'.format(how))
            graph()
    
    else:#if the user doesn't want to save a file.
        print('Okay, I will not save the data. The program is complete.')

def graph():
    '''Function which prints a graph of established data'''
    
    import pandas as pd
    table()
    tdf= pd.read_csv("ImmunityTable",sep=" ") #reads file to collect the data
    tdf.shape
    tdf=pd.read_csv("ImmunityTable",sep=" ",names=["Number of days", "Immunity (as percentage of the population)"]) #creates headers for the graph
    tdf.head()
    tdf.plot(x="Number of days",y="Immunity (as percentage of the population)") #plots the data

def vac_user():
    
    '''Function to ask the user for the vaccine data and efficiency, and calculate how many people become immune from 
    the vaccine per generation'''  
    
    vac_name = input("What is the vaccine used?")
    efficiency =input(("What is the efficiency of the vaccine in percentage? "))
    effi_dec = (int(efficiency)/100)
    vac_people = int(input(("How many people are being vaccinated in your city/town per day? ")))
    vac_immunity= (vac_people *effi_dec) #calculates how many people are becoming immune from the vaccine per generation
    return vac_immunity

def vac_calculations():
    
    '''Function to Calculate the number of individuals who gain immunity each generation WITH the inclusion of a vaccine.'''
    trans_rate, country, num_gen, daily_rise, population = user()
    
    vac_immunity = vac_user()
    print('The transmission rate for {} is {}. '.format(country, trans_rate)) #informs the user of the information they did not directly imput
    mr= 0.036 #the UK mortality rate for the corona virus
    zero_death = (daily_rise*mr) #number of individuals that died from the cases the user provided
    zero_immunity = daily_rise - zero_death #number of individuals that gained immunity from the cases the user provides
    #length= int(num_gen) + 1 #the number of generations the user provided +1 so that the for program goes through the required amount of times
    gen = range(1, num_gen +1) #list of all generations
    total_cases = [daily_rise] #a list of all the cases
    vac_total_immunity = [zero_immunity] #list of number of individuals immune each generation
    total_death = [zero_death] #list of number of individuals died each generation
    total_generation= [0] #creates a list of the generation numbers
    vac_immune_list = [zero_immunity] #Sum of total immunity each generation
    vac_immune_percentages = [] #Creats an empty list where the percentage of immune people will be included.
    
    for t in gen: #Sequences through all generations
        total_generation.append(t) #adds a number to the total generation
        sum_cases = sum(total_cases) #sums all the number of cases
        
        if sum_cases >= population: #if total number of cases is larger than the population or there are no more cases
            print('All of the population has been processed.')
            recovered = sum(total_immunity) #number of people who recovered
            I = daily_rate #number of people who are infectious
            portion_infected= I/population #the portion of the individuals who 
            not_in_population = (recovered + sum(total_death)) #sum of the people no longer suseptible either immune or dead
            S = (population-not_in_population) #removes those who are not suseptible from the population
            portion_S = (S/population) #portion of the people suseptible
            new_cases = portion_S*I*trans_rate #number of new cases: portion of individuals in the population who are suseptible * infected (contagious) * transmission rate
            total_cases.append(new_cases) #adds to the total number of cases
            death =  (new_cases)*0.036 #portion of those infected who died
            total_death.append(death) #adds to the total number of deaths
            gen_immunity = new_cases + vac_immunity - death  #individuals who are immune that generation
            vac_total_immunity.append(gen_immunity) #adds to the total number of immune 
            print('In generation {}, there were {:.0f} cases, after an increase of {:.0f}. {:.0f} people became immune, and {:.0f} died.'.format(t, new_cases, 
                                                                                                                               daily_rise, gen_immunity, death))
            print('After {} generation(s) of COVID, {:.0f} number of people will be immune.'.format(t,sum(vac_total_immunity))) 
            daily_rate = new_cases
            print(' ')
            vac_immune_list.append(sum(vac_total_immunity)) #this creates an overall list of all the generation immunity data
           
            break
           
        else:
            recovered = sum(vac_total_immunity) #number of people who recovered
            I = daily_rise #number of people who are infectious
            portion_infected= I/population #the portion of the individuals who 
            not_in_population = (recovered + sum(total_death)) #sum of the people no longer suseptible either immune or dead
            S = (population-not_in_population) #removes those who are not suseptible from the population
            portion_S = (S/population) #portion of the people suseptible
            new_cases = portion_S*I*trans_rate #number of new cases: portion of individuals in the population who are suseptible * infected (contagious) * transmission rate
            total_cases.append(new_cases) #adds to the total number of cases
            death = (new_cases)*0.036 #portion of those infected who died
            
            if death < 1:
                total_death.append(1) #adds to the total number of deaths
            else:
                total_death.append(death) #adds to the total number of deaths
            
            gen_immunity = new_cases+ vac_immunity - death #individuals who are immune that generation
            
            if gen_immunity < 1:
                    vac_total_immunity.append(1)
            else:
                vac_total_immunity.append(gen_immunity) #adds to the total number of immune
            print('In generation {}, there were {:.0f} cases, after an increase of {:.0f}. {:.0f} people became immune, and {:.0f} died.'.format(t, new_cases, 
                                                                                                                               daily_rate, vimmunity, death))
            print('After {} generation(s) of COVID, {:.0f} number of people will be immune.'.format(t,sum(vac_total_immunity))) 
            daily_rate = new_cases
            print(' ')
            vac_immune_list.append(sum(vac_total_immunity))
    
    for immune in vac_immune:
        percentage=immune/population*100
        vac_immune_percentages.append(percentage)
    
    return total_cases, vac_total_immunity, total_death, total_generation, vac_immune_list, vac_immune_percentages

def vac_table():
    '''Function to display and save to a file the data to be displayed in a graph'''
    total_cases, vac_total_immunity, total_death, total_generation, vac_immune_list, vac_immune_percentages = vac_calculations()
    
    #imports a software libraries needed to complete the program
    import pandas as pd
    import numpy as np
    
    #creates a dictionary of the number of generations vs the sum of the individuals with immunity
    data = {
    'Number of Generations': total_generation,
    'Percentage of individuals with immunity': vac_immune_percentages
        }
    
    #prints the information in data to a table
    table = pd.DataFrame(data)
    print(vac_table)
    numpy_array = table.to_numpy()
    print(' ')
    
    decide = input('Do you want to save the report to a file? Enter yes or no: ').capitalize() #ask if they want to save a file
    if decide == 'Yes': #If they input yes
        #currently only input that works is Gen
        print('Your file name will be "VacImmunityTable"') 

        how = input('How would you like your file to be opened? Enter append or write: ').capitalize() #ask how they want the data to be saved

            #confirm_how = input('Confirm editing format with yes or no: ').capitalize() #ask for confirmation

            #if confirm_how == 'No':#if enter no
               # how = input('How would you like your file to be opened? Enter append or write: ') #allowed to enter again

        if how == 'Write': #write the following into the provided file
            file = open('VacImmunityTable', 'w')
            np.savetxt('VacImmunityTable' , numpy_array, fmt = "%d")
            file.close()
            print('I have successfully saved the data under "VacImmunityTable". The program is complete.')

        elif how == 'Append': #append the following into the provided file
            file = open('VacImmunityTable', 'a')
            np.savetxt('VacImmunityTable' , numpy_array, fmt = "%d")
            file.close()
            print('I have successfully saved the data under "VacImmunityTable" The program is complete.')
            
        else:
            print('Error: I do not understand command "{}". Please enter either "Write" or "Append" and try again.'.format(how))
            graph()
    
    else:#if the user doesn't want to save a file.
        print('Okay, I will not save the data. The program is complete.')

def vac_graph():
    '''Function which prints a graph of established data'''
    
    import pandas as pd
    vac_table()
    tdf= pd.read_csv("VacImmunityTable",sep=" ") #reads file to collect the data
    tdf.shape
    tdf=pd.read_csv("VacImmunityTable",sep=" ",names=["Number of days", "Immunity with Vaccine (as percentage of the population)"]) #creates headers for the graph
    tdf.head()
    tdf.plot(x="Number of days",y="Immunity with Vaccine (as percentage of the population)") #plots the data

# %%
graph()
# Out:
# What is the approximate population size of your city/town? 50000
# What was the daily rise in number of cases in your area? 123
# How many days would you like to cycle through: 365
# Would you like the transmission rate to be a high or low estimate? Please enter "High" or "Low". high
# What country in the UK is your town or city? Scotland
# The transmission rate for Scotland is 1.0.
# On day 1, there were 123 new cases. 118 people became immune, and 4 died.
# After 1 generation(s) of COVID; there are 246 total cases across the population and a total 237 number of people will be immune.
#
# On day 2, there were 122 new cases. 118 people became immune, and 4 died.
# After 2 generation(s) of COVID; there are 368 total cases across the population and a total 355 number of people will be immune.
#
# On day 3, there were 121 new cases. 117 people became immune, and 4 died.
# After 3 generation(s) of COVID; there are 489 total cases across the population and a total 471 number of people will be immune.
#
# On day 4, there were 120 new cases. 116 people became immune, and 4 died.
# After 4 generation(s) of COVID; there are 609 total cases across the population and a total 587 number of people will be immune.
#
# On day 5, there were 119 new cases. 114 people became immune, and 4 died.
# After 5 generation(s) of COVID; there are 728 total cases across the population and a total 701 number of people will be immune.
#
# On day 6, there were 117 new cases. 113 people became immune, and 4 died.
# After 6 generation(s) of COVID; there are 844 total cases across the population and a total 814 number of people will be immune.
#
# On day 7, there were 115 new cases. 111 people became immune, and 4 died.
# After 7 generation(s) of COVID; there are 959 total cases across the population and a total 925 number of people will be immune.
#
# On day 8, there were 113 new cases. 109 people became immune, and 4 died.
# After 8 generation(s) of COVID; there are 1072 total cases across the population and a total 1033 number of people will be immune.
#
# On day 9, there were 110 new cases. 106 people became immune, and 4 died.
# After 9 generation(s) of COVID; there are 1182 total cases across the population and a total 1140 number of people will be immune.
#
# On day 10, there were 108 new cases. 104 people became immune, and 4 died.
# After 10 generation(s) of COVID; there are 1290 total cases across the population and a total 1243 number of people will be immune.
#
# On day 11, there were 105 new cases. 101 people became immune, and 4 died.
# After 11 generation(s) of COVID; there are 1395 total cases across the population and a total 1344 number of people will be immune.
#
# On day 12, there were 102 new cases. 98 people became immune, and 4 died.
# After 12 generation(s) of COVID; there are 1497 total cases across the population and a total 1443 number of people will be immune.
#
# On day 13, there were 99 new cases. 95 people became immune, and 4 died.
# After 13 generation(s) of COVID; there are 1595 total cases across the population and a total 1538 number of people will be immune.
#
# On day 14, there were 96 new cases. 92 people became immune, and 3 died.
# After 14 generation(s) of COVID; there are 1691 total cases across the population and a total 1630 number of people will be immune.
#
# On day 15, there were 92 new cases. 89 people became immune, and 3 died.
# After 15 generation(s) of COVID; there are 1784 total cases across the population and a total 1719 number of people will be immune.
#
# On day 16, there were 89 new cases. 86 people became immune, and 3 died.
# After 16 generation(s) of COVID; there are 1873 total cases across the population and a total 1805 number of people will be immune.
#
# On day 17, there were 86 new cases. 83 people became immune, and 3 died.
# After 17 generation(s) of COVID; there are 1959 total cases across the population and a total 1888 number of people will be immune.
#
# On day 18, there were 82 new cases. 80 people became immune, and 3 died.
# After 18 generation(s) of COVID; there are 2041 total cases across the population and a total 1968 number of people will be immune.
#
# On day 19, there were 79 new cases. 76 people became immune, and 3 died.
# After 19 generation(s) of COVID; there are 2120 total cases across the population and a total 2044 number of people will be immune.
#
# On day 20, there were 76 new cases. 73 people became immune, and 3 died.
# After 20 generation(s) of COVID; there are 2196 total cases across the population and a total 2117 number of people will be immune.
#
# On day 21, there were 72 new cases. 70 people became immune, and 3 died.
# After 21 generation(s) of COVID; there are 2268 total cases across the population and a total 2187 number of people will be immune.
#
# On day 22, there were 69 new cases. 67 people became immune, and 2 died.
# After 22 generation(s) of COVID; there are 2338 total cases across the population and a total 2253 number of people will be immune.
#
# On day 23, there were 66 new cases. 64 people became immune, and 2 died.
# After 23 generation(s) of COVID; there are 2403 total cases across the population and a total 2317 number of people will be immune.
#
# On day 24, there were 63 new cases. 60 people became immune, and 2 died.
# After 24 generation(s) of COVID; there are 2466 total cases across the population and a total 2377 number of people will be immune.
#
# On day 25, there were 60 new cases. 58 people became immune, and 2 died.
# After 25 generation(s) of COVID; there are 2526 total cases across the population and a total 2435 number of people will be immune.
#
# On day 26, there were 57 new cases. 55 people became immune, and 2 died.
# After 26 generation(s) of COVID; there are 2582 total cases across the population and a total 2490 number of people will be immune.
#
# On day 27, there were 54 new cases. 52 people became immune, and 2 died.
# After 27 generation(s) of COVID; there are 2636 total cases across the population and a total 2541 number of people will be immune.
#
# On day 28, there were 51 new cases. 49 people became immune, and 2 died.
# After 28 generation(s) of COVID; there are 2687 total cases across the population and a total 2590 number of people will be immune.
#
# On day 29, there were 48 new cases. 46 people became immune, and 2 died.
# After 29 generation(s) of COVID; there are 2735 total cases across the population and a total 2637 number of people will be immune.
#
# On day 30, there were 46 new cases. 44 people became immune, and 2 died.
# After 30 generation(s) of COVID; there are 2781 total cases across the population and a total 2681 number of people will be immune.
#
# On day 31, there were 43 new cases. 41 people became immune, and 2 died.
# After 31 generation(s) of COVID; there are 2824 total cases across the population and a total 2722 number of people will be immune.
#
# On day 32, there were 41 new cases. 39 people became immune, and 1 died.
# After 32 generation(s) of COVID; there are 2864 total cases across the population and a total 2761 number of people will be immune.
#
# On day 33, there were 38 new cases. 37 people became immune, and 1 died.
# After 33 generation(s) of COVID; there are 2903 total cases across the population and a total 2798 number of people will be immune.
#
# On day 34, there were 36 new cases. 35 people became immune, and 1 died.
# After 34 generation(s) of COVID; there are 2939 total cases across the population and a total 2833 number of people will be immune.
#
# On day 35, there were 34 new cases. 33 people became immune, and 1 died.
# After 35 generation(s) of COVID; there are 2972 total cases across the population and a total 2865 number of people will be immune.
#
# On day 36, there were 32 new cases. 31 people became immune, and 1 died.
# After 36 generation(s) of COVID; there are 3004 total cases across the population and a total 2896 number of people will be immune.
#
# On day 37, there were 30 new cases. 29 people became immune, and 1 died.
# After 37 generation(s) of COVID; there are 3034 total cases across the population and a total 2925 number of people will be immune.
#
# On day 38, there were 28 new cases. 27 people became immune, and 1 died.
# After 38 generation(s) of COVID; there are 3062 total cases across the population and a total 2952 number of people will be immune.
#
# On day 39, there were 26 new cases. 25 people became immune, and 1 died.
# After 39 generation(s) of COVID; there are 3089 total cases across the population and a total 2978 number of people will be immune.
#
# On day 40, there were 25 new cases. 24 people became immune, and 1 died.
# After 40 generation(s) of COVID; there are 3114 total cases across the population and a total 3002 number of people will be immune.
#
# On day 41, there were 23 new cases. 22 people became immune, and 1 died.
# After 41 generation(s) of COVID; there are 3137 total cases across the population and a total 3024 number of people will be immune.
#
# On day 42, there were 22 new cases. 21 people became immune, and 1 died.
# After 42 generation(s) of COVID; there are 3159 total cases across the population and a total 3045 number of people will be immune.
#
# On day 43, there were 20 new cases. 20 people became immune, and 1 died.
# After 43 generation(s) of COVID; there are 3179 total cases across the population and a total 3065 number of people will be immune.
#
# On day 44, there were 19 new cases. 18 people became immune, and 1 died.
# After 44 generation(s) of COVID; there are 3198 total cases across the population and a total 3083 number of people will be immune.
#
# On day 45, there were 18 new cases. 17 people became immune, and 1 died.
# After 45 generation(s) of COVID; there are 3216 total cases across the population and a total 3100 number of people will be immune.
#
# On day 46, there were 17 new cases. 16 people became immune, and 1 died.
# After 46 generation(s) of COVID; there are 3233 total cases across the population and a total 3116 number of people will be immune.
#
# On day 47, there were 16 new cases. 15 people became immune, and 1 died.
# After 47 generation(s) of COVID; there are 3248 total cases across the population and a total 3132 number of people will be immune.
#
# On day 48, there were 15 new cases. 14 people became immune, and 1 died.
# After 48 generation(s) of COVID; there are 3263 total cases across the population and a total 3146 number of people will be immune.
#
# On day 49, there were 14 new cases. 13 people became immune, and 0 died.
# After 49 generation(s) of COVID; there are 3277 total cases across the population and a total 3159 number of people will be immune.
#
# On day 50, there were 13 new cases. 12 people became immune, and 0 died.
# After 50 generation(s) of COVID; there are 3290 total cases across the population and a total 3171 number of people will be immune.
#
# On day 51, there were 12 new cases. 12 people became immune, and 0 died.
# After 51 generation(s) of COVID; there are 3301 total cases across the population and a total 3183 number of people will be immune.
#
# On day 52, there were 11 new cases. 11 people became immune, and 0 died.
# After 52 generation(s) of COVID; there are 3313 total cases across the population and a total 3193 number of people will be immune.
#
# On day 53, there were 10 new cases. 10 people became immune, and 0 died.
# After 53 generation(s) of COVID; there are 3323 total cases across the population and a total 3203 number of people will be immune.
#
# On day 54, there were 10 new cases. 9 people became immune, and 0 died.
# After 54 generation(s) of COVID; there are 3333 total cases across the population and a total 3213 number of people will be immune.
#
# On day 55, there were 9 new cases. 9 people became immune, and 0 died.
# After 55 generation(s) of COVID; there are 3342 total cases across the population and a total 3222 number of people will be immune.
#
# On day 56, there were 8 new cases. 8 people became immune, and 0 died.
# After 56 generation(s) of COVID; there are 3350 total cases across the population and a total 3230 number of people will be immune.
#
# On day 57, there were 8 new cases. 8 people became immune, and 0 died.
# After 57 generation(s) of COVID; there are 3358 total cases across the population and a total 3237 number of people will be immune.
#
# On day 58, there were 7 new cases. 7 people became immune, and 0 died.
# After 58 generation(s) of COVID; there are 3366 total cases across the population and a total 3244 number of people will be immune.
#
# On day 59, there were 7 new cases. 7 people became immune, and 0 died.
# After 59 generation(s) of COVID; there are 3372 total cases across the population and a total 3251 number of people will be immune.
#
# On day 60, there were 6 new cases. 6 people became immune, and 0 died.
# After 60 generation(s) of COVID; there are 3379 total cases across the population and a total 3257 number of people will be immune.
#
# On day 61, there were 6 new cases. 6 people became immune, and 0 died.
# After 61 generation(s) of COVID; there are 3385 total cases across the population and a total 3263 number of people will be immune.
#
# On day 62, there were 6 new cases. 5 people became immune, and 0 died.
# After 62 generation(s) of COVID; there are 3390 total cases across the population and a total 3268 number of people will be immune.
#
# On day 63, there were 5 new cases. 5 people became immune, and 0 died.
# After 63 generation(s) of COVID; there are 3396 total cases across the population and a total 3273 number of people will be immune.
#
# On day 64, there were 5 new cases. 5 people became immune, and 0 died.
# After 64 generation(s) of COVID; there are 3400 total cases across the population and a total 3278 number of people will be immune.
#
# On day 65, there were 5 new cases. 4 people became immune, and 0 died.
# After 65 generation(s) of COVID; there are 3405 total cases across the population and a total 3282 number of people will be immune.
#
# On day 66, there were 4 new cases. 4 people became immune, and 0 died.
# After 66 generation(s) of COVID; there are 3409 total cases across the population and a total 3286 number of people will be immune.
#
# On day 67, there were 4 new cases. 4 people became immune, and 0 died.
# After 67 generation(s) of COVID; there are 3413 total cases across the population and a total 3290 number of people will be immune.
#
# On day 68, there were 4 new cases. 4 people became immune, and 0 died.
# After 68 generation(s) of COVID; there are 3417 total cases across the population and a total 3294 number of people will be immune.
#
# On day 69, there were 3 new cases. 3 people became immune, and 0 died.
# After 69 generation(s) of COVID; there are 3420 total cases across the population and a total 3297 number of people will be immune.
#
# On day 70, there were 3 new cases. 3 people became immune, and 0 died.
# After 70 generation(s) of COVID; there are 3423 total cases across the population and a total 3300 number of people will be immune.
#
# On day 71, there were 3 new cases. 3 people became immune, and 0 died.
# After 71 generation(s) of COVID; there are 3426 total cases across the population and a total 3303 number of people will be immune.
#
# On day 72, there were 3 new cases. 3 people became immune, and 0 died.
# After 72 generation(s) of COVID; there are 3429 total cases across the population and a total 3305 number of people will be immune.
#
# On day 73, there were 3 new cases. 2 people became immune, and 0 died.
# After 73 generation(s) of COVID; there are 3431 total cases across the population and a total 3308 number of people will be immune.
#
# On day 74, there were 2 new cases. 2 people became immune, and 0 died.
# After 74 generation(s) of COVID; there are 3434 total cases across the population and a total 3310 number of people will be immune.
#
# On day 75, there were 2 new cases. 2 people became immune, and 0 died.
# After 75 generation(s) of COVID; there are 3436 total cases across the population and a total 3312 number of people will be immune.
#
# On day 76, there were 2 new cases. 2 people became immune, and 0 died.
# After 76 generation(s) of COVID; there are 3438 total cases across the population and a total 3314 number of people will be immune.
#
# On day 77, there were 2 new cases. 2 people became immune, and 0 died.
# After 77 generation(s) of COVID; there are 3440 total cases across the population and a total 3316 number of people will be immune.
#
# On day 78, there were 2 new cases. 2 people became immune, and 0 died.
# After 78 generation(s) of COVID; there are 3442 total cases across the population and a total 3318 number of people will be immune.
#
# On day 79, there were 2 new cases. 2 people became immune, and 0 died.
# After 79 generation(s) of COVID; there are 3443 total cases across the population and a total 3319 number of people will be immune.
#
# On day 80, there were 2 new cases. 1 people became immune, and 0 died.
# After 80 generation(s) of COVID; there are 3445 total cases across the population and a total 3321 number of people will be immune.
#
# On day 81, there were 1 new cases. 1 people became immune, and 0 died.
# After 81 generation(s) of COVID; there are 3446 total cases across the population and a total 3322 number of people will be immune.
#
# On day 82, there were 1 new cases. 1 people became immune, and 0 died.
# After 82 generation(s) of COVID; there are 3448 total cases across the population and a total 3324 number of people will be immune.
#
# On day 83, there were 1 new cases. 1 people became immune, and 0 died.
# After 83 generation(s) of COVID; there are 3449 total cases across the population and a total 3325 number of people will be immune.
#
# On day 84, there were 1 new cases. 1 people became immune, and 0 died.
# After 84 generation(s) of COVID; there are 3450 total cases across the population and a total 3326 number of people will be immune.
#
# On day 85, there were 1 new cases. 1 people became immune, and 0 died.
# After 85 generation(s) of COVID; there are 3451 total cases across the population and a total 3327 number of people will be immune.
#
# On day 86, there were 1 new cases. 1 people became immune, and 0 died.
# After 86 generation(s) of COVID; there are 3452 total cases across the population and a total 3328 number of people will be immune.
#
# On day 87, there were 1 new cases. 1 people became immune, and 0 died.
# After 87 generation(s) of COVID; there are 3453 total cases across the population and a total 3329 number of people will be immune.
#
# On day 88, there were 1 new cases. 1 people became immune, and 0 died.
# After 88 generation(s) of COVID; there are 3454 total cases across the population and a total 3330 number of people will be immune.
#
# On day 89, there were 1 new cases. 1 people became immune, and 0 died.
# After 89 generation(s) of COVID; there are 3455 total cases across the population and a total 3331 number of people will be immune.
#
# On day 90, there were 1 new cases. 1 people became immune, and 0 died.
# After 90 generation(s) of COVID; there are 3455 total cases across the population and a total 3332 number of people will be immune.
#
# On day 91, there were 1 new cases. 1 people became immune, and 0 died.
# After 91 generation(s) of COVID; there are 3456 total cases across the population and a total 3333 number of people will be immune.
#
# On day 92, there were 1 new cases. 1 people became immune, and 0 died.
# After 92 generation(s) of COVID; there are 3457 total cases across the population and a total 3334 number of people will be immune.
#
# On day 93, there were 1 new cases. 1 people became immune, and 0 died.
# After 93 generation(s) of COVID; there are 3457 total cases across the population and a total 3335 number of people will be immune.
#
# On day 94, there were 1 new cases. 1 people became immune, and 0 died.
# After 94 generation(s) of COVID; there are 3458 total cases across the population and a total 3336 number of people will be immune.
#
# On day 95, there were 1 new cases. 1 people became immune, and 0 died.
# After 95 generation(s) of COVID; there are 3459 total cases across the population and a total 3337 number of people will be immune.
#
# On day 96, there were 0 new cases. 0 people became immune, and 0 died.
# After 96 generation(s) of COVID; there are 3459 total cases across the population and a total 3338 number of people will be immune.
#
# On day 97, there were 0 new cases. 0 people became immune, and 0 died.
# After 97 generation(s) of COVID; there are 3459 total cases across the population and a total 3339 number of people will be immune.
#
# On day 98, there were 0 new cases. 0 people became immune, and 0 died.
# After 98 generation(s) of COVID; there are 3460 total cases across the population and a total 3340 number of people will be immune.
#
# On day 99, there were 0 new cases. 0 people became immune, and 0 died.
# After 99 generation(s) of COVID; there are 3460 total cases across the population and a total 3341 number of people will be immune.
#
# On day 100, there were 0 new cases. 0 people became immune, and 0 died.
# After 100 generation(s) of COVID; there are 3461 total cases across the population and a total 3342 number of people will be immune.
#
# On day 101, there were 0 new cases. 0 people became immune, and 0 died.
# After 101 generation(s) of COVID; there are 3461 total cases across the population and a total 3343 number of people will be immune.
#
# On day 102, there were 0 new cases. 0 people became immune, and 0 died.
# After 102 generation(s) of COVID; there are 3461 total cases across the population and a total 3344 number of people will be immune.
#
# On day 103, there were 0 new cases. 0 people became immune, and 0 died.
# After 103 generation(s) of COVID; there are 3462 total cases across the population and a total 3345 number of people will be immune.
#
# On day 104, there were 0 new cases. 0 people became immune, and 0 died.
# After 104 generation(s) of COVID; there are 3462 total cases across the population and a total 3346 number of people will be immune.
#
# On day 105, there were 0 new cases. 0 people became immune, and 0 died.
# After 105 generation(s) of COVID; there are 3462 total cases across the population and a total 3347 number of people will be immune.
#
# On day 106, there were 0 new cases. 0 people became immune, and 0 died.
# After 106 generation(s) of COVID; there are 3462 total cases across the population and a total 3348 number of people will be immune.
#
# On day 107, there were 0 new cases. 0 people became immune, and 0 died.
# After 107 generation(s) of COVID; there are 3463 total cases across the population and a total 3349 number of people will be immune.
#
# On day 108, there were 0 new cases. 0 people became immune, and 0 died.
# After 108 generation(s) of COVID; there are 3463 total cases across the population and a total 3350 number of people will be immune.
#
# On day 109, there were 0 new cases. 0 people became immune, and 0 died.
# After 109 generation(s) of COVID; there are 3463 total cases across the population and a total 3351 number of people will be immune.
#
# On day 110, there were 0 new cases. 0 people became immune, and 0 died.
# After 110 generation(s) of COVID; there are 3463 total cases across the population and a total 3352 number of people will be immune.
#
# On day 111, there were 0 new cases. 0 people became immune, and 0 died.
# After 111 generation(s) of COVID; there are 3463 total cases across the population and a total 3353 number of people will be immune.
#
# On day 112, there were 0 new cases. 0 people became immune, and 0 died.
# After 112 generation(s) of COVID; there are 3463 total cases across the population and a total 3354 number of people will be immune.
#
# On day 113, there were 0 new cases. 0 people became immune, and 0 died.
# After 113 generation(s) of COVID; there are 3464 total cases across the population and a total 3355 number of people will be immune.
#
# On day 114, there were 0 new cases. 0 people became immune, and 0 died.
# After 114 generation(s) of COVID; there are 3464 total cases across the population and a total 3356 number of people will be immune.
#
# On day 115, there were 0 new cases. 0 people became immune, and 0 died.
# After 115 generation(s) of COVID; there are 3464 total cases across the population and a total 3357 number of people will be immune.
#
# On day 116, there were 0 new cases. 0 people became immune, and 0 died.
# After 116 generation(s) of COVID; there are 3464 total cases across the population and a total 3358 number of people will be immune.
#
# On day 117, there were 0 new cases. 0 people became immune, and 0 died.
# After 117 generation(s) of COVID; there are 3464 total cases across the population and a total 3359 number of people will be immune.
#
# On day 118, there were 0 new cases. 0 people became immune, and 0 died.
# After 118 generation(s) of COVID; there are 3464 total cases across the population and a total 3360 number of people will be immune.
#
# On day 119, there were 0 new cases. 0 people became immune, and 0 died.
# After 119 generation(s) of COVID; there are 3464 total cases across the population and a total 3361 number of people will be immune.
#
# On day 120, there were 0 new cases. 0 people became immune, and 0 died.
# After 120 generation(s) of COVID; there are 3464 total cases across the population and a total 3362 number of people will be immune.
#
# On day 121, there were 0 new cases. 0 people became immune, and 0 died.
# After 121 generation(s) of COVID; there are 3464 total cases across the population and a total 3363 number of people will be immune.
#
# On day 122, there were 0 new cases. 0 people became immune, and 0 died.
# After 122 generation(s) of COVID; there are 3464 total cases across the population and a total 3364 number of people will be immune.
#
# On day 123, there were 0 new cases. 0 people became immune, and 0 died.
# After 123 generation(s) of COVID; there are 3465 total cases across the population and a total 3365 number of people will be immune.
#
# On day 124, there were 0 new cases. 0 people became immune, and 0 died.
# After 124 generation(s) of COVID; there are 3465 total cases across the population and a total 3366 number of people will be immune.
#
# On day 125, there were 0 new cases. 0 people became immune, and 0 died.
# After 125 generation(s) of COVID; there are 3465 total cases across the population and a total 3367 number of people will be immune.
#
# On day 126, there were 0 new cases. 0 people became immune, and 0 died.
# After 126 generation(s) of COVID; there are 3465 total cases across the population and a total 3368 number of people will be immune.
#
# On day 127, there were 0 new cases. 0 people became immune, and 0 died.
# After 127 generation(s) of COVID; there are 3465 total cases across the population and a total 3369 number of people will be immune.
#
# On day 128, there were 0 new cases. 0 people became immune, and 0 died.
# After 128 generation(s) of COVID; there are 3465 total cases across the population and a total 3370 number of people will be immune.
#
# On day 129, there were 0 new cases. 0 people became immune, and 0 died.
# After 129 generation(s) of COVID; there are 3465 total cases across the population and a total 3371 number of people will be immune.
#
# On day 130, there were 0 new cases. 0 people became immune, and 0 died.
# After 130 generation(s) of COVID; there are 3465 total cases across the population and a total 3372 number of people will be immune.
#
# On day 131, there were 0 new cases. 0 people became immune, and 0 died.
# After 131 generation(s) of COVID; there are 3465 total cases across the population and a total 3373 number of people will be immune.
#
# On day 132, there were 0 new cases. 0 people became immune, and 0 died.
# After 132 generation(s) of COVID; there are 3465 total cases across the population and a total 3374 number of people will be immune.
#
# On day 133, there were 0 new cases. 0 people became immune, and 0 died.
# After 133 generation(s) of COVID; there are 3465 total cases across the population and a total 3375 number of people will be immune.
#
# On day 134, there were 0 new cases. 0 people became immune, and 0 died.
# After 134 generation(s) of COVID; there are 3465 total cases across the population and a total 3376 number of people will be immune.
#
# On day 135, there were 0 new cases. 0 people became immune, and 0 died.
# After 135 generation(s) of COVID; there are 3465 total cases across the population and a total 3377 number of people will be immune.
#
# On day 136, there were 0 new cases. 0 people became immune, and 0 died.
# After 136 generation(s) of COVID; there are 3465 total cases across the population and a total 3378 number of people will be immune.
#
# On day 137, there were 0 new cases. 0 people became immune, and 0 died.
# After 137 generation(s) of COVID; there are 3465 total cases across the population and a total 3379 number of people will be immune.
#
# On day 138, there were 0 new cases. 0 people became immune, and 0 died.
# After 138 generation(s) of COVID; there are 3465 total cases across the population and a total 3380 number of people will be immune.
#
# On day 139, there were 0 new cases. 0 people became immune, and 0 died.
# After 139 generation(s) of COVID; there are 3465 total cases across the population and a total 3381 number of people will be immune.
#
# On day 140, there were 0 new cases. 0 people became immune, and 0 died.
# After 140 generation(s) of COVID; there are 3465 total cases across the population and a total 3382 number of people will be immune.
#
# On day 141, there were 0 new cases. 0 people became immune, and 0 died.
# After 141 generation(s) of COVID; there are 3465 total cases across the population and a total 3383 number of people will be immune.
#
# On day 142, there were 0 new cases. 0 people became immune, and 0 died.
# After 142 generation(s) of COVID; there are 3465 total cases across the population and a total 3384 number of people will be immune.
#
# On day 143, there were 0 new cases. 0 people became immune, and 0 died.
# After 143 generation(s) of COVID; there are 3465 total cases across the population and a total 3385 number of people will be immune.
#
# On day 144, there were 0 new cases. 0 people became immune, and 0 died.
# After 144 generation(s) of COVID; there are 3465 total cases across the population and a total 3386 number of people will be immune.
#
# On day 145, there were 0 new cases. 0 people became immune, and 0 died.
# After 145 generation(s) of COVID; there are 3465 total cases across the population and a total 3387 number of people will be immune.
#
# On day 146, there were 0 new cases. 0 people became immune, and 0 died.
# After 146 generation(s) of COVID; there are 3465 total cases across the population and a total 3388 number of people will be immune.
#
# On day 147, there were 0 new cases. 0 people became immune, and 0 died.
# After 147 generation(s) of COVID; there are 3465 total cases across the population and a total 3389 number of people will be immune.
#
# On day 148, there were 0 new cases. 0 people became immune, and 0 died.
# After 148 generation(s) of COVID; there are 3465 total cases across the population and a total 3390 number of people will be immune.
#
# On day 149, there were 0 new cases. 0 people became immune, and 0 died.
# After 149 generation(s) of COVID; there are 3465 total cases across the population and a total 3391 number of people will be immune.
#
# On day 150, there were 0 new cases. 0 people became immune, and 0 died.
# After 150 generation(s) of COVID; there are 3465 total cases across the population and a total 3392 number of people will be immune.
#
# On day 151, there were 0 new cases. 0 people became immune, and 0 died.
# After 151 generation(s) of COVID; there are 3465 total cases across the population and a total 3393 number of people will be immune.
#
# On day 152, there were 0 new cases. 0 people became immune, and 0 died.
# After 152 generation(s) of COVID; there are 3465 total cases across the population and a total 3394 number of people will be immune.
#
# On day 153, there were 0 new cases. 0 people became immune, and 0 died.
# After 153 generation(s) of COVID; there are 3465 total cases across the population and a total 3395 number of people will be immune.
#
# On day 154, there were 0 new cases. 0 people became immune, and 0 died.
# After 154 generation(s) of COVID; there are 3465 total cases across the population and a total 3396 number of people will be immune.
#
# On day 155, there were 0 new cases. 0 people became immune, and 0 died.
# After 155 generation(s) of COVID; there are 3465 total cases across the population and a total 3397 number of people will be immune.
#
# On day 156, there were 0 new cases. 0 people became immune, and 0 died.
# After 156 generation(s) of COVID; there are 3465 total cases across the population and a total 3398 number of people will be immune.
#
# On day 157, there were 0 new cases. 0 people became immune, and 0 died.
# After 157 generation(s) of COVID; there are 3465 total cases across the population and a total 3399 number of people will be immune.
#
# On day 158, there were 0 new cases. 0 people became immune, and 0 died.
# After 158 generation(s) of COVID; there are 3465 total cases across the population and a total 3400 number of people will be immune.
#
# On day 159, there were 0 new cases. 0 people became immune, and 0 died.
# After 159 generation(s) of COVID; there are 3465 total cases across the population and a total 3401 number of people will be immune.
#
# On day 160, there were 0 new cases. 0 people became immune, and 0 died.
# After 160 generation(s) of COVID; there are 3465 total cases across the population and a total 3402 number of people will be immune.
#
# On day 161, there were 0 new cases. 0 people became immune, and 0 died.
# After 161 generation(s) of COVID; there are 3465 total cases across the population and a total 3403 number of people will be immune.
#
# On day 162, there were 0 new cases. 0 people became immune, and 0 died.
# After 162 generation(s) of COVID; there are 3465 total cases across the population and a total 3404 number of people will be immune.
#
# On day 163, there were 0 new cases. 0 people became immune, and 0 died.
# After 163 generation(s) of COVID; there are 3465 total cases across the population and a total 3405 number of people will be immune.
#
# On day 164, there were 0 new cases. 0 people became immune, and 0 died.
# After 164 generation(s) of COVID; there are 3465 total cases across the population and a total 3406 number of people will be immune.
#
# On day 165, there were 0 new cases. 0 people became immune, and 0 died.
# After 165 generation(s) of COVID; there are 3465 total cases across the population and a total 3407 number of people will be immune.
#
# On day 166, there were 0 new cases. 0 people became immune, and 0 died.
# After 166 generation(s) of COVID; there are 3465 total cases across the population and a total 3408 number of people will be immune.
#
# On day 167, there were 0 new cases. 0 people became immune, and 0 died.
# After 167 generation(s) of COVID; there are 3465 total cases across the population and a total 3409 number of people will be immune.
#
# On day 168, there were 0 new cases. 0 people became immune, and 0 died.
# After 168 generation(s) of COVID; there are 3465 total cases across the population and a total 3410 number of people will be immune.
#
# On day 169, there were 0 new cases. 0 people became immune, and 0 died.
# After 169 generation(s) of COVID; there are 3465 total cases across the population and a total 3411 number of people will be immune.
#
# On day 170, there were 0 new cases. 0 people became immune, and 0 died.
# After 170 generation(s) of COVID; there are 3465 total cases across the population and a total 3412 number of people will be immune.
#
# On day 171, there were 0 new cases. 0 people became immune, and 0 died.
# After 171 generation(s) of COVID; there are 3465 total cases across the population and a total 3413 number of people will be immune.
#
# On day 172, there were 0 new cases. 0 people became immune, and 0 died.
# After 172 generation(s) of COVID; there are 3465 total cases across the population and a total 3414 number of people will be immune.
#
# On day 173, there were 0 new cases. 0 people became immune, and 0 died.
# After 173 generation(s) of COVID; there are 3465 total cases across the population and a total 3415 number of people will be immune.
#
# On day 174, there were 0 new cases. 0 people became immune, and 0 died.
# After 174 generation(s) of COVID; there are 3465 total cases across the population and a total 3416 number of people will be immune.
#
# On day 175, there were 0 new cases. 0 people became immune, and 0 died.
# After 175 generation(s) of COVID; there are 3465 total cases across the population and a total 3417 number of people will be immune.
#
# On day 176, there were 0 new cases. 0 people became immune, and 0 died.
# After 176 generation(s) of COVID; there are 3465 total cases across the population and a total 3418 number of people will be immune.
#
# On day 177, there were 0 new cases. 0 people became immune, and 0 died.
# After 177 generation(s) of COVID; there are 3465 total cases across the population and a total 3419 number of people will be immune.
#
# On day 178, there were 0 new cases. 0 people became immune, and 0 died.
# After 178 generation(s) of COVID; there are 3465 total cases across the population and a total 3420 number of people will be immune.
#
# On day 179, there were 0 new cases. 0 people became immune, and 0 died.
# After 179 generation(s) of COVID; there are 3465 total cases across the population and a total 3421 number of people will be immune.
#
# On day 180, there were 0 new cases. 0 people became immune, and 0 died.
# After 180 generation(s) of COVID; there are 3465 total cases across the population and a total 3422 number of people will be immune.
#
# On day 181, there were 0 new cases. 0 people became immune, and 0 died.
# After 181 generation(s) of COVID; there are 3465 total cases across the population and a total 3423 number of people will be immune.
#
# On day 182, there were 0 new cases. 0 people became immune, and 0 died.
# After 182 generation(s) of COVID; there are 3465 total cases across the population and a total 3424 number of people will be immune.
#
# On day 183, there were 0 new cases. 0 people became immune, and 0 died.
# After 183 generation(s) of COVID; there are 3465 total cases across the population and a total 3425 number of people will be immune.
#
# On day 184, there were 0 new cases. 0 people became immune, and 0 died.
# After 184 generation(s) of COVID; there are 3465 total cases across the population and a total 3426 number of people will be immune.
#
# On day 185, there were 0 new cases. 0 people became immune, and 0 died.
# After 185 generation(s) of COVID; there are 3465 total cases across the population and a total 3427 number of people will be immune.
#
# On day 186, there were 0 new cases. 0 people became immune, and 0 died.
# After 186 generation(s) of COVID; there are 3465 total cases across the population and a total 3428 number of people will be immune.
#
# On day 187, there were 0 new cases. 0 people became immune, and 0 died.
# After 187 generation(s) of COVID; there are 3465 total cases across the population and a total 3429 number of people will be immune.
#
# On day 188, there were 0 new cases. 0 people became immune, and 0 died.
# After 188 generation(s) of COVID; there are 3465 total cases across the population and a total 3430 number of people will be immune.
#
# On day 189, there were 0 new cases. 0 people became immune, and 0 died.
# After 189 generation(s) of COVID; there are 3465 total cases across the population and a total 3431 number of people will be immune.
#
# On day 190, there were 0 new cases. 0 people became immune, and 0 died.
# After 190 generation(s) of COVID; there are 3465 total cases across the population and a total 3432 number of people will be immune.
#
# On day 191, there were 0 new cases. 0 people became immune, and 0 died.
# After 191 generation(s) of COVID; there are 3465 total cases across the population and a total 3433 number of people will be immune.
#
# On day 192, there were 0 new cases. 0 people became immune, and 0 died.
# After 192 generation(s) of COVID; there are 3465 total cases across the population and a total 3434 number of people will be immune.
#
# On day 193, there were 0 new cases. 0 people became immune, and 0 died.
# After 193 generation(s) of COVID; there are 3465 total cases across the population and a total 3435 number of people will be immune.
#
# On day 194, there were 0 new cases. 0 people became immune, and 0 died.
# After 194 generation(s) of COVID; there are 3465 total cases across the population and a total 3436 number of people will be immune.
#
# On day 195, there were 0 new cases. 0 people became immune, and 0 died.
# After 195 generation(s) of COVID; there are 3465 total cases across the population and a total 3437 number of people will be immune.
#
# On day 196, there were 0 new cases. 0 people became immune, and 0 died.
# After 196 generation(s) of COVID; there are 3465 total cases across the population and a total 3438 number of people will be immune.
#
# On day 197, there were 0 new cases. 0 people became immune, and 0 died.
# After 197 generation(s) of COVID; there are 3465 total cases across the population and a total 3439 number of people will be immune.
#
# On day 198, there were 0 new cases. 0 people became immune, and 0 died.
# After 198 generation(s) of COVID; there are 3465 total cases across the population and a total 3440 number of people will be immune.
#
# On day 199, there were 0 new cases. 0 people became immune, and 0 died.
# After 199 generation(s) of COVID; there are 3465 total cases across the population and a total 3441 number of people will be immune.
#
# On day 200, there were 0 new cases. 0 people became immune, and 0 died.
# After 200 generation(s) of COVID; there are 3465 total cases across the population and a total 3442 number of people will be immune.
#
# On day 201, there were 0 new cases. 0 people became immune, and 0 died.
# After 201 generation(s) of COVID; there are 3465 total cases across the population and a total 3443 number of people will be immune.
#
# On day 202, there were 0 new cases. 0 people became immune, and 0 died.
# After 202 generation(s) of COVID; there are 3465 total cases across the population and a total 3444 number of people will be immune.
#
# On day 203, there were 0 new cases. 0 people became immune, and 0 died.
# After 203 generation(s) of COVID; there are 3465 total cases across the population and a total 3445 number of people will be immune.
#
# On day 204, there were 0 new cases. 0 people became immune, and 0 died.
# After 204 generation(s) of COVID; there are 3465 total cases across the population and a total 3446 number of people will be immune.
#
# On day 205, there were 0 new cases. 0 people became immune, and 0 died.
# After 205 generation(s) of COVID; there are 3465 total cases across the population and a total 3447 number of people will be immune.
#
# On day 206, there were 0 new cases. 0 people became immune, and 0 died.
# After 206 generation(s) of COVID; there are 3465 total cases across the population and a total 3448 number of people will be immune.
#
# On day 207, there were 0 new cases. 0 people became immune, and 0 died.
# After 207 generation(s) of COVID; there are 3465 total cases across the population and a total 3449 number of people will be immune.
#
# On day 208, there were 0 new cases. 0 people became immune, and 0 died.
# After 208 generation(s) of COVID; there are 3465 total cases across the population and a total 3450 number of people will be immune.
#
# On day 209, there were 0 new cases. 0 people became immune, and 0 died.
# After 209 generation(s) of COVID; there are 3465 total cases across the population and a total 3451 number of people will be immune.
#
# On day 210, there were 0 new cases. 0 people became immune, and 0 died.
# After 210 generation(s) of COVID; there are 3465 total cases across the population and a total 3452 number of people will be immune.
#
# On day 211, there were 0 new cases. 0 people became immune, and 0 died.
# After 211 generation(s) of COVID; there are 3465 total cases across the population and a total 3453 number of people will be immune.
#
# On day 212, there were 0 new cases. 0 people became immune, and 0 died.
# After 212 generation(s) of COVID; there are 3465 total cases across the population and a total 3454 number of people will be immune.
#
# On day 213, there were 0 new cases. 0 people became immune, and 0 died.
# After 213 generation(s) of COVID; there are 3465 total cases across the population and a total 3455 number of people will be immune.
#
# On day 214, there were 0 new cases. 0 people became immune, and 0 died.
# After 214 generation(s) of COVID; there are 3465 total cases across the population and a total 3456 number of people will be immune.
#
# On day 215, there were 0 new cases. 0 people became immune, and 0 died.
# After 215 generation(s) of COVID; there are 3465 total cases across the population and a total 3457 number of people will be immune.
#
# On day 216, there were 0 new cases. 0 people became immune, and 0 died.
# After 216 generation(s) of COVID; there are 3465 total cases across the population and a total 3458 number of people will be immune.
#
# On day 217, there were 0 new cases. 0 people became immune, and 0 died.
# After 217 generation(s) of COVID; there are 3465 total cases across the population and a total 3459 number of people will be immune.
#
# On day 218, there were 0 new cases. 0 people became immune, and 0 died.
# After 218 generation(s) of COVID; there are 3465 total cases across the population and a total 3460 number of people will be immune.
#
# On day 219, there were 0 new cases. 0 people became immune, and 0 died.
# After 219 generation(s) of COVID; there are 3465 total cases across the population and a total 3461 number of people will be immune.
#
# On day 220, there were 0 new cases. 0 people became immune, and 0 died.
# After 220 generation(s) of COVID; there are 3465 total cases across the population and a total 3462 number of people will be immune.
#
# On day 221, there were 0 new cases. 0 people became immune, and 0 died.
# After 221 generation(s) of COVID; there are 3465 total cases across the population and a total 3463 number of people will be immune.
#
# On day 222, there were 0 new cases. 0 people became immune, and 0 died.
# After 222 generation(s) of COVID; there are 3465 total cases across the population and a total 3464 number of people will be immune.
#
# On day 223, there were 0 new cases. 0 people became immune, and 0 died.
# After 223 generation(s) of COVID; there are 3465 total cases across the population and a total 3465 number of people will be immune.
#
# On day 224, there were 0 new cases. 0 people became immune, and 0 died.
# After 224 generation(s) of COVID; there are 3465 total cases across the population and a total 3466 number of people will be immune.
#
# On day 225, there were 0 new cases. 0 people became immune, and 0 died.
# After 225 generation(s) of COVID; there are 3465 total cases across the population and a total 3467 number of people will be immune.
#
# On day 226, there were 0 new cases. 0 people became immune, and 0 died.
# After 226 generation(s) of COVID; there are 3465 total cases across the population and a total 3468 number of people will be immune.
#
# On day 227, there were 0 new cases. 0 people became immune, and 0 died.
# After 227 generation(s) of COVID; there are 3465 total cases across the population and a total 3469 number of people will be immune.
#
# On day 228, there were 0 new cases. 0 people became immune, and 0 died.
# After 228 generation(s) of COVID; there are 3465 total cases across the population and a total 3470 number of people will be immune.
#
# On day 229, there were 0 new cases. 0 people became immune, and 0 died.
# After 229 generation(s) of COVID; there are 3465 total cases across the population and a total 3471 number of people will be immune.
#
# On day 230, there were 0 new cases. 0 people became immune, and 0 died.
# After 230 generation(s) of COVID; there are 3465 total cases across the population and a total 3472 number of people will be immune.
#
# On day 231, there were 0 new cases. 0 people became immune, and 0 died.
# ...
# On day 294, there were 0 new cases. 0 people became immune, and 0 died.
# After 294 generation(s) of COVID; there are 3465 total cases across the population and a total 3536 number of people will be immune.
#
# On day 295, there were 0 new cases. 0 people became immune, and 0 died.
# After 295 generation(s) of COVID; there are 3465 total cases across the population and a total 3537 number of people will be immune.
#
# On day 296, there were 0 new cases. 0 people became immune, and 0 died.
# After 296 generation(s) of COVID; there are 3465 total cases across the population and a total 3538 number of people will be immune.
#
# On day 297, there were 0 new cases. 0 people became immune, and 0 died.
# After 297 generation(s) of COVID; there are 3465 total cases across the population and a total 3539 number of people will be immune.
#
# On day 298, there were 0 new cases. 0 people became immune, and 0 died.
# After 298 generation(s) of COVID; there are 3465 total cases across the population and a total 3540 number of people will be immune.
#
# On day 299, there were 0 new cases. 0 people became immune, and 0 died.
# After 299 generation(s) of COVID; there are 3465 total cases across the population and a total 3541 number of people will be immune.
#
# On day 300, there were 0 new cases. 0 people became immune, and 0 died.
# After 300 generation(s) of COVID; there are 3465 total cases across the population and a total 3542 number of people will be immune.
#
# On day 301, there were 0 new cases. 0 people became immune, and 0 died.
# After 301 generation(s) of COVID; there are 3465 total cases across the population and a total 3543 number of people will be immune.
#
# On day 302, there were 0 new cases. 0 people became immune, and 0 died.
# After 302 generation(s) of COVID; there are 3465 total cases across the population and a total 3544 number of people will be immune.
#
# On day 303, there were 0 new cases. 0 people became immune, and 0 died.
# After 303 generation(s) of COVID; there are 3465 total cases across the population and a total 3545 number of people will be immune.
#
# On day 304, there were 0 new cases. 0 people became immune, and 0 died.
# After 304 generation(s) of COVID; there are 3465 total cases across the population and a total 3546 number of people will be immune.
#
# On day 305, there were 0 new cases. 0 people became immune, and 0 died.
# After 305 generation(s) of COVID; there are 3465 total cases across the population and a total 3547 number of people will be immune.
#
# On day 306, there were 0 new cases. 0 people became immune, and 0 died.
# After 306 generation(s) of COVID; there are 3465 total cases across the population and a total 3548 number of people will be immune.
#
# On day 307, there were 0 new cases. 0 people became immune, and 0 died.
# After 307 generation(s) of COVID; there are 3465 total cases across the population and a total 3549 number of people will be immune.
#
# On day 308, there were 0 new cases. 0 people became immune, and 0 died.
# After 308 generation(s) of COVID; there are 3465 total cases across the population and a total 3550 number of people will be immune.
#
# On day 309, there were 0 new cases. 0 people became immune, and 0 died.
# After 309 generation(s) of COVID; there are 3465 total cases across the population and a total 3551 number of people will be immune.
#
# On day 310, there were 0 new cases. 0 people became immune, and 0 died.
# After 310 generation(s) of COVID; there are 3465 total cases across the population and a total 3552 number of people will be immune.
#
# On day 311, there were 0 new cases. 0 people became immune, and 0 died.
# After 311 generation(s) of COVID; there are 3465 total cases across the population and a total 3553 number of people will be immune.
#
# On day 312, there were 0 new cases. 0 people became immune, and 0 died.
# After 312 generation(s) of COVID; there are 3465 total cases across the population and a total 3554 number of people will be immune.
#
# On day 313, there were 0 new cases. 0 people became immune, and 0 died.
# After 313 generation(s) of COVID; there are 3465 total cases across the population and a total 3555 number of people will be immune.
#
# On day 314, there were 0 new cases. 0 people became immune, and 0 died.
# After 314 generation(s) of COVID; there are 3465 total cases across the population and a total 3556 number of people will be immune.
#
# On day 315, there were 0 new cases. 0 people became immune, and 0 died.
# After 315 generation(s) of COVID; there are 3465 total cases across the population and a total 3557 number of people will be immune.
#
# On day 316, there were 0 new cases. 0 people became immune, and 0 died.
# After 316 generation(s) of COVID; there are 3465 total cases across the population and a total 3558 number of people will be immune.
#
# On day 317, there were 0 new cases. 0 people became immune, and 0 died.
# After 317 generation(s) of COVID; there are 3465 total cases across the population and a total 3559 number of people will be immune.
#
# On day 318, there were 0 new cases. 0 people became immune, and 0 died.
# After 318 generation(s) of COVID; there are 3465 total cases across the population and a total 3560 number of people will be immune.
#
# On day 319, there were 0 new cases. 0 people became immune, and 0 died.
# After 319 generation(s) of COVID; there are 3465 total cases across the population and a total 3561 number of people will be immune.
#
# On day 320, there were 0 new cases. 0 people became immune, and 0 died.
# After 320 generation(s) of COVID; there are 3465 total cases across the population and a total 3562 number of people will be immune.
#
# On day 321, there were 0 new cases. 0 people became immune, and 0 died.
# After 321 generation(s) of COVID; there are 3465 total cases across the population and a total 3563 number of people will be immune.
#
# On day 322, there were 0 new cases. 0 people became immune, and 0 died.
# After 322 generation(s) of COVID; there are 3465 total cases across the population and a total 3564 number of people will be immune.
#
# On day 323, there were 0 new cases. 0 people became immune, and 0 died.
# After 323 generation(s) of COVID; there are 3465 total cases across the population and a total 3565 number of people will be immune.
#
# On day 324, there were 0 new cases. 0 people became immune, and 0 died.
# After 324 generation(s) of COVID; there are 3465 total cases across the population and a total 3566 number of people will be immune.
#
# On day 325, there were 0 new cases. 0 people became immune, and 0 died.
# After 325 generation(s) of COVID; there are 3465 total cases across the population and a total 3567 number of people will be immune.
#
# On day 326, there were 0 new cases. 0 people became immune, and 0 died.
# After 326 generation(s) of COVID; there are 3465 total cases across the population and a total 3568 number of people will be immune.
#
# On day 327, there were 0 new cases. 0 people became immune, and 0 died.
# After 327 generation(s) of COVID; there are 3465 total cases across the population and a total 3569 number of people will be immune.
#
# On day 328, there were 0 new cases. 0 people became immune, and 0 died.
# After 328 generation(s) of COVID; there are 3465 total cases across the population and a total 3570 number of people will be immune.
#
# On day 329, there were 0 new cases. 0 people became immune, and 0 died.
# After 329 generation(s) of COVID; there are 3465 total cases across the population and a total 3571 number of people will be immune.
#
# On day 330, there were 0 new cases. 0 people became immune, and 0 died.
# After 330 generation(s) of COVID; there are 3465 total cases across the population and a total 3572 number of people will be immune.
#
# On day 331, there were 0 new cases. 0 people became immune, and 0 died.
# After 331 generation(s) of COVID; there are 3465 total cases across the population and a total 3573 number of people will be immune.
#
# On day 332, there were 0 new cases. 0 people became immune, and 0 died.
# After 332 generation(s) of COVID; there are 3465 total cases across the population and a total 3574 number of people will be immune.
#
# On day 333, there were 0 new cases. 0 people became immune, and 0 died.
# After 333 generation(s) of COVID; there are 3465 total cases across the population and a total 3575 number of people will be immune.
#
# On day 334, there were 0 new cases. 0 people became immune, and 0 died.
# After 334 generation(s) of COVID; there are 3465 total cases across the population and a total 3576 number of people will be immune.
#
# On day 335, there were 0 new cases. 0 people became immune, and 0 died.
# After 335 generation(s) of COVID; there are 3465 total cases across the population and a total 3577 number of people will be immune.
#
# On day 336, there were 0 new cases. 0 people became immune, and 0 died.
# After 336 generation(s) of COVID; there are 3465 total cases across the population and a total 3578 number of people will be immune.
#
# On day 337, there were 0 new cases. 0 people became immune, and 0 died.
# After 337 generation(s) of COVID; there are 3465 total cases across the population and a total 3579 number of people will be immune.
#
# On day 338, there were 0 new cases. 0 people became immune, and 0 died.
# After 338 generation(s) of COVID; there are 3465 total cases across the population and a total 3580 number of people will be immune.
#
# On day 339, there were 0 new cases. 0 people became immune, and 0 died.
# After 339 generation(s) of COVID; there are 3465 total cases across the population and a total 3581 number of people will be immune.
#
# On day 340, there were 0 new cases. 0 people became immune, and 0 died.
# After 340 generation(s) of COVID; there are 3465 total cases across the population and a total 3582 number of people will be immune.
#
# On day 341, there were 0 new cases. 0 people became immune, and 0 died.
# After 341 generation(s) of COVID; there are 3465 total cases across the population and a total 3583 number of people will be immune.
#
# On day 342, there were 0 new cases. 0 people became immune, and 0 died.
# After 342 generation(s) of COVID; there are 3465 total cases across the population and a total 3584 number of people will be immune.
#
# On day 343, there were 0 new cases. 0 people became immune, and 0 died.
# After 343 generation(s) of COVID; there are 3465 total cases across the population and a total 3585 number of people will be immune.
#
# On day 344, there were 0 new cases. 0 people became immune, and 0 died.
# After 344 generation(s) of COVID; there are 3465 total cases across the population and a total 3586 number of people will be immune.
#
# On day 345, there were 0 new cases. 0 people became immune, and 0 died.
# After 345 generation(s) of COVID; there are 3465 total cases across the population and a total 3587 number of people will be immune.
#
# On day 346, there were 0 new cases. 0 people became immune, and 0 died.
# After 346 generation(s) of COVID; there are 3465 total cases across the population and a total 3588 number of people will be immune.
#
# On day 347, there were 0 new cases. 0 people became immune, and 0 died.
# After 347 generation(s) of COVID; there are 3465 total cases across the population and a total 3589 number of people will be immune.
#
# On day 348, there were 0 new cases. 0 people became immune, and 0 died.
# After 348 generation(s) of COVID; there are 3465 total cases across the population and a total 3590 number of people will be immune.
#
# On day 349, there were 0 new cases. 0 people became immune, and 0 died.
# After 349 generation(s) of COVID; there are 3465 total cases across the population and a total 3591 number of people will be immune.
#
# On day 350, there were 0 new cases. 0 people became immune, and 0 died.
# After 350 generation(s) of COVID; there are 3465 total cases across the population and a total 3592 number of people will be immune.
#
# On day 351, there were 0 new cases. 0 people became immune, and 0 died.
# After 351 generation(s) of COVID; there are 3465 total cases across the population and a total 3593 number of people will be immune.
#
# On day 352, there were 0 new cases. 0 people became immune, and 0 died.
# After 352 generation(s) of COVID; there are 3465 total cases across the population and a total 3594 number of people will be immune.
#
# On day 353, there were 0 new cases. 0 people became immune, and 0 died.
# After 353 generation(s) of COVID; there are 3465 total cases across the population and a total 3595 number of people will be immune.
#
# On day 354, there were 0 new cases. 0 people became immune, and 0 died.
# After 354 generation(s) of COVID; there are 3465 total cases across the population and a total 3596 number of people will be immune.
#
# On day 355, there were 0 new cases. 0 people became immune, and 0 died.
# After 355 generation(s) of COVID; there are 3465 total cases across the population and a total 3597 number of people will be immune.
#
# On day 356, there were 0 new cases. 0 people became immune, and 0 died.
# After 356 generation(s) of COVID; there are 3465 total cases across the population and a total 3598 number of people will be immune.
#
# On day 357, there were 0 new cases. 0 people became immune, and 0 died.
# After 357 generation(s) of COVID; there are 3465 total cases across the population and a total 3599 number of people will be immune.
#
# On day 358, there were 0 new cases. 0 people became immune, and 0 died.
# After 358 generation(s) of COVID; there are 3465 total cases across the population and a total 3600 number of people will be immune.
#
# On day 359, there were 0 new cases. 0 people became immune, and 0 died.
# After 359 generation(s) of COVID; there are 3465 total cases across the population and a total 3601 number of people will be immune.
#
# On day 360, there were 0 new cases. 0 people became immune, and 0 died.
# After 360 generation(s) of COVID; there are 3465 total cases across the population and a total 3602 number of people will be immune.
#
# On day 361, there were 0 new cases. 0 people became immune, and 0 died.
# After 361 generation(s) of COVID; there are 3465 total cases across the population and a total 3603 number of people will be immune.
#
# On day 362, there were 0 new cases. 0 people became immune, and 0 died.
# After 362 generation(s) of COVID; there are 3465 total cases across the population and a total 3604 number of people will be immune.
#
# On day 363, there were 0 new cases. 0 people became immune, and 0 died.
# After 363 generation(s) of COVID; there are 3465 total cases across the population and a total 3605 number of people will be immune.
#
# On day 364, there were 0 new cases. 0 people became immune, and 0 died.
# After 364 generation(s) of COVID; there are 3465 total cases across the population and a total 3606 number of people will be immune.
#
# On day 365, there were 0 new cases. 0 people became immune, and 0 died.
# After 365 generation(s) of COVID; there are 3465 total cases across the population and a total 3607 number of people will be immune.
#
#      Number of Generations  Percentage of individuals with immunity
# 0                        0                                 0.237144
# 1                        1                                 0.473705
# 2                        2                                 0.709103
# 3                        3                                 0.942769
# 4                        4                                 1.174151
# ..                     ...                                      ...
# 361                    361                                 7.205792
# 362                    362                                 7.207792
# 363                    363                                 7.209792
# 364                    364                                 7.211792
# 365                    365                                 7.213792
#
# [366 rows x 2 columns]
# Do you want to save the report to a file? Enter yes or no: yes
# Your file name will be "ImmunityTable"
# How would you like your file to be opened? Enter append or write: write
# I have successfully saved the dat under "ImmunityTable". The program is complete.

# %%
vac_graph()
# Out:
# What is the approximate population size of your city/town? 50000
# What was the daily rise in number of cases in your area? 123
# How many days would you like to cycle through: 365
# Would you like the transmission rate to be a high or low estimate? Please enter "High" or "Low". high
# What country in the UK is your town or city? Scotland
# What is the vaccine used?anticovid
# What is the efficiency of the vaccine in percentage? 97
# How many people are being vaccinated in your city/town per day? 200
# The transmission rate for Scotland is 1.0.
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-4-a8b233ff2dcf> in <module>
# ----> 1 vac_graph()
#
# <ipython-input-2-0c8836efd7aa> in vac_graph()
#     321
#     322     import pandas as pd
# --> 323     vac_table()
#     324     tdf= pd.read_csv("VacImmunityTable",sep=" ") #reads file to collect the data
#     325     tdf.shape
#
# <ipython-input-2-0c8836efd7aa> in vac_table()
#     268 def vac_table():
#     269     '''Function to display and save to a file the data to be displayed in a graph'''
# --> 270     total_cases, vac_total_immunity, total_death, total_generation, vac_immune_list, vac_immune_percentages = vac_calculations()
#     271
#     272     #imports a software libraries needed to complete the program
#
# <ipython-input-2-0c8836efd7aa> in vac_calculations()
#     254                 vac_total_immunity.append(gen_immunity) #adds to the total number of immune
#     255             print('In generation {}, there were {:.0f} cases, after an increase of {:.0f}. {:.0f} people became immune, and {:.0f} died.'.format(t, new_cases,
# --> 256                                                                                                                                daily_rate, vimmunity, death))
#     257             print('After {} generation(s) of COVID, {:.0f} number of people will be immune.'.format(t,sum(vac_total_immunity)))
#     258             daily_rate = new_cases
#
# UnboundLocalError: local variable 'daily_rate' referenced before assignment
