# %%
def user():
    
    '''Function that asks for the user for values that will be used throughout the rest of the program.'''
    try: 
        population = int(input('What is the approximate population size of your city/town? ')) #Asks the user for the total population (number of individuals who can become suseptible.)
        daily_rise = int(input('What was the daily rise in number of cases in your area? ')) #Asks the user for the the number of cases (Thus the number of infectives in the first year)
        num_gen= int(input('How many days would you like to cycle through: ')) #The number of generations indicated how many data points the user wants.
    except:
        print('Error: Please enter numbers only and try again.')
        covid_model()
    high_or_low = input('Would you like the transmission rate to be a high or low estimate? Please enter "High" or "Low". ').capitalize() #Asks the user for what type of estimate they would like
    try:
        if high_or_low == 'Low': #if the user wants a low estimate
            low_estimate = {'England':0.8, 'Northen Ireland':0.9, 'Scotland':0.8, 'Wales':0.8} #low estimates for UK values
            country = input('What country in the UK is your town or city? ').capitalize() #answer used to select from the dictionary
            trans_rate = low_estimate[country] #pulls the estimate from the dictionary
            return trans_rate, country, num_gen, daily_rise, population
        
        else: # For high estimate
            high_estimate={'England':1.0, 'Northen Ireland':1.1, 'Scotland':1.0, 'Wales':1.0} #high estimates for UK values
            country = input('What country in the UK is your town or city? ').capitalize() #answer used to select from the dictionary
            trans_rate = high_estimate[country] #pulls the estimate from the dictionary
            return trans_rate, country, num_gen, daily_rise, population
    except:
        print('Error: {} is not a valid entry. Please enter a country in the UK and try again.'.format(country))
        covid_model()

# %%
def calculations(trans_rate, country, num_gen, daily_rise, population):
    
    '''Function to Calculate the number of individuals who gain immunity each generation without the inclusion of a vaccine.'''
    
    
    print('The transmission rate for {} is {}. '.format(country, trans_rate)) #informs the user of the information they did not directly imput
    mr= 0.036 #the UK mortality rate for the corona virus
    zero_death = (daily_rise*mr) #number of individuals that died from the cases the user provided (at time zero)
    zero_immunity = daily_rise - zero_death #number of individuals that gained immunity from the cases the user provides (at time zero)
    #length= int(num_gen) + 1 #the number of generations the user provided +1 so that the for program goes through the required amount of times
    gen = range(1, num_gen + 1) #list of all generations
    total_cases = [daily_rise] #a list of all the cases - that for now only includes the daily rise
    total_immunity = [zero_immunity] #list of number of individuals immune each generation
    total_death = [zero_death] #list of number of individuals died each generation
    total_generation= [0] #creates a list of the generation numbers
    immune_list = [zero_immunity] #Sum of total immunity each generation
    immune_percentage=[]
    infections = []
    gen_death = []
    death_percentage = []
    infect_percentage =[]
    
    import collections
    infectious = collections.deque(maxlen=3)
    infectious.append(daily_rise)
   
    for t in gen: #Sequences through all generations
        
        sum_cases = sum(total_cases) #sums all the number of cases
        
        if daily_rise == 0: #if total number of cases is larger than the population or there are no more cases
            
            print('All of the population has been processed.')
            recovered = sum(total_immunity) #number of people who recovered
            total_infectious = sum(infectious)
            I= total_infectious #number of people who are infectious #number of people who are infectious
            portion_infected = I/population #the portion of the individuals who 
            not_in_population = (recovered + sum(total_death)) #sum of the people no longer suseptible either immune or dead
            S = (population-not_in_population) #removes those who are not suseptible from the population
            portion_S = (S/population) #portion of the people suseptible
            new_cases = portion_S*I*trans_rate #number of new cases: portion of individuals in the population who are suseptible * infected (contagious) * transmission rate
            infectious.append(new_cases)
            total_cases.append(new_cases)#adds to the total number of cases
            
            death = (new_cases)*0.036 #portion of those infected who died
            total_death.append(death) #adds to the total number of deaths
            immunity = new_cases - death #individuals who are immune that generation
            total_immunity.append(immunity) #adds to the total number of immune
            print('On day {}, there were {:.0f} cases, after an increase of {:.0f}. {:.0f} people became immune, and {:.0f} died.'.format(t, new_cases, 
                                                                                                                               daily_rise, immunity, death))
            print('After {} day(s) of COVID, {:.0f} number of people will be immune.'.format(t,sum(total_immunity))) 
            daily_rise = new_cases
            print(' ')
            immune_list.append(sum(total_immunity))
            break
           
        else:
            recovered = sum(total_immunity) #number of people who recovered
            total_infectious = sum(infectious)
            I= total_infectious #number of people who are infectious #number of people who are infectious
            portion_infected= I/population #the portion of the individuals who 
            not_in_population = (recovered + sum(total_death)) #sum of the people no longer suseptible either immune or dead
            S = (population-not_in_population) #removes those who are not suseptible from the population
            portion_S = (S/population) #portion of the people suseptible
            new_cases = portion_S*I*trans_rate #number of new cases: portion of individuals in the population who are suseptible * infected (contagious) * transmission rate
            infectious.append(new_cases)
            if new_cases <= 0.5:
                pass
            else:
                total_generation.append(t) #adds a number to the total generation
                total_cases.append(new_cases) #adds to the total number of cases
                death = (new_cases)*0.036 #portion of those infected who died

                if death < 1:
                    total_death.append(1) #adds to the total number of deaths
                else:
                    total_death.append(death) #adds to the total number of deaths
                immunity = new_cases - death #individuals who are immune that generation

                if immunity < 1:
                        total_immunity.append(1) 
                else:
                    total_immunity.append(immunity) #adds to the total number of immune
                print('On day {}, there were {:.0f} new cases. {:.0f} people became immune, and {:.0f} died.'.format(t, new_cases, 
                                                                                                                 immunity, death))
                print('After {} day(s) of COVID; there are {:.0f} total cases across the population and a total {:.0f} number of people will be immune.'.format(t, sum(total_cases),
                                                                                                                                                                  sum(total_immunity))) 
                daily_rise = new_cases
                print(' ')
                immune_list.append(sum(total_immunity))
                infections.append(sum(total_cases))
                gen_death.append(sum(total_death))
    #The percentage is calculated and added to the list
    
    for immune in immune_list:
        percentage=immune/population*100
        immune_percentage.append(percentage)
    for infect in infections:
        inf_percentage = infect/population*100
        infect_percentage.append(inf_percentage)
    for d in gen_death:
        death_p = d/population*100
        death_percentage.append(death_p)
    
    return total_cases, total_immunity, total_death, total_generation, immune_list, immune_percentage, infect_percentage, death_percentage

# %%
def table(total_cases, total_immunity, total_death, total_generation, immune_list, immune_percentage,infect_percentage, death_percentage):
    
    '''Function to display and save to a file the data to be displayed in a graph'''
    
    
    #imports a software libraries needed to complete the program
    
    import pandas as pd
    import numpy as np
    
    #creates a dictionary of the number of generations vs the sum of the individuals with immunity
    
    data = {
    'Number of Generations': total_generation,
    'Number of individuals with immunity': immune_percentage,
    'Number of infections': infect_percentage,
    'Number of deaths': death_percentage
        }
    
    #prints the information in data to a table
    table = pd.DataFrame.from_dict(data,orient='index')
    table = table.transpose()
    print(table)
    numpy_array = table.to_numpy()
    print(' ')
    
    decide = input('Do you want to save the report to a file? Enter yes or no: ').capitalize() #ask if they want to save a file
    if decide == 'Yes': #If they input yes
        #currently only input that works is Gen
        print('Your file name will be "ImmunityTable"') 

        how = input('How would you like your file to be opened? Enter append or write: ').capitalize() #ask how they want the data to be saved

            #confirm_how = input('Confirm editing format with yes or no: ').capitalize() #ask for confirmation

            #if confirm_how == 'No':#if enter no
               # how = input('How would you like your file to be opened? Enter append or write: ') #allowed to enter again

        if how == 'Write': #write the following into the provided file
            file = open('ImmunityTable', 'w')
            np.savetxt('ImmunityTable' , numpy_array, fmt = "%d")
            file.close()
            print('I have successfully saved the data under "ImmunityTable". The program is complete.')

        elif how == 'Append': #append the following into the provided file
            file = open('ImmunityTable', 'a')
            np.savetxt('ImmunityTable' , numpy_array, fmt = "%d")
            file.close()
            print('I have successfully saved the data under "ImmunityTable" The program is complete.')
            
        else:
            print('Error: I do not understand command "{}". Please enter either "Write" or "Append" and try again.'.format(how))
            covid_model()
    
    else:#if the user doesn't want to save a file.
        print('Okay, I will not save the data. The program is complete.')

# %%
def graph(total_cases,total_immunity,total_death, total_generation,immune_list, immune_percentage, infect_percentage, death_percentage):
    '''Function which prints a graph of established data'''
    
    import pandas as pd
    
    tdf= pd.read_csv("ImmunityTable",sep=" ") #reads file to collect the data
    tdf.shape
    tdf=pd.read_csv("ImmunityTable",sep=" ",names=["Number of days", "Immunity (as percentage of the population)", "Deaths", "Infections"]) #creates headers for the graph
    tdf.head()
    tdf.plot(x="Number of days",y=["Immunity (as percentage of the population)","Deaths","Infections"]) #plots the data

# %%
def vac_user():
    
    '''Function to ask the user for the vaccine data and efficiency, and calculate how many people become immune from 
    the vaccine per generation'''  
    
    vac_name = input("What is the vaccine used? ")
    efficiency =input(("What is the efficiency of the vaccine in percentage? "))
    effi_dec = (int(efficiency)/100)
    vac_people = int(input(("How many people are being vaccinated in your city/town per day? ")))
    vac_immunity= (vac_people *effi_dec) #calculates how many people are becoming immune from the vaccine per generation
    return vac_immunity

# %%
def vac_calculations( trans_rate, country, num_gen, daily_rise, population):
    
    '''Function to Calculate the number of individuals who gain immunity each generation WITH the inclusion of a vaccine.'''
  

    vac_immunity = vac_user()
    print('The transmission rate for {} is {}. '.format(country, trans_rate)) #informs the user of the information they did not directly imput
    mr= 0.036 #the UK mortality rate for the corona virus
    zero_death = (daily_rise*mr) #number of individuals that died from the cases the user provided
    zero_immunity = daily_rise - zero_death #number of individuals that gained immunity from the cases the user provides
    #length= int(num_gen) + 1 #the number of generations the user provided +1 so that the for program goes through the required amount of times
    gen = range(1, num_gen +1) #list of all generations
    total_cases = [daily_rise] #a list of all the cases
    vac_total_immunity = [zero_immunity] #list of number of individuals immune each generation
    total_death = [zero_death] #list of number of individuals died each generation
    total_generation= [0] #creates a list of the generation numbers
    vac_immune_list = [zero_immunity] #Sum of total immunity each generation
    vac_immune_percentage= []
    
    import collections
    infectious = collections.deque(maxlen=3)
    infectious.append(daily_rise)
    
    
    for t in gen: #Sequences through all generations
        
        sum_cases = sum(total_cases) #sums all the number of cases
        
        if sum_cases >= population: #if total number of cases is larger than the population or there are no more cases
            print('All of the population has been processed.')
            recovered = sum(total_immunity) #number of people who recovered
            total_infectious = sum(infectious)
            I= total_infectious
            portion_infected= I/population #the portion of the individuals who 
            not_in_population = (recovered + sum(total_death)) #sum of the people no longer suseptible either immune or dead
            S = (population-not_in_population) #removes those who are not suseptible from the population
            portion_S = (S/population) #portion of the people suseptible
            new_cases = portion_S*I*trans_rate#number of new cases: portion of individuals in the population who are suseptible * infected (contagious) * transmission rate
            infectious.append(new_cases)
            total_cases.append(new_cases) #adds to the total number of cases
            death =  (new_cases)*0.036 #portion of those infected who died
            total_death.append(death) #adds to the total number of deaths
            gen_immunity = new_cases + vac_immunity - death  #individuals who are immune that generation
            vac_total_immunity.append(gen_immunity) #adds to the total number of immune 
            print('On day {}, there were {:.0f} cases, after an increase of {:.0f}. {:.0f} people became immune, and {:.0f} died.'.format(t, new_cases, 
                                                                                                                               daily_rise, gen_immunity, death))
            print('After {} day(s) of COVID, {:.0f} number of people will be immune.'.format(t,sum(vac_total_immunity))) 
            daily_rise = new_cases
            print(' ')
            vac_immune_list.append(sum(vac_total_immunity)) #this creates an overall list of all the generation immunity data
           
            break
           
        else:
            recovered = sum(vac_total_immunity) #number of people who recovered
            total_infectious = sum(infectious)
            I= total_infectious #number of people who are infectious
            portion_infected= I/population #the portion of the individuals who 
            not_in_population = (recovered + sum(total_death)) #sum of the people no longer suseptible either immune or dead
            S = (population-not_in_population) #removes those who are not suseptible from the population
            portion_S = (S/population) #portion of the people suseptible
            new_cases = portion_S*I*trans_rate #number of new cases: portion of individuals in the population who are suseptible * infected (contagious) * transmission rate
            infectious.append(new_cases)
            if new_cases <= 0.5:
                pass
            else:
                total_generation.append(t) #adds a number to the total generation
                total_cases.append(new_cases) #adds to the total number of cases
                death = (new_cases)*0.036 #portion of those infected who died

                if death < 1:
                    total_death.append(1) #adds to the total number of deaths
                else:
                    total_death.append(death) #adds to the total number of deaths

                gen_immunity = new_cases+ vac_immunity - death #individuals who are immune that generation

                if gen_immunity < 1:
                        vac_total_immunity.append(1)
                else:
                    vac_total_immunity.append(gen_immunity) #adds to the total number of immune
                print('On day {}, there were {:.0f} cases, after an increase of {:.0f}. {:.0f} people became immune, and {:.0f} died.'.format(t, new_cases, 
                                                                                                                                   daily_rise, gen_immunity, death))
                print('After {} day(s) of COVID, {:.0f} number of people will be immune.'.format(t,sum(vac_total_immunity))) 
                daily_rise = new_cases
                print(' ')
                vac_immune_list.append(sum(vac_total_immunity))
    #The percentage is calculated and added to the list
    for immune in vac_immune_list:
        percentage=immune/population*100
        vac_immune_percentage.append(percentage)  
    return total_cases, vac_total_immunity, total_death, total_generation, vac_immune_list, vac_immune_percentage

# %%
def vac_table(total_cases, vac_total_immunity, total_death, total_generation, vac_immune_list, vac_immune_percentage ):
    '''Function to display and save to a file the data to be displayed in a graph'''
 
    
    #imports a software libraries needed to complete the program
    import pandas as pd
    import numpy as np
    
    #creates a dictionary of the number of generations vs the sum of the individuals with immunity
    data = {
    'Number of Generations': total_generation,
    'Number of individuals with immunity': vac_immune_percentage
        }
    
    #prints the information in data to a table
    table = pd.DataFrame(data)
    print(vac_table)
    numpy_array = table.to_numpy()
    print(' ')
    
    decide = input('Do you want to save the report to a file? Enter yes or no: ').capitalize() #ask if they want to save a file
    if decide == 'Yes': #If they input yes
        #currently only input that works is Gen
        print('Your file name will be "VacImmunityTable"') 

        how = input('How would you like your file to be opened? Enter append or write: ').capitalize() #ask how they want the data to be saved

            #confirm_how = input('Confirm editing format with yes or no: ').capitalize() #ask for confirmation

            #if confirm_how == 'No':#if enter no
               # how = input('How would you like your file to be opened? Enter append or write: ') #allowed to enter again

        if how == 'Write': #write the following into the provided file
            file = open('VacImmunityTable', 'w')
            np.savetxt('VacImmunityTable' , numpy_array, fmt = "%d")
            file.close()
            print('I have successfully saved the data under "VacImmunityTable". The program is complete.')

        elif how == 'Append': #append the following into the provided file
            file = open('VacImmunityTable', 'a')
            np.savetxt('VacImmunityTable' , numpy_array, fmt = "%d")
            file.close()
            print('I have successfully saved the data under "VacImmunityTable" The program is complete.')
            
        else:
            print('Error: I do not understand command "{}". Please enter either "Write" or "Append" and try again.'.format(how))
            vac_graph(total_cases,vac_total_immunity,total_death, total_generation,vac_immune_list, vac_immune_percentage)
    
    else:#if the user doesn't want to save a file.
        print('Okay, I will not save the data. The program is complete.')

# %%
def vac_graph(total_cases,vac_total_immunity,total_death, total_generation,vac_immune_list, vac_immune_percentage):
    '''Function which prints a graph of established data'''
    
    import pandas as pd
    
    tdf= pd.read_csv("VacImmunityTable",sep=" ") #reads file to collect the data
    tdf.shape
    tdf=pd.read_csv("VacImmunityTable",sep=" ",names=["Number of days", "Immunity with Vaccine (as percentage of the population)"]) #creates headers for the graph
    tdf.head()
    tdf.plot(x="Number of days",y="Immunity with Vaccine (as percentage of the population)") #plots the data

# %%
def covid_model():
    trans_rate, country, num_gen, daily_rise, population = user()
    total_cases,total_immunity,total_death, total_generation, immune_list,immune_percentage, infect_percentage, death_percentage = calculations(trans_rate, country, num_gen, daily_rise, population)
    table(total_cases,total_immunity,total_death, total_generation,immune_list,immune_percentage, infect_percentage, death_percentage)
    graph(total_cases,total_immunity,total_death, total_generation,immune_list,immune_percentage, infect_percentage, death_percentage)
    vac_decide = input('Do you want to run the vaccine simulation with the same values? Enter yes or no: ').capitalize()
    if vac_decide == 'Yes':
        
        total_cases, vac_total_immunity, total_death, total_generation, vac_immune_list,vac_immune_percentage= vac_calculations(trans_rate, country, num_gen, daily_rise, population)
        vac_table(total_cases,total_immunity,total_death, total_generation,immune_list,vac_immune_percentage)
        vac_graph(total_cases,vac_total_immunity,total_death, total_generation,vac_immune_list, vac_immune_percentage)
    else:
        trans_rate, country, num_gen, daily_rise, population = user()
        
        total_cases, vac_total_immunity, total_death, total_generation, vac_immune_list,vac_immune_percentage= vac_calculations(trans_rate, country, num_gen, daily_rise, population)
        vac_table(total_cases, vac_total_immunity, total_death, total_generation, vac_immune_list, vac_immune_percentage)
        vac_graph(total_cases,vac_total_immunity,total_death, total_generation,vac_immune_list, vac_immune_percentage)

# %%
covid_model()
# Out:
# What is the approximate population size of your city/town? 5000000
# What was the daily rise in number of cases in your area? 845
# How many days would you like to cycle through: 40
# Would you like the transmission rate to be a high or low estimate? Please enter "High" or "Low". low
# What country in the UK is your town or city? scotland
# The transmission rate for Scotland is 0.8.
# On day 1, there were 676 new cases. 652 people became immune, and 24 died.
# After 1 day(s) of COVID; there are 1521 total cases across the population and a total 1466 number of people will be immune.
#
# On day 2, there were 1216 new cases. 1173 people became immune, and 44 died.
# After 2 day(s) of COVID; there are 2737 total cases across the population and a total 2639 number of people will be immune.
#
# On day 3, there were 2189 new cases. 2110 people became immune, and 79 died.
# After 3 day(s) of COVID; there are 4926 total cases across the population and a total 4748 number of people will be immune.
#
# On day 4, there were 3261 new cases. 3144 people became immune, and 117 died.
# After 4 day(s) of COVID; there are 8187 total cases across the population and a total 7892 number of people will be immune.
#
# On day 5, there were 5324 new cases. 5133 people became immune, and 192 died.
# After 5 day(s) of COVID; there are 13512 total cases across the population and a total 13025 number of people will be immune.
#
# On day 6, there were 8596 new cases. 8287 people became immune, and 309 died.
# After 6 day(s) of COVID; there are 22108 total cases across the population and a total 21312 number of people will be immune.
#
# On day 7, there were 13685 new cases. 13192 people became immune, and 493 died.
# After 7 day(s) of COVID; there are 35793 total cases across the population and a total 34504 number of people will be immune.
#
# On day 8, there were 21926 new cases. 21137 people became immune, and 789 died.
# After 8 day(s) of COVID; there are 57719 total cases across the population and a total 55641 number of people will be immune.
#
# On day 9, there were 34957 new cases. 33699 people became immune, and 1258 died.
# After 9 day(s) of COVID; there are 92676 total cases across the population and a total 89340 number of people will be immune.
#
# On day 10, there were 55408 new cases. 53414 people became immune, and 1995 died.
# After 10 day(s) of COVID; there are 148085 total cases across the population and a total 142754 number of people will be immune.
#
# On day 11, there were 87173 new cases. 84035 people became immune, and 3138 died.
# After 11 day(s) of COVID; there are 235258 total cases across the population and a total 226788 number of people will be immune.
#
# On day 12, there were 135348 new cases. 130476 people became immune, and 4873 died.
# After 12 day(s) of COVID; there are 370606 total cases across the population and a total 357264 number of people will be immune.
#
# On day 13, there were 205863 new cases. 198452 people became immune, and 7411 died.
# After 13 day(s) of COVID; there are 576469 total cases across the population and a total 555716 number of people will be immune.
#
# On day 14, there were 303196 new cases. 292281 people became immune, and 10915 died.
# After 14 day(s) of COVID; there are 879665 total cases across the population and a total 847997 number of people will be immune.
#
# On day 15, there were 424828 new cases. 409534 people became immune, and 15294 died.
# After 15 day(s) of COVID; there are 1304493 total cases across the population and a total 1257531 number of people will be immune.
#
# On day 16, there were 552190 new cases. 532311 people became immune, and 19879 died.
# After 16 day(s) of COVID; there are 1856682 total cases across the population and a total 1789842 number of people will be immune.
#
# On day 17, there were 643859 new cases. 620680 people became immune, and 23179 died.
# After 17 day(s) of COVID; there are 2500541 total cases across the population and a total 2410521 number of people will be immune.
#
# On day 18, there were 648210 new cases. 624875 people became immune, and 23336 died.
# After 18 day(s) of COVID; there are 3148751 total cases across the population and a total 3035396 number of people will be immune.
#
# On day 19, there were 546269 new cases. 526603 people became immune, and 19666 died.
# After 19 day(s) of COVID; there are 3695020 total cases across the population and a total 3561999 number of people will be immune.
#
# On day 20, there were 383839 new cases. 370021 people became immune, and 13818 died.
# After 20 day(s) of COVID; there are 4078859 total cases across the population and a total 3932020 number of people will be immune.
#
# On day 21, there were 232617 new cases. 224242 people became immune, and 8374 died.
# After 21 day(s) of COVID; there are 4311476 total cases across the population and a total 4156263 number of people will be immune.
#
# On day 22, there were 128090 new cases. 123479 people became immune, and 4611 died.
# After 22 day(s) of COVID; there are 4439566 total cases across the population and a total 4279742 number of people will be immune.
#
# On day 23, there were 66763 new cases. 64360 people became immune, and 2403 died.
# After 23 day(s) of COVID; there are 4506329 total cases across the population and a total 4344101 number of people will be immune.
#
# On day 24, there were 33765 new cases. 32549 people became immune, and 1216 died.
# After 24 day(s) of COVID; there are 4540094 total cases across the population and a total 4376650 number of people will be immune.
#
# On day 25, there were 16823 new cases. 16217 people became immune, and 606 died.
# After 25 day(s) of COVID; there are 4556917 total cases across the population and a total 4392868 number of people will be immune.
#
# On day 26, there were 8319 new cases. 8020 people became immune, and 299 died.
# After 26 day(s) of COVID; there are 4565236 total cases across the population and a total 4400887 number of people will be immune.
#
# On day 27, there were 4098 new cases. 3950 people became immune, and 148 died.
# After 27 day(s) of COVID; there are 4569334 total cases across the population and a total 4404838 number of people will be immune.
#
# On day 28, there were 2015 new cases. 1942 people became immune, and 73 died.
# After 28 day(s) of COVID; there are 4571348 total cases across the population and a total 4406780 number of people will be immune.
#
# On day 29, there were 990 new cases. 954 people became immune, and 36 died.
# After 29 day(s) of COVID; there are 4572338 total cases across the population and a total 4407734 number of people will be immune.
#
# On day 30, there were 486 new cases. 468 people became immune, and 17 died.
# After 30 day(s) of COVID; there are 4572824 total cases across the population and a total 4408203 number of people will be immune.
#
# On day 31, there were 239 new cases. 230 people became immune, and 9 died.
# After 31 day(s) of COVID; there are 4573063 total cases across the population and a total 4408433 number of people will be immune.
#
# On day 32, there were 117 new cases. 113 people became immune, and 4 died.
# After 32 day(s) of COVID; there are 4573180 total cases across the population and a total 4408545 number of people will be immune.
#
# On day 33, there were 57 new cases. 55 people became immune, and 2 died.
# After 33 day(s) of COVID; there are 4573237 total cases across the population and a total 4408601 number of people will be immune.
#
# On day 34, there were 28 new cases. 27 people became immune, and 1 died.
# After 34 day(s) of COVID; there are 4573266 total cases across the population and a total 4408628 number of people will be immune.
#
# On day 35, there were 14 new cases. 13 people became immune, and 0 died.
# After 35 day(s) of COVID; there are 4573279 total cases across the population and a total 4408641 number of people will be immune.
#
# On day 36, there were 7 new cases. 7 people became immune, and 0 died.
# After 36 day(s) of COVID; there are 4573286 total cases across the population and a total 4408648 number of people will be immune.
#
# On day 37, there were 3 new cases. 3 people became immune, and 0 died.
# After 37 day(s) of COVID; there are 4573290 total cases across the population and a total 4408651 number of people will be immune.
#
# On day 38, there were 2 new cases. 2 people became immune, and 0 died.
# After 38 day(s) of COVID; there are 4573291 total cases across the population and a total 4408653 number of people will be immune.
#
# On day 39, there were 1 new cases. 1 people became immune, and 0 died.
# After 39 day(s) of COVID; there are 4573292 total cases across the population and a total 4408654 number of people will be immune.
#
#     Number of Generations  Number of individuals with immunity  \
# 0                     0.0                             0.016292
# 1                     1.0                             0.029323
# 2                     2.0                             0.052774
# 3                     3.0                             0.094970
# 4                     4.0                             0.157850
# 5                     5.0                             0.260503
# 6                     6.0                             0.426238
# 7                     7.0                             0.690081
# 8                     8.0                             1.112817
# 9                     9.0                             1.786797
# 10                   10.0                             2.855070
# 11                   11.0                             4.535766
# 12                   12.0                             7.145280
# 13                   13.0                            11.114325
# 14                   14.0                            16.959936
# 15                   15.0                            25.150616
# 16                   16.0                            35.796833
# 17                   17.0                            48.210427
# 18                   18.0                            60.707919
# 19                   19.0                            71.239987
# 20                   20.0                            78.640404
# 21                   21.0                            83.125251
# 22                   22.0                            85.594831
# 23                   23.0                            86.882022
# 24                   24.0                            87.533006
# 25                   25.0                            87.857351
# 26                   26.0                            88.017748
# 27                   27.0                            88.096752
# 28                   28.0                            88.135598
# 29                   29.0                            88.154681
# 30                   30.0                            88.164051
# 31                   31.0                            88.168651
# 32                   32.0                            88.170909
# 33                   33.0                            88.172017
# 34                   34.0                            88.172561
# 35                   35.0                            88.172828
# 36                   36.0                            88.172959
# 37                   37.0                            88.173023
# 38                   38.0                            88.173055
# 39                   39.0                            88.173075
#
#     Number of infections  Number of deaths
# 0               0.030418          0.001095
# 1               0.054744          0.001971
# 2               0.098516          0.003547
# 3               0.163745          0.005895
# 4               0.270232          0.009728
# 5               0.442155          0.015918
# 6               0.715851          0.025771
# 7               1.154375          0.041557
# 8               1.853524          0.066727
# 9               2.961691          0.106621
# 10              4.705151          0.169385
# 11              7.412117          0.266836
# 12             11.529383          0.415058
# 13             17.593295          0.633359
# 14             26.089851          0.939235
# 15             37.133644          1.336811
# 16             50.010817          1.800389
# 17             62.975020          2.267101
# 18             73.900401          2.660414
# 19             81.577182          2.936779
# 20             86.229513          3.104262
# 21             88.791319          3.196487
# 22             90.126579          3.244557
# 23             90.801874          3.268867
# 24             91.138331          3.280980
# 25             91.304718          3.286970
# 26             91.386672          3.289920
# 27             91.426969          3.291371
# 28             91.446765          3.292084
# 29             91.456485          3.292433
# 30             91.461256          3.292605
# 31             91.463598          3.292690
# 32             91.464748          3.292731
# 33             91.465312          3.292751
# 34             91.465589          3.292771
# 35             91.465725          3.292791
# 36             91.465792          3.292811
# 37             91.465824          3.292831
# 38             91.465840          3.292851
# 39                   NaN               NaN
#
# Do you want to save the report to a file? Enter yes or no: yes
# Your file name will be "ImmunityTable"
# How would you like your file to be opened? Enter append or write: write
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-47421d0aa91d> in <module>
# ----> 1 covid_model()
#
# <ipython-input-9-015de0466b86> in covid_model()
#       2     trans_rate, country, num_gen, daily_rise, population = user()
#       3     total_cases,total_immunity,total_death, total_generation, immune_list,immune_percentage, infect_percentage, death_percentage = calculations(trans_rate, country, num_gen, daily_rise, population)
# ----> 4     table(total_cases,total_immunity,total_death, total_generation,immune_list,immune_percentage, infect_percentage, death_percentage)
#       5     graph(total_cases,total_immunity,total_death, total_generation,immune_list,immune_percentage, infect_percentage, death_percentage)
#       6     vac_decide = input('Do you want to run the vaccine simulation with the same values? Enter yes or no: ').capitalize()
#
# <ipython-input-14-c8758a057c86> in table(total_cases, total_immunity, total_death, total_generation, immune_list, immune_percentage, infect_percentage, death_percentage)
#      39         if how == 'Write': #write the following into the provided file
#      40             file = open('ImmunityTable', 'w')
# ---> 41             np.savetxt('ImmunityTable' , numpy_array, fmt = "%d")
#      42             file.close()
#      43             print('I have successfully saved the data under "ImmunityTable". The program is complete.')
#
# <__array_function__ internals> in savetxt(*args, **kwargs)
#
# /opt/anaconda3/lib/python3.8/site-packages/numpy/lib/npyio.py in savetxt(fname, X, fmt, delimiter, newline, header, footer, comments, encoding)
#    1445             for row in X:
#    1446                 try:
# -> 1447                     v = format % tuple(row) + newline
#    1448                 except TypeError:
#    1449                     raise TypeError("Mismatch between array dtype ('%s') and "
#
# ValueError: cannot convert float NaN to integer
